# %%
import pandas as pd
import os

# %%
genome_dir = "/projects/ps-yeolab/genomes/hg19/gencode_v19/"
gene_attributes = "gencode.v19.annotation.gene.attributes.txt"
gene_attributes = pd.read_table(genome_dir+gene_attributes, names=['attributes']) # , index_col=0)
gene_attributes.head()
# Out:
#                                           attributes
# 0  gene_id "ENSG00000223972.4"; transcript_id "EN...
# 1  gene_id "ENSG00000227232.4"; transcript_id "EN...
# 2  gene_id "ENSG00000243485.2"; transcript_id "EN...
# 3  gene_id "ENSG00000237613.2"; transcript_id "EN...
# 4  gene_id "ENSG00000268020.2"; transcript_id "EN...

# %%
gene_attributes['coding'] = gene_attributes['attributes'].str.extract("gene_type \"([\w\d\.]+)\"")
# Out:
# /home/bay001/anaconda2/envs/brian/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
gene_attributes
# Out:
#                                               attributes                coding
# 0      gene_id "ENSG00000223972.4"; transcript_id "EN...            pseudogene
# 1      gene_id "ENSG00000227232.4"; transcript_id "EN...            pseudogene
# 2      gene_id "ENSG00000243485.2"; transcript_id "EN...               lincRNA
# 3      gene_id "ENSG00000237613.2"; transcript_id "EN...               lincRNA
# 4      gene_id "ENSG00000268020.2"; transcript_id "EN...            pseudogene
# 5      gene_id "ENSG00000240361.1"; transcript_id "EN...            pseudogene
# 6      gene_id "ENSG00000186092.4"; transcript_id "EN...        protein_coding
# 7      gene_id "ENSG00000238009.2"; transcript_id "EN...               lincRNA
# 8      gene_id "ENSG00000239945.1"; transcript_id "EN...               lincRNA
# 9      gene_id "ENSG00000233750.3"; transcript_id "EN...            pseudogene
# 10     gene_id "ENSG00000237683.5"; transcript_id "EN...        protein_coding
# ...

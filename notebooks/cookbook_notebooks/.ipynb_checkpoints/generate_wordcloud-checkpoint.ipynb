# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import glob
import networkx as nx
from wordcloud import WordCloud
# Out:
# /home/bay001/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
wd = '/home/bay001/projects/tbos_clipseq_20160809/analysis/recall_clips/recall_with_old/'
bedhead = ['chrom','start','end','l10p','l2fc','strand','annotation','gene']
gene2name = '/projects/ps-yeolab/genomes/hg19/ensembl_to_gene_name_biomart.txt'
clip2hta = '/home/bay001/projects/tbos_clipseq_20160809/permanent_data/clip2hta.txt'
hta2peak = pd.read_table(clip2hta,names=['hta','peak'])

clips = glob.glob(os.path.join(wd,"*.bed.annotated"))
#clips = clips[:1]

#clip = clips[0]
def gencode2ensembl(row):
    try:
        return row['gene'].split('.')[0]
    except Exception as e:
        return 'intergenic'
def getpeaks(clip, l10p = 3, l2fc = 3):
    df = pd.read_table(clip,names=bedhead)
    df = df[(df['l10p']>l10p) & (df['l2fc']>l2fc)]
    df['ensembl'] = df.apply(gencode2ensembl,axis=1)
    return df
def peak2rbp(clip,dfz):
    hta = ''
    try:
        hta = dfz[dfz['peak']==os.path.basename(clip).replace('.annotated','.trimmed.sorted.annotated')]['hta'].iloc[0]
    except IndexError as e:
        print('no known RBP for {}'.format(os.path.basename(clip)))
        return '-'
    return hta.replace(
        'hta_sepscore_yeo_aug15_all_','').replace(
        '_sepscore','').replace(
        '_over','').replace(
        '_kd','').replace(
        '_over1','')
def make_wordcloud(clip,outdir,l10p=3,l2fc=3,min_peak_count=0):
    hta2peak = pd.read_table(clip2hta,names=['hta','peak'])
    dfx = pd.read_table(gene2name)
    
    dfy = getpeaks(clip,l10p,l2fc)
    num_peaks = dfy.shape[0]
    df = pd.merge(dfy,dfx,how='left',left_on='ensembl',right_on='Ensembl Gene ID')
    df['Counts'] = df.groupby(['Associated Gene Name'])['Associated Gene Name'].transform('count')
    df.sort_values('Counts',ascending=False,inplace=True)
    df = df[df['Counts'] > min_peak_count]
    wordcloud = WordCloud().generate(str(list(df['Associated Gene Name'])).replace(',','').replace('\'',''))
    plt.imshow(wordcloud)
    plt.title("{}, peaks: {}".format(peak2rbp(clip,hta2peak),num_peaks))
    plt.axis("off")
    plt.savefig(os.path.join(outdir,clip)+'.png')
    return df

# %%
out = '/home/bay001/projects/tbos_clipseq_20160809/analysis/recall_clips/recall_with_old/wordclouds/'
i = 0
for clip in clips:
    make_wordcloud(clip,out)
    print(os.path.basename(clip),i),
    i = i + 1
# Out:
# ('A11_02_01.basedon_A11_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 0) ('TIAL_01_01.basedon_TIAL_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 1) ('WTL_01_01.basedon_WTL_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 2) ('APO_01_01.basedon_APO_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 3) ('DAZ_P_02_01.basedon_DAZ_P_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 4) ('DAZ_NP_02_01.basedon_DAZ_NP_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 5) ('A5_01_01.basedon_A5_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 6) ('A2_02_01.basedon_A2_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 7) ('DAZ_NP_01_01.basedon_DAZ_NP_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 8) ('A3_01_01.basedon_A3_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 9) ('A4_02_01.basedon_A4_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 10) ('A1_01_01.basedon_A1_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 11) ('A6_02_01.basedon_A6_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 12) ('A9_01_01.basedon_A9_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 13) ('TIAL_02_01.basedon_TIAL_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 14) ('LUC_02_01.basedon_LUC_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 15) ('A3_02_01.basedon_A3_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 16) ('A4_01_01.basedon_A4_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 17) ('A1_02_01.basedon_A1_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 18) ('A6_01_01.basedon_A6_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 19) ('LUC_01_01.basedon_LUC_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 20) ('A5_02_01.basedon_A5_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 21) ('A2_01_01.basedon_A2_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 22) ('A9_02_01.basedon_A9_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 23) no known RBP for WTV5_01_01.basedon_WTV5_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated
# ('WTV5_01_01.basedon_WTV5_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 24) ('DAZ_P_01_01.basedon_DAZ_P_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 25) no known RBP for WTV5_02_01.basedon_WTV5_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated
# ('WTV5_02_01.basedon_WTV5_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 26) ('A11_01_01.basedon_A11_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 27) ('WTL_02_01.basedon_WTL_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 28) ('APO_02_01.basedon_APO_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated', 29)

# %%
import xml.etree.ElementTree as et 
import pandas as pd
import numpy as np
import os
import glob
from xml.dom import minidom
from collections import defaultdict
import yaml

from yaml.representer import Representer
yaml.add_representer(defaultdict, Representer.represent_dict)

import json

# %%
input_file = '/projects/ps-yeolab4/NCRCRG/home/bay001/notebooks/SraExperimentPackage.xml'

# %%
my_expt_set_metadata = []    

xmldoc = minidom.parse(input_file)
expt_packages = xmldoc.getElementsByTagName('EXPERIMENT_PACKAGE')
for expt_package in expt_packages:
    my_expt_metadata = defaultdict(list)
    
    organization_metadata = expt_package.getElementsByTagName('Organization')
    for metadata in organization_metadata:
        my_expt_metadata['organization'].append(metadata.getElementsByTagName('Name')[0].firstChild.data)
        my_expt_metadata['email'].append(metadata.getElementsByTagName('Contact')[0].attributes['email'].value)
    my_expt_metadata['organization'] = ','.join(my_expt_metadata['organization'])
    my_expt_metadata['email'] = ','.join(my_expt_metadata['email'])
    
    expt_metadata = expt_package.getElementsByTagName('EXPERIMENT')
    for metadata in expt_metadata:
        title = metadata.getElementsByTagName('TITLE')[0].firstChild.data
        my_expt_metadata['experiment_nickname'].append(metadata.attributes['accession'].value)
        my_expt_metadata['experiment_summary'].append(title)
    my_expt_metadata['experiment_nickname'] = ','.join(my_expt_metadata['experiment_nickname'])
    my_expt_metadata['experiment_summary'] = ','.join(my_expt_metadata['experiment_summary'])
    
    design_metadata = expt_package.getElementsByTagName('DESIGN')
    for metadata in design_metadata:
        try:
            design = metadata.getElementsByTagName('DESIGN_DESCRIPTION')[0].firstChild.data
        except AttributeError:
            design = ''
        my_expt_metadata['experiment_design'].append(design)
    my_expt_metadata['experiment_design'] = ','.join(my_expt_metadata['experiment_design'])
    
    run_set = expt_package.getElementsByTagName('RUN_SET')
    
    for run in run_set:
        my_run_metadata = defaultdict(dict)
        
        
        run_metadata = run.getElementsByTagName('RUN')
        for metadata in run_metadata:
            my_run_metadata['library_nickname'] = metadata.attributes['accession'].value
            my_run_metadata['library_prep'] = ""
            my_run_metadata['sample_id'] = metadata.attributes['accession'].value
            my_run_metadata['original_assembly'] = metadata.attributes['assembly'].value
        
        file_metadata = run.getElementsByTagName('SRAFile')
        for metadata in file_metadata:
            filename = metadata.attributes['filename'].value
            url = metadata.attributes['url'].value
            if filename.endswith('.bam'):
                my_run_metadata['bam_file']['class'] = 'File'
                my_run_metadata['bam_file']['path'] = metadata.attributes['url'].value
                
        instrument_metadata = expt_package.getElementsByTagName('PLATFORM')
        for metadata in instrument_metadata:
            try:
                instrument = metadata.getElementsByTagName('INSTRUMENT_MODEL')[0].firstChild.data
            except AttributeError:
                instrument = ''
            my_run_metadata['instrument_model'] = instrument
            my_run_metadata['read1_length'] = 26
            my_run_metadata['read2_length'] = 98
            my_run_metadata['expect_cells'] = 3000
            
        
        # This actually belong on the top level per-expt, but we apply characteristics to each file.
        taxonomy_metadata = expt_package.getElementsByTagName('SAMPLE_NAME')
        for metadata in taxonomy_metadata:
            scientific_name = metadata.getElementsByTagName('SCIENTIFIC_NAME')[0].firstChild.data
            my_expt_metadata['organism'] = scientific_name
        
        sample_set = expt_package.getElementsByTagName('SAMPLE')
        for sample in sample_set:
            sample_metadata = sample.getElementsByTagName('SAMPLE_ATTRIBUTES')
            characteristics_list = []
            for metadata in sample_metadata:
                attributes = metadata.getElementsByTagName('SAMPLE_ATTRIBUTE')
                my_sample_metadata = defaultdict()
                for attribute in attributes:
                    characteristics_tag = {
                        'name': attribute.getElementsByTagName('TAG')[0].firstChild.data,
                        'value': attribute.getElementsByTagName('VALUE')[0].firstChild.data
                    }
                    characteristics_list.append(characteristics_tag)
        my_run_metadata['characteristics'] = characteristics_list
        my_expt_metadata['samples'].append(my_run_metadata)
        

    my_expt_set_metadata.append(my_expt_metadata)

# %%
for expt in my_expt_set_metadata:
    with open('/projects/ps-yeolab4/NCRCRG/home/bay001/notebooks/{}.json'.format(expt['experiment_nickname']), 'w') as o:
        json.dump(dict(expt), o, indent=2)

# %%
my_expt_set_metadata
# Out:
# [defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809389',
#               'experiment_summary': 'RNA-Seq of mouse ENS',
#               'experiment_design': 'Single-cell suspensions were prepared using Liberase/TrypLE digestion followed by manual trituration using a Pasteur pipette. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854061',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854061',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854061/10X81_2.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'Wnt1Cre-R26Rtomato-C57BL/6J'},
#                              {'name': 'age', 'value': 'p19, p21'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'ENS'},
#                              {'name': 'cell_index', 'value': 'SI-GA-D5'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809388',
#               'experiment_summary': 'RNA-Seq of mouse ENS',
#               'experiment_design': 'Single-cell suspensions were prepared using Liberase/TrypLE digestion followed by manual trituration using a Pasteur pipette. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854062',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854062',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854062/10X81_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'Wnt1Cre-R26Rtomato-C57BL/6J'},
#                              {'name': 'age', 'value': 'p19, p21'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'ENS'},
#                              {'name': 'cell_index', 'value': 'SI-GA-C5'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809383',
#               'experiment_summary': 'RNA-Seq of mouse ENS',
#               'experiment_design': 'Single-cell suspensions were prepared using Liberase/TrypLE digestion followed by manual trituration using a Pasteur pipette. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854067',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854067',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854067/10X82_2.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'Wnt1Cre-R26Rtomato-C57BL/6J'},
#                              {'name': 'age', 'value': 'p21, p23'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'ENS'},
#                              {'name': 'cell_index', 'value': 'SI-GA-G5'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809382',
#               'experiment_summary': 'RNA-Seq of mouse ENS',
#               'experiment_design': 'Single-cell suspensions were prepared using Liberase/TrypLE digestion followed by manual trituration using a Pasteur pipette. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854068',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854068',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854068/10X81_3.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'Wnt1Cre-R26Rtomato-C57BL/6J'},
#                              {'name': 'age', 'value': 'p19, p21'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'ENS'},
#                              {'name': 'cell_index', 'value': 'SI-GA-E5'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3830113',
#               'experiment_summary': 'RNA-Seq of mouse ventral midbrain',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6877265',
#                             'library_prep': '',
#                             'sample_id': 'SRR6877265',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6877265/10X52_7.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad26'},
#                              {'name': 'age', 'value': 'p20'},
#                              {'name': 'sex', 'value': 'male'},
#                              {'name': 'tissue', 'value': 'ventral midbrain'},
#                              {'name': 'cell_index', 'value': 'SI-3A-G10'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809399',
#               'experiment_summary': 'RNA-Seq of mouse Pons',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854051',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854051',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854051/10X33_4.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad15, Ad16'},
#                              {'name': 'age', 'value': 'p20'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'Pons'},
#                              {'name': 'cell_index', 'value': 'SI-3A-B11'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809398',
#               'experiment_summary': 'RNA-Seq of mouse Amygdala',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854052',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854052',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854052/10X34_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad17'},
#                              {'name': 'age', 'value': 'p21'},
#                              {'name': 'sex', 'value': 'female'},
#                              {'name': 'tissue', 'value': 'Amygdala'},
#                              {'name': 'cell_index', 'value': 'SI-3A-E4'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809397',
#               'experiment_summary': 'RNA-Seq of mouse StriatumVentral',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854053',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854053',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854053/10X26_4.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad13'},
#                              {'name': 'age', 'value': 'p25'},
#                              {'name': 'sex', 'value': 'female'},
#                              {'name': 'tissue', 'value': 'StriatumVentral'},
#                              {'name': 'cell_index', 'value': 'SI-3A-D8'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809396',
#               'experiment_summary': 'RNA-Seq of mouse Ctx3',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854054',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854054',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854054/10X28_2.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad14'},
#                              {'name': 'age', 'value': 'p26'},
#                              {'name': 'sex', 'value': 'male'},
#                              {'name': 'tissue', 'value': 'Ctx3'},
#                              {'name': 'cell_index', 'value': 'SI-3A-E8'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809395',
#               'experiment_summary': 'RNA-Seq of mouse Ctx3',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854055',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854055',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854055/10X28_3.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad14'},
#                              {'name': 'age', 'value': 'p26'},
#                              {'name': 'sex', 'value': 'male'},
#                              {'name': 'tissue', 'value': 'Ctx3'},
#                              {'name': 'cell_index', 'value': 'SI-3A-F8'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809394',
#               'experiment_summary': 'RNA-Seq of mouse OB',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854056',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854056',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854056/10X28_4.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad14'},
#                              {'name': 'age', 'value': 'p26'},
#                              {'name': 'sex', 'value': 'male'},
#                              {'name': 'tissue', 'value': 'OB'},
#                              {'name': 'cell_index', 'value': 'SI-3A-G8'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809393',
#               'experiment_summary': 'RNA-Seq of mouse OB',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854057',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854057',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854057/10X28_5.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad14'},
#                              {'name': 'age', 'value': 'p26'},
#                              {'name': 'sex', 'value': 'male'},
#                              {'name': 'tissue', 'value': 'OB'},
#                              {'name': 'cell_index', 'value': 'SI-3A-H8'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809392',
#               'experiment_summary': 'RNA-Seq of mouse Medulla',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854058',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854058',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854058/10X33_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad15, Ad16'},
#                              {'name': 'age', 'value': 'p20'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'Medulla'},
#                              {'name': 'cell_index', 'value': 'SI-3A-G10'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809391',
#               'experiment_summary': 'RNA-Seq of mouse Medulla',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854059',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854059',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854059/10X33_2.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad15, Ad16'},
#                              {'name': 'age', 'value': 'p20'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'Medulla'},
#                              {'name': 'cell_index', 'value': 'SI-3A-H10'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809390',
#               'experiment_summary': 'RNA-Seq of mouse Pons',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854060',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854060',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854060/10X33_3.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad15, Ad16'},
#                              {'name': 'age', 'value': 'p20'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'Pons'},
#                              {'name': 'cell_index', 'value': 'SI-3A-A11'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809387',
#               'experiment_summary': 'RNA-Seq of mouse Sympath',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854063',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854063',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854063/10X75_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'SYMP1'},
#                              {'name': 'age', 'value': '6w'},
#                              {'name': 'sex', 'value': 'missing'},
#                              {'name': 'tissue', 'value': 'Sympath'},
#                              {'name': 'cell_index', 'value': 'SI-3A-A8'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809386',
#               'experiment_summary': 'RNA-Seq of mouse Thalamus',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854064',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854064',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854064/10X57_7.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'Swiss'},
#                              {'name': 'isolate', 'value': 'Ad33, Ad34'},
#                              {'name': 'age', 'value': 'p25-27'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'Thalamus'},
#                              {'name': 'cell_index', 'value': 'SI-3A-D2'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809385',
#               'experiment_summary': 'RNA-Seq of mouse Hypothalamus',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854065',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854065',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854065/10X86_3.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'missing'},
#                              {'name': 'isolate', 'value': 'Ad36'},
#                              {'name': 'age', 'value': 'p19'},
#                              {'name': 'sex', 'value': 'missing'},
#                              {'name': 'tissue', 'value': 'Hypothalamus'},
#                              {'name': 'cell_index', 'value': 'SI-3A-A1'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809384',
#               'experiment_summary': 'RNA-Seq of mouse Hypothalamus',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854066',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854066',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854066/10X86_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'missing'},
#                              {'name': 'age', 'value': 'p19'},
#                              {'name': 'sex', 'value': 'missing'},
#                              {'name': 'tissue', 'value': 'Hypothalamus'},
#                              {'name': 'cell_index', 'value': 'SI-3A-A3'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809381',
#               'experiment_summary': 'RNA-Seq of mouse Amygdala',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854069',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854069',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854069/10X87_2.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'missing'},
#                              {'name': 'isolate', 'value': 'Ad37,Ad38'},
#                              {'name': 'age', 'value': 'p21'},
#                              {'name': 'sex', 'value': 'missing'},
#                              {'name': 'tissue', 'value': 'Amygdala'},
#                              {'name': 'cell_index', 'value': 'SI-3A-D1'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809380',
#               'experiment_summary': 'RNA-Seq of mouse Amygdala',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854070',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854070',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854070/10X87_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'missing'},
#                              {'name': 'isolate', 'value': 'Ad37,Ad38'},
#                              {'name': 'age', 'value': 'p21'},
#                              {'name': 'sex', 'value': 'missing'},
#                              {'name': 'tissue', 'value': 'Amygdala'},
#                              {'name': 'cell_index', 'value': 'SI-3A-C1'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809379',
#               'experiment_summary': 'RNA-Seq of mouse SScortex',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854071',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854071',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854071/10X01_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad01'},
#                              {'name': 'age', 'value': 'p28'},
#                              {'name': 'sex', 'value': 'missing'},
#                              {'name': 'tissue', 'value': 'SScortex'},
#                              {'name': 'cell_index', 'value': 'SI-3A-A1'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809378',
#               'experiment_summary': 'RNA-Seq of mouse SScortex',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854072',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854072',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854072/10X02_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad02'},
#                              {'name': 'age', 'value': 'p29'},
#                              {'name': 'sex', 'value': 'missing'},
#                              {'name': 'tissue', 'value': 'SScortex'},
#                              {'name': 'cell_index', 'value': 'SI-3A-B1'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809377',
#               'experiment_summary': 'RNA-Seq of mouse MidbrainVentral',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854073',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854073',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854073/10X57_5.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'Swiss'},
#                              {'name': 'isolate', 'value': 'Ad33, Ad34'},
#                              {'name': 'age', 'value': 'p25-27'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'MidbrainVentral'},
#                              {'name': 'cell_index', 'value': 'SI-3A-B2'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809376',
#               'experiment_summary': 'RNA-Seq of mouse Thalamus',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854074',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854074',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854074/10X57_6.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'Swiss'},
#                              {'name': 'isolate', 'value': 'Ad33, Ad34'},
#                              {'name': 'age', 'value': 'p25-27'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'Thalamus'},
#                              {'name': 'cell_index', 'value': 'SI-3A-C2'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809375',
#               'experiment_summary': 'RNA-Seq of mouse MidbrainDorsal',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854075',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854075',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854075/10X57_3.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'Swiss'},
#                              {'name': 'isolate', 'value': 'Ad33, Ad34'},
#                              {'name': 'age', 'value': 'p25-27'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'MidbrainDorsal'},
# ...
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate',
#                               'value': 'Pdgfra01, Pdgfra02'},
#                              {'name': 'age', 'value': 'p20'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'Medulla'},
#                              {'name': 'cell_index', 'value': 'SI-3A-D7'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809276',
#               'experiment_summary': 'RNA-Seq of mouse Ctx1.5',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854174',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854174',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854174/10X38_3.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'vGat-tdTomato'},
#                              {'name': 'isolate',
#                               'value': 'CAint08, CAint09, CAint10'},
#                              {'name': 'age', 'value': 'p60'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'Ctx1.5'},
#                              {'name': 'cell_index', 'value': 'SI-3A-D12'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809275',
#               'experiment_summary': 'RNA-Seq of mouse DentGyr',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854175',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854175',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854175/10X43_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad19, Ad20'},
#                              {'name': 'age', 'value': 'p12, p35'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'DentGyr'},
#                              {'name': 'cell_index', 'value': 'SI-3A-E12'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809274',
#               'experiment_summary': 'RNA-Seq of mouse CA1',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854176',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854176',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854176/10X38_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'vGat-tdTomato'},
#                              {'name': 'isolate',
#                               'value': 'CAint08, CAint09, CAint10'},
#                              {'name': 'age', 'value': 'p60'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'CA1'},
#                              {'name': 'cell_index', 'value': 'SI-3A-B12'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809273',
#               'experiment_summary': 'RNA-Seq of mouse CA1',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854177',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854177',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854177/10X38_2.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'vGat-tdTomato'},
#                              {'name': 'isolate',
#                               'value': 'CAint08, CAint09, CAint10'},
#                              {'name': 'age', 'value': 'p60'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'CA1'},
#                              {'name': 'cell_index', 'value': 'SI-3A-C12'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809272',
#               'experiment_summary': 'RNA-Seq of mouse DentGyr',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854178',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854178',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854178/10X46_1.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad22, Ad23'},
#                              {'name': 'age', 'value': 'p16, p24'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'DentGyr'},
#                              {'name': 'cell_index', 'value': 'SI-3A-H12'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809271',
#               'experiment_summary': 'RNA-Seq of mouse StriatumVentral',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854179',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854179',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854179/10X46_2.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad22, Ad23'},
#                              {'name': 'age', 'value': 'p16, p24'},
#                              {'name': 'sex',
#                               'value': 'pooled male and female'},
#                              {'name': 'tissue', 'value': 'StriatumVentral'},
#                              {'name': 'cell_index', 'value': 'SI-3A-H11'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809270',
#               'experiment_summary': 'RNA-Seq of mouse DRG',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854180',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854180',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854180/10X43_2.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad21'},
#                              {'name': 'age', 'value': 'p20'},
#                              {'name': 'sex', 'value': 'male'},
#                              {'name': 'tissue', 'value': 'DRG'},
#                              {'name': 'cell_index', 'value': 'SI-3A-F12'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]}),
#  defaultdict(list,
#              {'organization': 'Karolinska Institute',
#               'email': 'peter.lonnerberg@ki.se',
#               'experiment_nickname': 'SRX3809269',
#               'experiment_summary': 'RNA-Seq of mouse SC',
#               'experiment_design': 'Single-cell suspensions were prepared using papain digestion followed by manual trituration using a Pasteur pipettes. Cells were resuspended in artificial cerebrospinal fluid and further processed with the 10X Genomics Chromium Single Cell Kit Version 1 aiming for 3500 cells per sample.',
#               'organism': 'Mus musculus',
#               'samples': [defaultdict(dict,
#                            {'library_nickname': 'SRR6854181',
#                             'library_prep': '',
#                             'sample_id': 'SRR6854181',
#                             'original_assembly': 'GRCm38',
#                             'bam_file': {'class': 'File',
#                              'path': 'https://sra-pub-src-1.s3.amazonaws.com/SRR6854181/10X43_3.bam.1'},
#                             'instrument_model': 'Illumina HiSeq 2500',
#                             'read1_length': 26,
#                             'read2_length': 98,
#                             'expect_cells': 3000,
#                             'characteristics': [{'name': 'strain',
#                               'value': 'CD-1'},
#                              {'name': 'isolate', 'value': 'Ad21'},
#                              {'name': 'age', 'value': 'p20'},
#                              {'name': 'sex', 'value': 'male'},
#                              {'name': 'tissue', 'value': 'SC'},
#                              {'name': 'cell_index', 'value': 'SI-3A-G12'},
#                              {'name': 'BioSampleModel',
#                               'value': 'Model organism or animal'}]})]})]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import glob
import seaborn as sns
import gffutils
from pathway import GO  # look at bfx/

# %%
input_dir = 'inputs/'
output_dir = 'outputs/'

# %%
gene_list = os.path.join(output_dir, 'GO.txt')
bg_list = os.path.join(output_dir, 'BG.txt')

# %%
go_file = '/projects/ps-yeolab3/bay001/annotations/hg19_ensg_to_go.txt'
hg19go = GO.GO(go_file)

# %%
# get the background (all genes)
db_file = '/projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf.db'
DATABASE = gffutils.FeatureDB(db_file)

def find_protein_coding_genes(db):
    """
    Finds the number of protein coding genes in the database.
    """
    all_pc = []
    pc_count = 0
    genes = db.features_of_type('gene')
    for gene in genes:
        pc = False
        for gene_type in gene.attributes['gene_type']:
            if gene_type == 'protein_coding':
                for geneid in gene.attributes['gene_id']:
                    all_pc.append(geneid.split('.')[0]) # just get the ensembl-style IDs, not gencode
    return set(all_pc)

protein_coding_genes = find_protein_coding_genes(DATABASE)
# Out:
# /home/bay001/anaconda2/envs/brian/lib/python2.7/site-packages/gffutils/interface.py:161: UserWarning: It appears that this database has not had the ANALYZE sqlite3 command run on it. Doing so can dramatically speed up queries, and is done by default for databases created with gffutils >0.8.7.1 (this database was created with version 0.8.1) Consider calling the analyze() method of this object.
#   "method of this object." % self.version)

# %%
print(len(protein_coding_genes)) # number of protein coding genes. make sure it's reasonable (~20,000)
with open(bg_list, 'w') as f:
    for geneid in protein_coding_genes:
        f.write('{}\n'.format(geneid))
# Out:
# 20345

# %%
genes = pd.read_table(
    os.path.join(input_dir, '764.01v02.IDR.out.0102merged.bed.annotated'),
    names=['chrom','start','end','name','score','strand','region','geneid']
)
genes.head()
# Out:
#    chrom      start        end      name     score strand  \
# 0   chr5  138665777  138665826  5.290644  3.686779      +
# 1  chr20   30824074   30824134  3.887475  5.240236      +
# 2   chr3  141667691  141667722  5.369356  4.129040      -
# 3   chr1  113667717  113667786  8.662595  4.978746      +
# 4   chr1  113667654  113667717  5.413653  4.076449      +
#
#                               region              geneid
# 0  3utr|contained|ENSG00000015479.13  ENSG00000015479.13
# 1   3utr|contained|ENSG00000101346.7   ENSG00000101346.7
# 2  3utr|contained|ENSG00000114126.13  ENSG00000114126.13
# 3   3utr|contained|ENSG00000198799.7   ENSG00000198799.7
# 4   3utr|contained|ENSG00000198799.7   ENSG00000198799.7

# %%
def get_ensembl_id(row):
    try:
        return row['geneid'].split('.')[0]
    except AttributeError:
        return 'intergenic'
    
genes['ensembl'] = genes.apply(get_ensembl_id, axis=1)
genes.head()
# Out:
#    chrom      start        end      name     score strand  \
# 0   chr5  138665777  138665826  5.290644  3.686779      +
# 1  chr20   30824074   30824134  3.887475  5.240236      +
# 2   chr3  141667691  141667722  5.369356  4.129040      -
# 3   chr1  113667717  113667786  8.662595  4.978746      +
# 4   chr1  113667654  113667717  5.413653  4.076449      +
#
#                               region              geneid          ensembl
# 0  3utr|contained|ENSG00000015479.13  ENSG00000015479.13  ENSG00000015479
# 1   3utr|contained|ENSG00000101346.7   ENSG00000101346.7  ENSG00000101346
# 2  3utr|contained|ENSG00000114126.13  ENSG00000114126.13  ENSG00000114126
# 3   3utr|contained|ENSG00000198799.7   ENSG00000198799.7  ENSG00000198799
# 4   3utr|contained|ENSG00000198799.7   ENSG00000198799.7  ENSG00000198799

# %%
with open(gene_list, 'w') as f:
    for geneid in set(genes['ensembl']):
        if geneid != 'intergenic':
            f.write('{}\n'.format(geneid))

# %%
df = hg19go.enrichment(list(set(genes['ensembl'])), background=list(protein_coding_genes))
# Out:
#                                                       Gene stable ID  \
# GO term accession
# GO:0005829         {ENSG00000167693, ENSG00000171408, ENSG0000006...
# GO:0005515         {ENSG00000167693, ENSG00000064703, ENSG0000011...
# GO:0005634         {ENSG00000167693, ENSG00000064703, ENSG0000019...
# GO:0005654         {ENSG00000102054, ENSG00000198157, ENSG0000023...
# GO:0005737         {ENSG00000124209, ENSG00000261772, ENSG0000018...
#
#                                                            Gene name  \
# GO term accession
# GO:0005829         {HIF3A, PGM2L1, CEL, FHIT, NCBP2, HSPA8, AGL, ...
# GO:0005515         {RNF14, DUOXA1, RNF17, RNF10, RNF11, RNF13, UB...
# GO:0005634         {HIF3A, HIST1H4B, HIST1H4A, RNF17, HIST1H4G, R...
# GO:0005654         {HIF3A, HIST1H4B, HIST1H4A, C17orf70, HIST1H4F...
# GO:0005737         {HIF3A, RNF14, ELANE, RNF17, RNF10, FHIT, NCBP...
#
#                         GO term name  \
# GO term accession
# GO:0005829                 {cytosol}
# GO:0005515         {protein binding}
# GO:0005634                 {nucleus}
# GO:0005654             {nucleoplasm}
# GO:0005737               {cytoplasm}
#
#                                                   GO term definition  \
# GO term accession
# GO:0005829         {The part of the cytoplasm that does not conta...
# GO:0005515         {Interacting selectively and non-covalently wi...
# GO:0005634         {A membrane-bounded organelle of eukaryotic ce...
# GO:0005654         {That part of the nuclear content other than t...
# GO:0005737         {All of the contents of a cell excluding the p...
#
#                                           GO term evidence code  \
# GO term accession
# GO:0005829              {TAS, ISS, IBA, NAS, IEA, IC, IMP, IDA}
# GO:0005515                                           {IEA, IPI}
# GO:0005634         {TAS, ISS, IBA, IPI, IMP, NAS, IEA, IC, IDA}
# GO:0005654                  {NAS, ISS, IBA, TAS, IMP, IEA, IDA}
# GO:0005737         {TAS, ISS, IBA, IPI, IMP, NAS, IEA, IC, IDA}
#
#                             GO domain  nGenes  inBoth  expressedGOGenes  \
# GO term accession
# GO:0005829         cellular_component    2766     540              2548
# GO:0005515         molecular_function   10450    1401              9086
# GO:0005634         cellular_component    5809     889              5323
# GO:0005654         cellular_component    1119     242              1022
# GO:0005737         cellular_component    5205     772              4794
#
#                    Hypergeometric p-Value  \
# GO term accession
# GO:0005829                   2.907186e-45
# GO:0005515                   1.573878e-39
# GO:0005634                   5.605998e-32
# GO:0005654                   1.064598e-26
# GO:0005737                   8.224785e-22
#
#                    Bonferroni-corrected Hypergeometric p-Value  \
# GO term accession
# GO:0005829                                        4.264842e-42
# GO:0005515                                        2.308879e-36
# GO:0005634                                        8.223999e-29
# GO:0005654                                        1.561765e-23
# GO:0005737                                        1.206576e-18
#
#                                             Ensembl Gene IDs in List  \
# GO term accession
# GO:0005829         ENSG00000233927,ENSG00000075643,ENSG0000010052...
# GO:0005515         ENSG00000124209,ENSG00000103507,ENSG0000010655...
# GO:0005634         ENSG00000124209,ENSG00000123091,ENSG0000017921...
# GO:0005654         ENSG00000111358,ENSG00000131508,ENSG0000017393...
# GO:0005737         ENSG00000124209,ENSG00000173933,ENSG0000017921...
#
#                                                 Gene symbols in List  \
# GO term accession
# GO:0005829         NCBP1,CRKL,AP1M1,FKBP4,SMG5,BLOC1S6,SMG7,PPP3R...
# GO:0005515         RNF14,UBE2Q2,NCBP1,HSPA5,RNF13,NELFB,RNF11,PPP...
# GO:0005634         RNF14,SMARCC1,RNF11,HSPA5,NELFB,MNT,SUMO3,STK1...
# GO:0005654         KHSRP,NCBP1,PPP3R1,ZFPM2,SUMO3,ZFPM1,AKT1,SRSF...
# GO:0005737         RNF14,UBE2Q2,NELFB,SUMO3,STK11,FKBP4,FKBP5,HIP...
#
#                   GO Term Description  N Genes in GO category  \
# GO term accession
# GO:0005829                    cytosol                    2766
# GO:0005515            protein binding                   10450
# GO:0005634                    nucleus                    5809
# GO:0005654                nucleoplasm                    1119
# GO:0005737                  cytoplasm                    5205
#
#                    N Expressed Genes in GO Category  \
# GO term accession
# GO:0005829                                     2548
# GO:0005515                                     9086
# GO:0005634                                     5323
# GO:0005654                                     1022
# GO:0005737                                     4794
#
#                    N Genes in List and GO Category
# GO term accession
# GO:0005829                                     540
# GO:0005515                                    1401
# GO:0005634                                     889
# GO:0005654                                     242
# GO:0005737                                     772

# %% [markdown]
# # Some helpful functions for querying NCBI's REST API

# %%
import urllib
import xmltodict
from xml.dom import minidom

# %% [markdown]
# # Query the Gene Expression Omnibus (GEO) using a key term

# %%
def esearch(term, db='gds'):
    """
    Queries NCBI using the esearch utility. GEO ('gds') database is used as default for search term.
    """
    url = f'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db={db}&term={term}&retmax=5000&usehistory=y'
    response = urllib.request.urlopen(url)
    return response.read()


def get_esummary(esearch_string, db='gds'):
    """
    Parses a http response in XML format to obtain the webenv and querykey tokens.
    Uses NCBI eutils to transform these tokens into web summaries of GEO (db='gds') datasets.
    """
    xmldoc = minidom.parseString(esearch_string)
    try:
        webenv = xmldoc.getElementsByTagName('WebEnv')[0].firstChild.data
        querykey = xmldoc.getElementsByTagName('QueryKey')[0].firstChild.data
        host = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi'
        params = f'?db={db}&version=2.0&query_key={querykey}&WebEnv={webenv}'
        url = host + params
        response = urllib.request.urlopen(url)
        return response.read()
    except IndexError as e:
        print(f"Unparsable publication string ({e}, search={esearch_string}")
        return ""

# %%
key_term = "eCLIP"
esearch_string = esearch(key_term, db='gds')
result = get_esummary(esearch_string=esearch_string)
result = xmltodict.parse(result)
result['eSummaryResult']['DocumentSummarySet']['DocumentSummary'][:3]  # get the first three studies
# Out:
# [{'@uid': '200199161',
#   'Accession': 'GSE199161',
#   'GDS': None,
#   'title': 'Modulation of RNA splicing enhances response to BCL2 inhibition in leukemia',
#   'summary': 'This SuperSeries is composed of the SubSeries listed below.',
#   'GPL': '11154;24676',
#   'GSE': '199161',
#   'taxon': 'Homo sapiens',
#   'entryType': 'GSE',
#   'gdsType': 'Expression profiling by high throughput sequencing; Other',
#   'ptechType': None,
#   'valType': None,
#   'SSInfo': None,
#   'subsetInfo': None,
#   'PDAT': '2022/10/31',
#   'suppFile': 'BW',
#   'Samples': {'Sample': [{'Accession': 'GSM5965526',
#      'Title': 'eCLIP_MOLM13_RBM10_Replicate_3'},
#     {'Accession': 'GSM5965512', 'Title': 'RNAseq_MOLM13_sgRBM10-1_Venetoclax'},
#     {'Accession': 'GSM5965498',
#      'Title': 'RNAseq_MOLM13_SM09419+Venetoclax_Replicate_2'},
#     {'Accession': 'GSM5965515',
#      'Title': 'RNAseq_MOLM13_sgROSA_Venetoclax_Replicate_1'},
#     {'Accession': 'GSM5965518', 'Title': 'eCLIP_MOLM13_Rabbit_IgG_INPUT'},
#     {'Accession': 'GSM5965495', 'Title': 'RNAseq_MOLM13_SM09419_Replicate_2'},
#     {'Accession': 'GSM5965507', 'Title': 'RNAseq_MOLM13_sgRBM10-2_DMSO'},
#     {'Accession': 'GSM5965524', 'Title': 'eCLIP_MOLM13_RBM10_Replicate_1'},
#     {'Accession': 'GSM5965527', 'Title': 'eCLIP_MOLM13_RBM10_Replicate_4'},
#     {'Accession': 'GSM5965501', 'Title': 'RNAseq_MOLM13_Vehicle_Replicate_2'},
#     {'Accession': 'GSM5965521', 'Title': 'eCLIP_MOLM13_INPUT_Replicate_2'},
#     {'Accession': 'GSM5965504',
#      'Title': 'RNAseq_MOLM13_Venetoclax_Replicate_2'},
#     {'Accession': 'GSM5965510',
#      'Title': 'RNAseq_MOLM13_sgROSA_DMSO_Replicate_2'},
#     {'Accession': 'GSM5965513', 'Title': 'RNAseq_MOLM13_sgRBM10-2_Venetoclax'},
#     {'Accession': 'GSM5965499',
#      'Title': 'RNAseq_MOLM13_SM09419+Venetoclax_Replicate_3'},
#     {'Accession': 'GSM5965502', 'Title': 'RNAseq_MOLM13_Vehicle_Replicate_3'},
#     {'Accession': 'GSM5965496', 'Title': 'RNAseq_MOLM13_SM09419_Replicate_3'},
#     {'Accession': 'GSM5965525', 'Title': 'eCLIP_MOLM13_RBM10_Replicate_2'},
#     {'Accession': 'GSM5965508', 'Title': 'RNAseq_MOLM13_sgRBM10-3_DMSO'},
#     {'Accession': 'GSM5965497',
#      'Title': 'RNAseq_MOLM13_SM09419+Venetoclax_Replicate_1'},
#     {'Accession': 'GSM5965505',
#      'Title': 'RNAseq_MOLM13_Venetoclax_Replicate_3'},
#     {'Accession': 'GSM5965517',
#      'Title': 'RNAseq_MOLM13_sgROSA_Venetoclax_Replicate_3'},
#     {'Accession': 'GSM5965511',
#      'Title': 'RNAseq_MOLM13_sgROSA_DMSO_Replicate_3'},
#     {'Accession': 'GSM5965514', 'Title': 'RNAseq_MOLM13_sgRBM10-3_Venetoclax'},
#     {'Accession': 'GSM5965494', 'Title': 'RNAseq_MOLM13_SM09419_Replicate_1'},
#     {'Accession': 'GSM5965520', 'Title': 'eCLIP_MOLM13_INPUT_Replicate_1'},
#     {'Accession': 'GSM5965523', 'Title': 'eCLIP_MOLM13_INPUT_Replicate_4'},
#     {'Accession': 'GSM5965506', 'Title': 'RNAseq_MOLM13_sgRBM10-1_DMSO'},
#     {'Accession': 'GSM5965509',
#      'Title': 'RNAseq_MOLM13_sgROSA_DMSO_Replicate_1'},
#     {'Accession': 'GSM5965516',
#      'Title': 'RNAseq_MOLM13_sgROSA_Venetoclax_Replicate_2'},
#     {'Accession': 'GSM5965519', 'Title': 'eCLIP_MOLM13_Rabbit_IgG_IP'},
#     {'Accession': 'GSM5965522', 'Title': 'eCLIP_MOLM13_INPUT_Replicate_3'},
#     {'Accession': 'GSM5965500', 'Title': 'RNAseq_MOLM13_Vehicle_Replicate_1'},
#     {'Accession': 'GSM5965503',
#      'Title': 'RNAseq_MOLM13_Venetoclax_Replicate_1'}]},
#   'Relations': None,
#   'ExtRelations': None,
#   'n_samples': '34',
#   'SeriesTitle': None,
#   'PlatformTitle': None,
#   'PlatformTaxa': None,
#   'SamplesTaxa': None,
#   'PubMedIds': None,
#   'Projects': None,
#   'FTPLink': 'ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE199nnn/GSE199161/',
#   'GEO2R': 'yes',
#   'BioProject': 'PRJNA818668'},
#  {'@uid': '200199160',
#   'Accession': 'GSE199160',
#   'GDS': None,
#   'title': 'Modulation of RNA splicing enhances response to BCL2 inhibition in leukemia [eCLIP]',
#   'summary': 'Therapy resistance is a major challenge in the treatment of cancer. Here, we performed CRISPR/Cas9 screens across a broad range of therapies used in acute myeloid leukemia (AML) to identify genomic determinants of drug response. Our screens uncovered a selective dependency on RNA splicing factors whose loss preferentially synergized with the BCL2 inhibitor venetoclax. Loss of the splicing factor RBM10 augmented response to venetoclax in leukemia yet was completely dispensable for normal hematopoiesis. Combined RBM10 and BCL2 inhibition led to mis-splicing and inactivation of the inhibitor of apoptosis XIAP and downregulation of BCL2A1, an anti-apoptotic protein implicated in venetoclax resistance. A novel inhibitor of splicing kinase families CLKs and DYRKs led to intron retention of key splicing factors identified from our screens, synergized with venetoclax, and overcame resistance to BCL2 inhibition. Our findings underscore the central importance of splicing in modulating apoptosis and provide a strategy to improve venetoclax-based treatments.',
#   'GPL': '24676',
#   'GSE': '199160',
#   'taxon': 'Homo sapiens',
#   'entryType': 'GSE',
#   'gdsType': 'Other',
#   'ptechType': None,
#   'valType': None,
#   'SSInfo': None,
#   'subsetInfo': None,
#   'PDAT': '2022/10/31',
#   'suppFile': 'BW',
#   'Samples': {'Sample': [{'Accession': 'GSM5965522',
#      'Title': 'eCLIP_MOLM13_INPUT_Replicate_3'},
#     {'Accession': 'GSM5965525', 'Title': 'eCLIP_MOLM13_RBM10_Replicate_2'},
#     {'Accession': 'GSM5965520', 'Title': 'eCLIP_MOLM13_INPUT_Replicate_1'},
#     {'Accession': 'GSM5965523', 'Title': 'eCLIP_MOLM13_INPUT_Replicate_4'},
#     {'Accession': 'GSM5965526', 'Title': 'eCLIP_MOLM13_RBM10_Replicate_3'},
#     {'Accession': 'GSM5965518', 'Title': 'eCLIP_MOLM13_Rabbit_IgG_INPUT'},
#     {'Accession': 'GSM5965519', 'Title': 'eCLIP_MOLM13_Rabbit_IgG_IP'},
#     {'Accession': 'GSM5965521', 'Title': 'eCLIP_MOLM13_INPUT_Replicate_2'},
#     {'Accession': 'GSM5965524', 'Title': 'eCLIP_MOLM13_RBM10_Replicate_1'},
#     {'Accession': 'GSM5965527', 'Title': 'eCLIP_MOLM13_RBM10_Replicate_4'}]},
#   'Relations': None,
#   'ExtRelations': None,
#   'n_samples': '10',
#   'SeriesTitle': None,
#   'PlatformTitle': None,
#   'PlatformTaxa': None,
#   'SamplesTaxa': None,
#   'PubMedIds': None,
#   'Projects': None,
#   'FTPLink': 'ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE199nnn/GSE199160/',
#   'GEO2R': 'yes',
#   'BioProject': 'PRJNA818672'},
#  {'@uid': '200126263',
#   'Accession': 'GSE126263',
#   'GDS': None,
#   'title': 'Musashi-1 is a master regulator of aberrant translation in Group 3 medulloblastoma',
#   'summary': 'Transcripts bound to Musashi-1 (MSI1) are explored in Group 3 medulloblastoma (G3 MB) and neural stem cells harvested from the cerebellar portion of a embryonal brain',
#   'GPL': '11154',
#   'GSE': '126263',
#   'taxon': 'Homo sapiens',
#   'entryType': 'GSE',
#   'gdsType': 'Expression profiling by high throughput sequencing; Other',
#   'ptechType': None,
#   'valType': None,
#   'SSInfo': None,
#   'subsetInfo': None,
#   'PDAT': '2022/10/28',
#   'suppFile': 'BED, BW, TSV',
#   'Samples': {'Sample': [{'Accession': 'GSM3595520', 'Title': 'MB002 rep1'},
#     {'Accession': 'GSM3595525', 'Title': 'NSC201cb input'},
#     {'Accession': 'GSM3595522', 'Title': 'MB002 input'},
#     {'Accession': 'GSM3595521', 'Title': 'MB002 rep2'},
#     {'Accession': 'GSM3595524', 'Title': 'NSC201cb rep2'},
#     {'Accession': 'GSM3595523', 'Title': 'NSC201cb rep1'}]},
#   'Relations': None,
#   'ExtRelations': {'ExtRelation': {'RelationType': 'SRA',
#     'TargetObject': 'SRP184542',
#     'TargetFTPLink': 'ftp://ftp-trace.ncbi.nlm.nih.gov/sra/sra-instant/reads/ByStudy/sra/SRP/SRP184/SRP184542/'}},
#   'n_samples': '6',
#   'SeriesTitle': None,
#   'PlatformTitle': None,
#   'PlatformTaxa': None,
#   'SamplesTaxa': None,
#   'PubMedIds': None,
#   'Projects': None,
#   'FTPLink': 'ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE126nnn/GSE126263/',
#   'GEO2R': 'yes',
#   'BioProject': 'PRJNA521417'}]

# %% [markdown]
# # Return species name from an accession ID:

# %%
term = "AP025035.1"
esearch_string = esearch(term=term, db='nucleotide')
result = get_esummary(esearch_string=esearch_string, db='nucleotide')
result = xmltodict.parse(result)
result['eSummaryResult']['DocumentSummarySet']['DocumentSummary']['Title']
# Out:
# 'Citrobacter freundii RTE-E5 DNA, complete genome: sequence1'

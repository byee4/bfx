# %%
import pandas as pd
import gffutils
import os
from collections import defaultdict

# %%
db_file = '/projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf.db'
DATABASE = gffutils.FeatureDB(db_file)
# Out:
# /home/bay001/anaconda2/envs/brian/lib/python2.7/site-packages/gffutils/interface.py:161: UserWarning: It appears that this database has not had the ANALYZE sqlite3 command run on it. Doing so can dramatically speed up queries, and is done by default for databases created with gffutils >0.8.7.1 (this database was created with version 0.8.1) Consider calling the analyze() method of this object.
#   "method of this object." % self.version)

# %%
# wd = '/projects/ps-yeolab3/iachaim/Cleber_Organoids/6_months/' # working directory
wd = '/projects/ps-yeolab3/bay001/Cleber_Organoids_tempdir/'

# %% [markdown]
# # Build a gene id to name dictionary
# - {EnsemblID:name}

# %%
def gene_id_to_name(db):
    '''
    Returns a dictionary containing a gene_id:name translation
    Note: may be different if the 'gene_id' or 'gene_name' 
    keys are not in the source GTF file
    (taken from gscripts.region_helpers)
    '''
    genes = db.features_of_type('gene')
    gene_name_dict = {}
    for gene in genes:
        gene_id = gene.attributes['gene_id'][0] if type(gene.attributes['gene_id']) == list else gene.attributes['gene_id']
        try:
            ensembl_id = gene_id.split('.')[0] # gencode and ensembl differ in that gencode includes annotation version 
            gene_name_dict[ensembl_id] = gene.attributes['gene_name'][0] # returns the first gene name found per id (no aliases), also ensures only one gene name is returned per id
        except KeyError:
            print(gene.attributes.keys())
            print("Warning. Key not found for {}".format(gene))
            return 1
    return gene_name_dict

# create the dictionary
gene_id_to_name_dictionary = gene_id_to_name(DATABASE)

# let's test it out
gene_id_to_name_dictionary['ENSG00000100320']
# Out:
# 'RBFOX2'

# %%
# read in table
fn = 'H09_expression.csv' # filename (fn)

csv = pd.read_table(
    os.path.join(wd, fn),
    sep=',',
    index_col=0
)
print("original matrix sizes (row, column)", csv.shape)
csv.head()
# Out:
# ('original matrix sizes (row, column)', (32738, 1739))
#                  AAACCTGAGATCTGAA-1  AAACCTGCATCCTTGC-1  AAACCTGGTCAGAGGT-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                  AAACGGGCAATGTTGC-1  AAACGGGCAGTTCATG-1  AAACGGGGTGTGGTTT-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                  AAACGGGGTTAAGAAC-1  AAACGGGTCAGTCCCT-1  AAAGATGAGCGCTCCA-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                  AAAGATGGTTACCAGT-1         ...          TTTGCGCTCAGGCAAG-1  \
# ENSG00000243485                   0         ...                           0
# ENSG00000237613                   0         ...                           0
# ENSG00000186092                   0         ...                           0
# ENSG00000238009                   0         ...                           0
# ENSG00000239945                   0         ...                           0
#
#                  TTTGGTTAGGACAGAA-1  TTTGGTTTCAGGTAAA-1  TTTGGTTTCTCGTATT-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                  TTTGTCAAGACCTAGG-1  TTTGTCACACAACGCC-1  TTTGTCACAGCCTTGG-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                  TTTGTCAGTATGAATG-1  TTTGTCAGTCTTTCAT-1  TTTGTCAGTTCGAATC-1
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
# [5 rows x 1739 columns]

# %% [markdown]
# # Convert gene ids

# %%
def geneid2name(row, d=gene_id_to_name_dictionary):
    try:
        return '{}_{}'.format(row.name, d[row.name])
    except KeyError:
        return '{}_{}'.format(row.name, 'NA')

csv['gene_name'] = csv.apply(geneid2name, axis=1)
csv.head()
# Out:
#                  AAACCTGAGATCTGAA-1  AAACCTGCATCCTTGC-1  AAACCTGGTCAGAGGT-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                  AAACGGGCAATGTTGC-1  AAACGGGCAGTTCATG-1  AAACGGGGTGTGGTTT-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                  AAACGGGGTTAAGAAC-1  AAACGGGTCAGTCCCT-1  AAAGATGAGCGCTCCA-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                  AAAGATGGTTACCAGT-1              ...               \
# ENSG00000243485                   0              ...
# ENSG00000237613                   0              ...
# ENSG00000186092                   0              ...
# ENSG00000238009                   0              ...
# ENSG00000239945                   0              ...
#
#                  TTTGGTTAGGACAGAA-1  TTTGGTTTCAGGTAAA-1  TTTGGTTTCTCGTATT-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                  TTTGTCAAGACCTAGG-1  TTTGTCACACAACGCC-1  TTTGTCACAGCCTTGG-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                  TTTGTCAGTATGAATG-1  TTTGTCAGTCTTTCAT-1  TTTGTCAGTTCGAATC-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
#                                     gene_name
# ENSG00000243485    ENSG00000243485_MIR1302-11
# ENSG00000237613       ENSG00000237613_FAM138A
# ENSG00000186092         ENSG00000186092_OR4F5
# ENSG00000238009  ENSG00000238009_RP11-34P13.7
# ENSG00000239945  ENSG00000239945_RP11-34P13.8
#
# [5 rows x 1740 columns]

# %%
# remove ensembl IDs and replace with gene names
csv.set_index('gene_name', inplace=True) # setting index also functionally sends the column to the left, there are other ways to do it
csv.head()
# Out:
#                               AAACCTGAGATCTGAA-1  AAACCTGCATCCTTGC-1  \
# gene_name
# ENSG00000243485_MIR1302-11                     0                   0
# ENSG00000237613_FAM138A                        0                   0
# ENSG00000186092_OR4F5                          0                   0
# ENSG00000238009_RP11-34P13.7                   0                   0
# ENSG00000239945_RP11-34P13.8                   0                   0
#
#                               AAACCTGGTCAGAGGT-1  AAACGGGCAATGTTGC-1  \
# gene_name
# ENSG00000243485_MIR1302-11                     0                   0
# ENSG00000237613_FAM138A                        0                   0
# ENSG00000186092_OR4F5                          0                   0
# ENSG00000238009_RP11-34P13.7                   0                   0
# ENSG00000239945_RP11-34P13.8                   0                   0
#
#                               AAACGGGCAGTTCATG-1  AAACGGGGTGTGGTTT-1  \
# gene_name
# ENSG00000243485_MIR1302-11                     0                   0
# ENSG00000237613_FAM138A                        0                   0
# ENSG00000186092_OR4F5                          0                   0
# ENSG00000238009_RP11-34P13.7                   0                   0
# ENSG00000239945_RP11-34P13.8                   0                   0
#
#                               AAACGGGGTTAAGAAC-1  AAACGGGTCAGTCCCT-1  \
# gene_name
# ENSG00000243485_MIR1302-11                     0                   0
# ENSG00000237613_FAM138A                        0                   0
# ENSG00000186092_OR4F5                          0                   0
# ENSG00000238009_RP11-34P13.7                   0                   0
# ENSG00000239945_RP11-34P13.8                   0                   0
#
#                               AAAGATGAGCGCTCCA-1  AAAGATGGTTACCAGT-1  \
# gene_name
# ENSG00000243485_MIR1302-11                     0                   0
# ENSG00000237613_FAM138A                        0                   0
# ENSG00000186092_OR4F5                          0                   0
# ENSG00000238009_RP11-34P13.7                   0                   0
# ENSG00000239945_RP11-34P13.8                   0                   0
#
#                                      ...          TTTGCGCTCAGGCAAG-1  \
# gene_name                            ...
# ENSG00000243485_MIR1302-11           ...                           0
# ENSG00000237613_FAM138A              ...                           0
# ENSG00000186092_OR4F5                ...                           0
# ENSG00000238009_RP11-34P13.7         ...                           0
# ENSG00000239945_RP11-34P13.8         ...                           0
#
#                               TTTGGTTAGGACAGAA-1  TTTGGTTTCAGGTAAA-1  \
# gene_name
# ENSG00000243485_MIR1302-11                     0                   0
# ENSG00000237613_FAM138A                        0                   0
# ENSG00000186092_OR4F5                          0                   0
# ENSG00000238009_RP11-34P13.7                   0                   0
# ENSG00000239945_RP11-34P13.8                   0                   0
#
#                               TTTGGTTTCTCGTATT-1  TTTGTCAAGACCTAGG-1  \
# gene_name
# ENSG00000243485_MIR1302-11                     0                   0
# ENSG00000237613_FAM138A                        0                   0
# ENSG00000186092_OR4F5                          0                   0
# ENSG00000238009_RP11-34P13.7                   0                   0
# ENSG00000239945_RP11-34P13.8                   0                   0
#
#                               TTTGTCACACAACGCC-1  TTTGTCACAGCCTTGG-1  \
# gene_name
# ENSG00000243485_MIR1302-11                     0                   0
# ENSG00000237613_FAM138A                        0                   0
# ENSG00000186092_OR4F5                          0                   0
# ENSG00000238009_RP11-34P13.7                   0                   0
# ENSG00000239945_RP11-34P13.8                   0                   0
#
#                               TTTGTCAGTATGAATG-1  TTTGTCAGTCTTTCAT-1  \
# gene_name
# ENSG00000243485_MIR1302-11                     0                   0
# ENSG00000237613_FAM138A                        0                   0
# ENSG00000186092_OR4F5                          0                   0
# ENSG00000238009_RP11-34P13.7                   0                   0
# ENSG00000239945_RP11-34P13.8                   0                   0
#
#                               TTTGTCAGTTCGAATC-1
# gene_name
# ENSG00000243485_MIR1302-11                     0
# ENSG00000237613_FAM138A                        0
# ENSG00000186092_OR4F5                          0
# ENSG00000238009_RP11-34P13.7                   0
# ENSG00000239945_RP11-34P13.8                   0
#
# [5 rows x 1739 columns]

# %%
print("new matrix sizes (row, column)", csv.shape) # double check that the number of rows is unchanged (may change if there are duplicates)
# Out:
# ('new matrix sizes (row, column)', (32738, 1739))

# %%
csv.to_csv(
    os.path.join(wd, fn + '.genename.csv'), # add a '.genename.txt' suffix to the original file
    sep=','
)

# %%
# check for duplicate indices
csv[csv.index.duplicated()].head()
# Out:
# Empty DataFrame
# Columns: [AAACCTGAGATCTGAA-1, AAACCTGCATCCTTGC-1, AAACCTGGTCAGAGGT-1, AAACGGGCAATGTTGC-1, AAACGGGCAGTTCATG-1, AAACGGGGTGTGGTTT-1, AAACGGGGTTAAGAAC-1, AAACGGGTCAGTCCCT-1, AAAGATGAGCGCTCCA-1, AAAGATGGTTACCAGT-1, AAAGCAACATCACGTA-1, AAAGCAAGTCCCTACT-1, AAAGTAGCAATGGACG-1, AAAGTAGCATCTATGG-1, AAAGTAGGTTGCTCCT-1, AAATGCCCATTTCACT-1, AAATGCCGTAAGGGAA-1, AAATGCCGTGATGTCT-1, AAATGCCGTGCACTTA-1, AAATGCCTCTATGTGG-1, AACACGTAGAAACCAT-1, AACACGTAGCTAACAA-1, AACACGTAGTCTCAAC-1, AACACGTCACATGACT-1, AACACGTTCCGCGCAA-1, AACACGTTCTGTCTCG-1, AACCATGAGGACATTA-1, AACCATGCACGTCAGC-1, AACCATGCAGCTGGCT-1, AACCATGGTCTAGAGG-1, AACCATGGTGGAAAGA-1, AACCGCGAGAAGAAGC-1, AACCGCGAGTGGAGAA-1, AACCGCGCATTACGAC-1, AACGTTGAGCCAGAAC-1, AACGTTGAGGTGACCA-1, AACGTTGCATCCCACT-1, AACGTTGTCACCCGAG-1, AACTCAGCACATAACC-1, AACTCAGCACCTTGTC-1, AACTCAGTCTTCCTTC-1, AACTCCCAGATGGCGT-1, AACTCCCGTAGGAGTC-1, AACTCTTAGACGCTTT-1, AACTCTTCAATAGCGG-1, AACTCTTGTGAGCGAT-1, AACTCTTGTTCGAATC-1, AACTGGTGTTCAGGCC-1, AACTTTCAGAGGTTAT-1, AACTTTCAGCGTAATA-1, AACTTTCAGTGAATTG-1, AACTTTCCAAAGGTGC-1, AACTTTCCAGGGTTAG-1, AACTTTCGTCTGGTCG-1, AAGACCTCACCAACCG-1, AAGACCTGTCGCGTGT-1, AAGCCGCAGATCCCGC-1, AAGCCGCAGGATTCGG-1, AAGCCGCCACCATCCT-1, AAGCCGCTCAGAGGTG-1, AAGCCGCTCTTGTATC-1, AAGGAGCAGAATGTTG-1, AAGGAGCAGTCGTACT-1, AAGGAGCGTCAATACC-1, AAGGAGCGTTAAGAAC-1, AAGGCAGAGAGGACGG-1, AAGGCAGAGATGAGAG-1, AAGGCAGAGCAACGGT-1, AAGGCAGCATATACCG-1, AAGGCAGGTCTTCGTC-1, AAGGCAGGTGACTACT-1, AAGGCAGTCGTGGTCG-1, AAGGTTCAGCGTTCCG-1, AAGGTTCCACTTCGAA-1, AAGGTTCCAGTTTACG-1, AAGGTTCCATGGATGG-1, AAGGTTCGTCTCAACA-1, AAGGTTCTCGACCAGC-1, AAGTCTGGTTCCCTTG-1, AATCCAGAGGAATCGC-1, AATCCAGAGTGTGGCA-1, AATCCAGCAGCTGGCT-1, AATCCAGTCAACGAAA-1, AATCCAGTCAGTCAGT-1, AATCCAGTCCACTGGG-1, AATCGGTAGCATGGCA-1, AATCGGTAGGGAGTAA-1, AATCGGTCAGGAATGC-1, AATCGGTTCTCAACTT-1, ACACCAAAGAGCTATA-1, ACACCAACAGGACGTA-1, ACACCAATCCAATGGT-1, ACACCCTAGGAACTGC-1, ACACCCTCAGACAGGT-1, ACACCCTCATCACGTA-1, ACACCCTGTAAACCTC-1, ACACCCTGTTCGTCTC-1, ACACCGGAGGTCATCT-1, ACACCGGCAAGCCGCT-1, ACACCGGTCAGTTAGC-1, ...]
# Index: []
#
# [0 rows x 1739 columns]

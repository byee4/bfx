# %% [markdown]
# # From the fasta and clustered fasta gene sequences, return a list of genes that are interesting to the study.

# %%
import pandas as pd
import numpy as np
import os
import glob
from Bio import SeqIO

# %%
wd = '/home/bay001/projects/kes_20160307/org/03_output/assembly/gene_sequences'
all_genes = glob.glob(os.path.join(wd,'*.clustered.fasta'))

# %%
genelist = []
for gene in all_genes:
    genelist.append(os.path.basename(gene).replace('.clustered.fasta',''))

# %%
df = pd.DataFrame(genelist)
df.columns = ['Gene ID']
ensembl2gene = pd.read_table('/home/bay001/projects/kes_20160307/org/00_data/references/biomart/galgal4_biomart.txt').fillna('NONAME')

merged = pd.merge(df,ensembl2gene,how='left',on=['Gene ID'])
merged.to_csv('/home/bay001/projects/kes_20160307/data/ensembl-genename-description.tsv',sep='\t',index=None)
merged
# Out:
#                   Gene ID                                        Description  \
# 0      ENSGALG00000012304  Gallus gallus nuclear factor of kappa light po...
# 1      ENSGALG00000027245  glyoxalase domain containing 4 [Source:HGNC Sy...
# 2      ENSGALG00000025732  Uncharacterized protein  [Source:UniProtKB/TrE...
# 3      ENSGALG00000027762  post-GPI attachment to proteins 2 [Source:HGNC...
# 4      ENSGALG00000028148  PHD finger protein 13 [Source:HGNC Symbol;Acc:...
# 5      ENSGALG00000012623  Gallus gallus cripto, FRL-1, cryptic family 1B...
# 6      ENSGALG00000023842  Uncharacterized protein  [Source:UniProtKB/TrE...
# 7      ENSGALG00000009039  neural proliferation, differentiation and cont...
# 8      ENSGALG00000006613  Gallus gallus cathepsin D (CTSD), mRNA. [Sourc...
# 9      ENSGALG00000004643  Gallus gallus protein-L-isoaspartate (D-aspart...
# 10     ENSGALG00000014953  Gallus gallus RWD domain containing 1 (RWDD1),...
# 11     ENSGALG00000002394  Gallus gallus RGP1 retrograde golgi transport ...
# 12     ENSGALG00000006334  Gallus gallus leucine aminopeptidase 3 (LAP3),...
# 13     ENSGALG00000004364     active BCR-related [Source:HGNC Symbol;Acc:81]
# 14     ENSGALG00000006131  Gallus gallus formiminotransferase cyclodeamin...
# 15     ENSGALG00000004161  Gallus gallus cyclin B2 (CCNB2), mRNA. [Source...
# 16     ENSGALG00000004446  neuropeptide FF receptor 1  [Source:RefSeq pep...
# 17     ENSGALG00000016148  C2 calcium-dependent domain containing 2 [Sour...
# 18     ENSGALG00000028683  Gallus gallus signal sequence receptor, gamma ...
# 19     ENSGALG00000014118  Gallus gallus mitochondrial ribosomal protein ...
# 20     ENSGALG00000028903  Uncharacterized protein  [Source:UniProtKB/TrE...
# 21     ENSGALG00000012426  DDHD domain containing 1 [Source:HGNC Symbol;A...
# 22     ENSGALG00000010476  BCL2/adenovirus E1B 19kDa interacting protein ...
# 23     ENSGALG00000016486  HCLS1 binding protein 3 [Source:HGNC Symbol;Ac...
# 24     ENSGALG00000012101  adaptor-related protein complex 5, mu 1 subuni...
# 25     ENSGALG00000010151  Gallus gallus coiled-coil domain containing 16...
# 26     ENSGALG00000016065  bromodomain and WD repeat domain containing 1 ...
# 27     ENSGALG00000027184  olfactomedin-like 1 [Source:HGNC Symbol;Acc:24...
# 28     ENSGALG00000021174  ALG9, alpha-1,2-mannosyltransferase [Source:HG...
# 29     ENSGALG00000014512  Gallus gallus COP9 constitutive photomorphogen...
# ...                   ...                                                ...
# 12726  ENSGALG00000004297  dynein, axonemal, heavy chain 1 [Source:HGNC S...
# 12727  ENSGALG00000002267  DCN1, defective in cullin neddylation 1, domai...
# 12728  ENSGALG00000004353  Gallus gallus tubulin folding cofactor A (TBCA...
# 12729  ENSGALG00000006303  cytosolic thiouridylase subunit 2 homolog (S. ...
# 12730  ENSGALG00000012994  ELKS/RAB6-interacting/CAST family member 1 [So...
# 12731  ENSGALG00000014964  5'-nucleotidase domain containing 1 [Source:HG...
# 12732  ENSGALG00000016934    protocadherin 20 [Source:HGNC Symbol;Acc:14257]
# 12733  ENSGALG00000019077  Uncharacterized protein  [Source:UniProtKB/TrE...
# 12734  ENSGALG00000000954  sphingomyelin phosphodiesterase 2, neutral mem...
# 12735  ENSGALG00000002904  Gallus gallus receptor accessory protein 3 (RE...
# 12736  ENSGALG00000027272  Gallus gallus adenine phosphoribosyltransferas...
# 12737  ENSGALG00000028458  chromosome 19 open reading frame 25 [Source:HG...
# 12738  ENSGALG00000010363  Gallus gallus hect domain and RLD 3 (HERC3), m...
# 12739  ENSGALG00000012333  chromosome 7 open reading frame 25 [Source:HGN...
# 12740  ENSGALG00000028934  oxysterol binding protein-like 7 [Source:HGNC ...
# 12741  ENSGALG00000000438  endoplasmic reticulum metallopeptidase 1 [Sour...
# 12742  ENSGALG00000004498  solute carrier family 2 (facilitated glucose t...
# 12743  ENSGALG00000010166  Uncharacterized protein  [Source:UniProtKB/TrE...
# 12744  ENSGALG00000012136  Gallus gallus metallophosphoesterase domain co...
# 12745  ENSGALG00000016196  cystathionine-beta-synthase [Source:HGNC Symbo...
# 12746  ENSGALG00000021087  Uncharacterized protein  [Source:UniProtKB/TrE...
# 12747  ENSGALG00000027550  Gallus gallus regulator of G-protein signaling...
# 12748  ENSGALG00000010441  Gallus gallus glycogenin 1 (GYG1), mRNA. [Sour...
# 12749  ENSGALG00000004471  adaptor-related protein complex 5, zeta 1 subu...
# 12750  ENSGALG00000006421  solute carrier family 16, member 12 [Source:HG...
# 12751  ENSGALG00000004156  Gallus gallus KIAA1279 (KIAA1279), nuclear gen...
# 12752  ENSGALG00000006106  tumor necrosis factor receptor superfamily, me...
# 12753  ENSGALG00000014408  lethal giant larvae homolog 1 (Drosophila) [So...
# 12754  ENSGALG00000009845  Gallus gallus gap junction protein, delta 2, 3...
# 12755  ENSGALG00000019755  Gallus gallus CD300 antigen-like family member...
#
#       Associated Gene Name
# 0                    NFKB1
# 1                    GLOD4
# 2                   NONAME
# 3                    PGAP2
# 4                    PHF13
# 5                     CFC1
# 6                   NONAME
# 7                    NPDC1
# 8                     CTSD
# 9                   NONAME
# 10                   RWDD1
# 11                    RGP1
# 12                    LAP3
# 13                     ABR
# 14                    FTCD
# 15                   CCNB2
# 16                   NPFF1
# 17                   C2CD2
# 18                    SSR3
# 19                  MRPS26
# 20                  NONAME
# 21                   DDHD1
# 22                   BNIP3
# 23                  HS1BP3
# 24                   AP5M1
# 25                 CCDC167
# 26                   BRWD1
# 27                  OLFML1
# 28                    ALG9
# 29                   COPS5
# ...                    ...
# 12726                DNAH1
# 12727              DCUN1D3
# 12728                 TBCA
# 12729                 CTU2
# 12730                 ERC1
# 12731               NT5DC1
# 12732               PCDH20
# 12733               NONAME
# 12734                SMPD2
# 12735                REEP3
# 12736                 APRT
# 12737             C19orf25
# 12738                HERC3
# 12739              C7orf25
# 12740               OSBPL7
# 12741                ERMP1
# 12742              SLC2A10
# 12743                 VLDL
# 12744               MPPED2
# 12745                  CBS
# 12746               NONAME
# 12747                RGS16
# 12748                 GYG1
# 12749                AP5Z1
# 12750             SLC16A12
# 12751                  KBP
# 12752             TNFRSF6B
# 12753                LLGL1
# 12754                 GJD2
# 12755            CD300L-S1
#
# [12756 rows x 3 columns]

# %% [markdown]
# # Look at the genes of interest
# - Deiodinase 1 and 2,
# - thyroid stimulating hormone (TSH), (TSHB, TSHZ2, TSHZ1, TSHZ3,
# - EEF1A1,
# - ALB (Albumin),
# - HPRT1,
# - TATA-Box Binding Protein (TBP),
# - YWHAZ,
# - PPIA

# %%
goi = ['ENSGALG00000010736','ENSGALG00000026005','ENSGALG00000002550','ENSGALG00000007809',
       'ENSGALG00000013672','ENSGALG00000004528','ENSGALG00000015917','ENSGALG00000020180',
      'ENSGALG00000006098','ENSGALG00000011171','ENSGALG00000010725','ENSGALG00000028600']
goi = pd.DataFrame(goi)
goi.columns = ['Gene ID']
merged2 = pd.merge(goi,merged,how='left',on='Gene ID')
merged2.to_csv('/home/bay001/projects/kes_20160307/data/ensembl-genename-description-goi.tsv',sep='\t',index=None)

# %%
merged
# Out:
#                   Gene ID                                        Description  \
# 0      ENSGALG00000012304  Gallus gallus nuclear factor of kappa light po...
# 1      ENSGALG00000027245  glyoxalase domain containing 4 [Source:HGNC Sy...
# 2      ENSGALG00000025732  Uncharacterized protein  [Source:UniProtKB/TrE...
# 3      ENSGALG00000027762  post-GPI attachment to proteins 2 [Source:HGNC...
# 4      ENSGALG00000028148  PHD finger protein 13 [Source:HGNC Symbol;Acc:...
# 5      ENSGALG00000012623  Gallus gallus cripto, FRL-1, cryptic family 1B...
# 6      ENSGALG00000023842  Uncharacterized protein  [Source:UniProtKB/TrE...
# 7      ENSGALG00000009039  neural proliferation, differentiation and cont...
# 8      ENSGALG00000006613  Gallus gallus cathepsin D (CTSD), mRNA. [Sourc...
# 9      ENSGALG00000004643  Gallus gallus protein-L-isoaspartate (D-aspart...
# 10     ENSGALG00000014953  Gallus gallus RWD domain containing 1 (RWDD1),...
# 11     ENSGALG00000002394  Gallus gallus RGP1 retrograde golgi transport ...
# 12     ENSGALG00000006334  Gallus gallus leucine aminopeptidase 3 (LAP3),...
# 13     ENSGALG00000004364     active BCR-related [Source:HGNC Symbol;Acc:81]
# 14     ENSGALG00000006131  Gallus gallus formiminotransferase cyclodeamin...
# 15     ENSGALG00000004161  Gallus gallus cyclin B2 (CCNB2), mRNA. [Source...
# 16     ENSGALG00000004446  neuropeptide FF receptor 1  [Source:RefSeq pep...
# 17     ENSGALG00000016148  C2 calcium-dependent domain containing 2 [Sour...
# 18     ENSGALG00000028683  Gallus gallus signal sequence receptor, gamma ...
# 19     ENSGALG00000014118  Gallus gallus mitochondrial ribosomal protein ...
# 20     ENSGALG00000028903  Uncharacterized protein  [Source:UniProtKB/TrE...
# 21     ENSGALG00000012426  DDHD domain containing 1 [Source:HGNC Symbol;A...
# 22     ENSGALG00000010476  BCL2/adenovirus E1B 19kDa interacting protein ...
# 23     ENSGALG00000016486  HCLS1 binding protein 3 [Source:HGNC Symbol;Ac...
# 24     ENSGALG00000012101  adaptor-related protein complex 5, mu 1 subuni...
# 25     ENSGALG00000010151  Gallus gallus coiled-coil domain containing 16...
# 26     ENSGALG00000016065  bromodomain and WD repeat domain containing 1 ...
# 27     ENSGALG00000027184  olfactomedin-like 1 [Source:HGNC Symbol;Acc:24...
# 28     ENSGALG00000021174  ALG9, alpha-1,2-mannosyltransferase [Source:HG...
# 29     ENSGALG00000014512  Gallus gallus COP9 constitutive photomorphogen...
# ...                   ...                                                ...
# 12726  ENSGALG00000004297  dynein, axonemal, heavy chain 1 [Source:HGNC S...
# 12727  ENSGALG00000002267  DCN1, defective in cullin neddylation 1, domai...
# 12728  ENSGALG00000004353  Gallus gallus tubulin folding cofactor A (TBCA...
# 12729  ENSGALG00000006303  cytosolic thiouridylase subunit 2 homolog (S. ...
# 12730  ENSGALG00000012994  ELKS/RAB6-interacting/CAST family member 1 [So...
# 12731  ENSGALG00000014964  5'-nucleotidase domain containing 1 [Source:HG...
# 12732  ENSGALG00000016934    protocadherin 20 [Source:HGNC Symbol;Acc:14257]
# 12733  ENSGALG00000019077  Uncharacterized protein  [Source:UniProtKB/TrE...
# 12734  ENSGALG00000000954  sphingomyelin phosphodiesterase 2, neutral mem...
# 12735  ENSGALG00000002904  Gallus gallus receptor accessory protein 3 (RE...
# 12736  ENSGALG00000027272  Gallus gallus adenine phosphoribosyltransferas...
# 12737  ENSGALG00000028458  chromosome 19 open reading frame 25 [Source:HG...
# 12738  ENSGALG00000010363  Gallus gallus hect domain and RLD 3 (HERC3), m...
# 12739  ENSGALG00000012333  chromosome 7 open reading frame 25 [Source:HGN...
# 12740  ENSGALG00000028934  oxysterol binding protein-like 7 [Source:HGNC ...
# 12741  ENSGALG00000000438  endoplasmic reticulum metallopeptidase 1 [Sour...
# 12742  ENSGALG00000004498  solute carrier family 2 (facilitated glucose t...
# 12743  ENSGALG00000010166  Uncharacterized protein  [Source:UniProtKB/TrE...
# 12744  ENSGALG00000012136  Gallus gallus metallophosphoesterase domain co...
# 12745  ENSGALG00000016196  cystathionine-beta-synthase [Source:HGNC Symbo...
# 12746  ENSGALG00000021087  Uncharacterized protein  [Source:UniProtKB/TrE...
# 12747  ENSGALG00000027550  Gallus gallus regulator of G-protein signaling...
# 12748  ENSGALG00000010441  Gallus gallus glycogenin 1 (GYG1), mRNA. [Sour...
# 12749  ENSGALG00000004471  adaptor-related protein complex 5, zeta 1 subu...
# 12750  ENSGALG00000006421  solute carrier family 16, member 12 [Source:HG...
# 12751  ENSGALG00000004156  Gallus gallus KIAA1279 (KIAA1279), nuclear gen...
# 12752  ENSGALG00000006106  tumor necrosis factor receptor superfamily, me...
# 12753  ENSGALG00000014408  lethal giant larvae homolog 1 (Drosophila) [So...
# 12754  ENSGALG00000009845  Gallus gallus gap junction protein, delta 2, 3...
# 12755  ENSGALG00000019755  Gallus gallus CD300 antigen-like family member...
#
#       Associated Gene Name
# 0                    NFKB1
# 1                    GLOD4
# 2                   NONAME
# 3                    PGAP2
# 4                    PHF13
# 5                     CFC1
# 6                   NONAME
# 7                    NPDC1
# 8                     CTSD
# 9                   NONAME
# 10                   RWDD1
# 11                    RGP1
# 12                    LAP3
# 13                     ABR
# 14                    FTCD
# 15                   CCNB2
# 16                   NPFF1
# 17                   C2CD2
# 18                    SSR3
# 19                  MRPS26
# 20                  NONAME
# 21                   DDHD1
# 22                   BNIP3
# 23                  HS1BP3
# 24                   AP5M1
# 25                 CCDC167
# 26                   BRWD1
# 27                  OLFML1
# 28                    ALG9
# 29                   COPS5
# ...                    ...
# 12726                DNAH1
# 12727              DCUN1D3
# 12728                 TBCA
# 12729                 CTU2
# 12730                 ERC1
# 12731               NT5DC1
# 12732               PCDH20
# 12733               NONAME
# 12734                SMPD2
# 12735                REEP3
# 12736                 APRT
# 12737             C19orf25
# 12738                HERC3
# 12739              C7orf25
# 12740               OSBPL7
# 12741                ERMP1
# 12742              SLC2A10
# 12743                 VLDL
# 12744               MPPED2
# 12745                  CBS
# 12746               NONAME
# 12747                RGS16
# 12748                 GYG1
# 12749                AP5Z1
# 12750             SLC16A12
# 12751                  KBP
# 12752             TNFRSF6B
# 12753                LLGL1
# 12754                 GJD2
# 12755            CD300L-S1
#
# [12756 rows x 3 columns]

# %%
def get_seq(df):
    records = {}
    i = 0
    for gene in all_genes:
        ensg = os.path.basename(gene).replace('.clustered.fasta','')
        if ensg in list(df['Gene ID']):
            gene_name = df[(df['Gene ID'].str.contains(ensg))]['Associated Gene Name'].to_string(index=False)
            handle = open(gene, "rU")
            for record in SeqIO.parse(handle,"fasta"):
                records[i] = (ensg, gene_name, record.id)
                i = i + 1
    df = pd.DataFrame(records).T
    df.columns = ['ensembl','name','contig_name']
    return df

# %%
get_seq(merged).to_csv('/home/bay001/projects/kes_20160307/org/03_output/csvs/contig_and_gene_name.txt',sep='\t',index=None)

# %%
! head /home/bay001/projects/kes_20160307/org/03_output/csvs/contig_and_gene_name.txt
# Out:
# ensembl	name	contig_name
# ENSGALG00000012304	NFKB1	unmapped-49-contig_list_contig_33037-0
# ENSGALG00000012304	NFKB1	EC-4AK111_TAGCTT_R1_(paired)_contig_2427-0
# ENSGALG00000012304	NFKB1	unmapped-49-contig_list_contig_117584-0
# ENSGALG00000012304	NFKB1	unmapped-49-contig_list_contig_288882-0
# ENSGALG00000012304	NFKB1	unmapped-49-contig_list_contig_35316-0
# ENSGALG00000027245	GLOD4	unmapped-49-contig_list_contig_44777-0
# ENSGALG00000027245	GLOD4	EC-4AK111_TAGCTT_R1_(paired)_contig_2228-0
# ENSGALG00000027245	GLOD4	unmapped-49-contig_list_contig_82939-0
# ENSGALG00000025732	NONAME	unmapped-49-contig_list_contig_87832-0

# %%
all_genes[:5]

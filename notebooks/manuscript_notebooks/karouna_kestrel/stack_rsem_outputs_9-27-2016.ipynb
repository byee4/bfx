# %% [markdown]
# # Create a 'abundance matrix' file from each RSEM result.
# - functionally equivalent to the raw counts file and can be used as input to DESeq2 (must convert to INTEGERS first)

# %%
import pandas as pd
import numpy as np
import os

# %%
results = ! ls /home/bay001/projects/kes_20160307/data/RSEM/*.genes.results

# %%
results = results[9:]+results[:9]
results
# Out:
# ['/home/bay001/projects/kes_20160307/data/RSEM/EC-1AK228_CAGATC.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-2AK546_ACTTGA.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-3AK436_GATCAG.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-4AK111_TAGCTT.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-5AK453_GGCTAC.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-6AK100_CTTGTA.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-7AK501_AGTCAA.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-8AK511_AGTTCC.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-9AK123_ATGTCA.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-10AK244_CCGTCC.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-11AK330_GTCCGC.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-12AK422_GTGAAA.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-13AK430_GTGGCC.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-14AK418_GTTTCG.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-15AK219_CGTACG.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-16AK327_GAGTGG.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-17AK506_ACTGAT.genes.results',
#  '/home/bay001/projects/kes_20160307/data/RSEM/EC-18AK105_ATTCCT.genes.results']

# %%
MASTER = pd.read_table(results[0],index_col=0)
master = pd.DataFrame(MASTER['expected_count'])
master.rename(columns={'expected_count':os.path.basename(results[0]).replace('.genes.results','')}, inplace=True)
for i in range(1,len(results)):
    X = pd.read_table(results[i],index_col=0)
    x = pd.DataFrame(X['expected_count'])
    x.rename(columns={'expected_count':os.path.basename(results[i]).replace('.genes.results','')}, inplace=True)
    master = pd.merge(master, x, how='outer', left_index=True, right_index=True)
master.head()
# Out:
#                                              EC-1AK228_CAGATC  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             857.57
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0            403.54
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0            217.78
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0             59.00
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0             99.77
#
#                                              EC-2AK546_ACTTGA  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             915.97
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0            389.58
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0            173.84
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0             94.04
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0            116.96
#
#                                              EC-3AK436_GATCAG  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             862.61
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0            596.27
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0            211.39
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0             98.48
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0             99.95
#
#                                              EC-4AK111_TAGCTT  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0            2405.84
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0            753.69
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0            664.18
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0            118.00
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0            250.46
#
#                                              EC-5AK453_GGCTAC  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             978.03
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0            585.08
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0            283.00
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0            155.29
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0            143.11
#
#                                              EC-6AK100_CTTGTA  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0            1103.49
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0            347.54
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0            315.21
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0             70.18
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0            109.21
#
#                                              EC-7AK501_AGTCAA  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             804.56
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0            422.48
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0            169.40
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0             55.00
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0             93.58
#
#                                              EC-8AK511_AGTTCC  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             919.31
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0            459.85
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0            147.88
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0            102.90
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0            129.38
#
#                                              EC-9AK123_ATGTCA  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             800.74
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0            601.84
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0            254.13
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0             79.57
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0            151.32
#
#                                              EC-10AK244_CCGTCC  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0              997.92
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0             632.69
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0             242.65
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0              74.62
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0              97.61
#
#                                              EC-11AK330_GTCCGC  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0              960.35
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0             614.72
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0             179.59
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0             100.98
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0             106.81
#
#                                              EC-12AK422_GTGAAA  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0              788.26
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0             388.06
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0             189.87
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0              80.60
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0              96.82
#
#                                              EC-13AK430_GTGGCC  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0              774.09
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0             530.67
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0             371.04
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0              69.67
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0              82.91
#
#                                              EC-14AK418_GTTTCG  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             1142.82
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0             446.87
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0             252.59
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0              44.00
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0              81.26
#
#                                              EC-15AK219_CGTACG  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             1523.27
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0             563.19
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0             210.18
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0              99.92
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0             102.15
#
#                                              EC-16AK327_GAGTGG  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             1333.79
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0             548.91
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0             287.10
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0              69.00
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0             234.03
#
#                                              EC-17AK506_ACTGAT  \
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0             1335.39
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0             537.05
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0             353.93
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0              82.51
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0             122.85
#
#                                              EC-18AK105_ATTCCT
# gene_id
# EC-4AK111_TAGCTT_R1_(paired)_contig_1003-0              970.72
# EC-4AK111_TAGCTT_R1_(paired)_contig_10031-0             433.79
# EC-4AK111_TAGCTT_R1_(paired)_contig_10050-0             299.87
# EC-4AK111_TAGCTT_R1_(paired)_contig_10085-0              70.66
# EC-4AK111_TAGCTT_R1_(paired)_contig_10099-0             106.00

# %%
master.round().astype(int).to_csv('/home/bay001/projects/kes_20160307/permanent_data/9-27-2016/counts.RSEM.txt',
                                 sep='\t',
                                 )

# %%
test = master.reset_index()

# %%
test[test['gene_id']=='ENSGALG00000000019']
# Out:
#                 gene_id  EC-1AK228_CAGATC  EC-2AK546_ACTTGA  EC-3AK436_GATCAG  \
# 865  ENSGALG00000000019            306.11            250.37            313.87
#
#      EC-4AK111_TAGCTT  EC-5AK453_GGCTAC  EC-6AK100_CTTGTA  EC-7AK501_AGTCAA  \
# 865            306.67            312.97            270.29            318.73
#
#      EC-8AK511_AGTTCC  EC-9AK123_ATGTCA  EC-10AK244_CCGTCC  EC-11AK330_GTCCGC  \
# 865            256.45            310.13             519.11             512.37
#
#      EC-12AK422_GTGAAA  EC-13AK430_GTGGCC  EC-14AK418_GTTTCG  \
# 865             318.97             675.18             440.15
#
#      EC-15AK219_CGTACG  EC-16AK327_GAGTGG  EC-17AK506_ACTGAT  \
# 865             421.52             601.67             457.26
#
#      EC-18AK105_ATTCCT
# 865             593.75

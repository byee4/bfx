# %% [markdown]
# # Create venn diagrams of significantly altered genes for Male/Female for each condition
# - per a phone-call discussion, may be useful for a poster.

# %%
# %matplotlib inline
from matplotlib_venn import venn2, venn3
import pandas as pd
import numpy as np
import os

# %%
wd = '/home/bay001/projects/kes_20160307/permanent_data/9-29-2016'

# %%
# SCCP VS CTRL
fc = 1

# %%
female = pd.read_table(os.path.join(wd,'SCCP_vs_CONTROL_FEMALE/diffexp.csv'),sep=',',index_col=0)
female = female[(female['padj']<=0.05) &
                (female['log2FoldChange'] >=fc)]
female_genes = set(female.index)

male = pd.read_table(os.path.join(wd,'SCCP_vs_CONTROL_MALE/diffexp.csv'),sep=',',index_col=0)
male = male[(male['padj']<=0.05) &
                (male['log2FoldChange'] >=fc)]
male_genes = set(male.index)

a = pd.read_table(os.path.join(wd,'SCCP_vs_CONTROL/diffexp.csv'),sep=',',index_col=0)
a = a[(a['padj']<=0.05) &
                (a['log2FoldChange'] >=fc)]
all_genes = set(a.index)
venn3([male_genes, female_genes, all_genes],['Male','Female','All'])
# Out:
# <matplotlib_venn._common.VennDiagram instance at 0x2b081a545d40>

# %%
female = pd.read_table(os.path.join(wd,'TBBPA_vs_CONTROL_FEMALE/diffexp.csv'),sep=',',index_col=0)
female = female[(female['padj']<=0.05) &
                (female['log2FoldChange'] >=fc)]
female_genes = set(female.index)

male = pd.read_table(os.path.join(wd,'TBBPA_vs_CONTROL_MALE/diffexp.csv'),sep=',',index_col=0)
male = male[(male['padj']<=0.05) &
                (male['log2FoldChange'] >=fc)]
male_genes = set(male.index)

a = pd.read_table(os.path.join(wd,'TBBPA_vs_CONTROL/diffexp.csv'),sep=',',index_col=0)
a = a[(a['padj']<=0.05) &
                (a['log2FoldChange'] >=fc)]
all_genes = set(a.index)
venn3([male_genes, female_genes, all_genes],['Male','Female','All'])
# Out:
# <matplotlib_venn._common.VennDiagram instance at 0x2b081a7983f8>

# %%
male - female
# Out:
#                                              baseMean  log2FoldChange  lfcSE  \
# EC-4AK111_TAGCTT_R1_(paired)_contig_1434-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_15357-0       NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_16972-0       NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_2138-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_2206-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_2548-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_2604-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_2817-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_3286-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_4027-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_4161-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_6809-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_6940-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_7110-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_8437-0        NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_923-0         NaN             NaN    NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_3286-0    NaN     NaN   NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_4027-0    NaN     NaN   NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_4161-0    NaN     NaN   NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_6809-0    NaN     NaN   NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_6940-0    NaN     NaN   NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_7110-0    NaN     NaN   NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_8437-0    NaN     NaN   NaN
# EC-4AK111_TAGCTT_R1_(paired)_contig_923-0     NaN     NaN   NaN
# ENSGALG00000000437                            NaN     NaN   NaN
# ENSGALG00000004246                            NaN     NaN   NaN
# ENSGALG00000004445                            NaN     NaN   NaN
# ENSGALG00000005796                            NaN     NaN   NaN
# ENSGALG00000008820                            NaN     NaN   NaN
# ENSGALG00000009262                            NaN     NaN   NaN
# ENSGALG00000009266                            NaN     NaN   NaN
# ENSGALG00000009268                            NaN     NaN   NaN
# ENSGALG00000009446                            NaN     NaN   NaN
# ENSGALG00000010018                            NaN     NaN   NaN
# ENSGALG00000010137                            NaN     NaN   NaN
# ENSGALG00000010369                            NaN     NaN   NaN
# ENSGALG00000012015                            NaN     NaN   NaN
# ENSGALG00000013164                            NaN     NaN   NaN
# ...                                           ...     ...   ...
# unmapped-49-contig_list_contig_36587-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_36944-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_37087-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_39506-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_40369-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_41072-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_42450-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_42718-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_43768-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_43820-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_44627-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_44665-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_44720-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_45678-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_47371-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_47646-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_47690-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_4803-0         NaN     NaN   NaN
# unmapped-49-contig_list_contig_5056-2         NaN     NaN   NaN
# unmapped-49-contig_list_contig_50909-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_5528-0         NaN     NaN   NaN
# unmapped-49-contig_list_contig_66151-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_66188-1        NaN     NaN   NaN
# unmapped-49-contig_list_contig_67735-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_67847-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_69852-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_7057-0         NaN     NaN   NaN
# unmapped-49-contig_list_contig_71043-0        NaN     NaN   NaN
# unmapped-49-contig_list_contig_8189-0         NaN     NaN   NaN
# unmapped-49-contig_list_contig_9597-0         NaN     NaN   NaN
#
# [116 rows x 6 columns]

# %% [markdown]
# - 1. The authors mention that they do poly-A selection of the RNA samples (p.6). What proportion of
# transcripts identified are actually unspliced? Given that more than 50% of the identified A-to- I edits are in the
# introns, the data sets examined may actually be an under representation of the true unspliced
# transcriptome.
#     - get the introns where each editing site occurs
#     - count reads supporting splicing versus reads supporting splicing versus retained intron
#     - calculate the difference between intron and exon reads

# %% [markdown]
# # Minor point 1
# ### Check why there are so many intronic editing sites:
# - Updated pie chart to reflect WS257 (or keep the WS254 ones, it looks like many of them don't really change)
# - Check intron retention between introns that were edited versus a background (all introns that were spliced)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os
import glob

rnaseq_dir = '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/'
editing_calls_dir = '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/editing_calls_v18/ws257/'
wd = '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/editor_response_minor_1/ws257/'
# Out:
# /home/bay001/anaconda2/envs/brian/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# load the previous annotations
old_ws254 = pd.read_table(
    '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/editing_calls_v15_final/ws254/annotations_wbgene.txt'
)
ws254_introns = old_ws254[old_ws254['region']=='intron']
print("number of ws254 introns called: {}".format(ws254_introns.shape[0]))
new_ws257 = pd.read_table(
    os.path.join(wd, 'supplemental_doc_1.txt')
)
ws257_introns = new_ws257[new_ws257['Region']=='intron']
print("number of ws257 introns called: {}".format(ws257_introns.shape[0]))
ws257_introns.head()
# Out:
# number of ws254 introns called: 3630
# number of ws257 introns called: 3644
#   Chromosome  Position  % Edit  Coverage  Region     Wormbase ID Gene Name
# 0       chrI    454106     0.8         5  intron  WBGene00006593     tol-1
# 1       chrI    454111     0.4         5  intron  WBGene00006593     tol-1
# 2       chrI    454113     0.6         5  intron  WBGene00006593     tol-1
# 3       chrI    454118     0.6         5  intron  WBGene00006593     tol-1
# 4       chrI    454330     0.4         5  intron  WBGene00006593     tol-1

# %%
os.path.join(wd, 'supplemental_doc_1.txt')
# Out:
# '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/editor_response_minor_1/ws257/supplemental_doc_1.txt'

# %%
merged = pd.merge(
    old_ws254, new_ws257, 
    how='outer', 
    left_on=['chrom','pos'], 
    right_on=['Chromosome','Position']
)

# %%
# regions that were introns using the old annotations, but not called intronic in the new
merged[(merged['Region']!='intron') & (merged['region']=='intron')]
# Out:
# Empty DataFrame
# Columns: [chrom, pos-1, pos, approx_edit_fraction, approx_coverage, strand, region_chrom, source, region_start, region_end, region_strand, attributes, region, id, wbgene, gene, Chromosome, Position, % Edit, Coverage, Region, Wormbase ID, Gene Name]
# Index: []
#
# [0 rows x 23 columns]

# %%
merged[(merged['Region']=='intron') & (merged['region']!='intron')]
# Out:
#        chrom       pos-1         pos  approx_edit_fraction  approx_coverage  \
# 6898  chrIII  12554628.0  12554629.0                  53.0             13.0
# 6900  chrIII  12554649.0  12554650.0                  26.0             15.0
# 6901  chrIII  12554629.0  12554630.0                  69.0             13.0
# 6902  chrIII  12554623.0  12554624.0                  61.0             13.0
# 6904  chrIII  12554605.0  12554606.0                  15.0             13.0
# 6905  chrIII  12554404.0  12554405.0                  31.0             19.0
# 6911  chrIII  12554405.0  12554406.0                  31.0             19.0
# 6912  chrIII  12554434.0  12554435.0                  46.0             15.0
# 6913  chrIII  12554435.0  12554436.0                  53.0             15.0
# 6926  chrIII  12554617.0  12554618.0                  92.0             13.0
# 6927  chrIII  12554621.0  12554622.0                  15.0             13.0
# 6932  chrIII  12554622.0  12554623.0                  69.0             13.0
# 6934  chrIII  12554465.0  12554466.0                  18.0             16.0
# 7009  chrIII  12554650.0  12554651.0                  13.0             15.0
#
#      strand region_chrom    source  region_start  region_end    ...      \
# 6898      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6900      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6901      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6902      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6904      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6905      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6911      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6912      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6913      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6926      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6927      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6932      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 6934      -       chrIII  WormBase    12549806.0  12549889.0    ...
# 7009      -       chrIII  WormBase    12549806.0  12549889.0    ...
#
#                   id          wbgene        gene Chromosome  Position  \
# 6898      Y111B2A.32  WBGene00196205  Y111B2A.32     chrIII  12554629
# 6900      Y111B2A.32  WBGene00196205  Y111B2A.32     chrIII  12554650
# 6901      Y111B2A.32  WBGene00196205  Y111B2A.32     chrIII  12554630
# 6902      Y111B2A.32  WBGene00196205  Y111B2A.32     chrIII  12554624
# 6904      Y111B2A.32  WBGene00196205  Y111B2A.32     chrIII  12554606
# 6905      Y111B2A.32  WBGene00196205  Y111B2A.32     chrIII  12554405
# 6911  WBGene00196205  WBGene00196205  Y111B2A.32     chrIII  12554406
# 6912      Y111B2A.32  WBGene00196205  Y111B2A.32     chrIII  12554435
# 6913      Y111B2A.32  WBGene00196205  Y111B2A.32     chrIII  12554436
# 6926  WBGene00196205  WBGene00196205  Y111B2A.32     chrIII  12554618
# 6927      Y111B2A.32  WBGene00196205  Y111B2A.32     chrIII  12554622
# 6932  WBGene00196205  WBGene00196205  Y111B2A.32     chrIII  12554623
# 6934      Y111B2A.32  WBGene00196205  Y111B2A.32     chrIII  12554466
# 7009  WBGene00196205  WBGene00196205  Y111B2A.32     chrIII  12554651
#
#         % Edit Coverage  Region     Wormbase ID  Gene Name
# 6898  0.538462       13  intron  WBGene00013732     aakg-1
# 6900  0.266667       15  intron  WBGene00013732     aakg-1
# 6901  0.692308       13  intron  WBGene00013732     aakg-1
# 6902  0.615385       13  intron  WBGene00013732     aakg-1
# 6904  0.153846       13  intron  WBGene00013732     aakg-1
# 6905  0.315789       19  intron  WBGene00013732     aakg-1
# 6911  0.315789       19  intron  WBGene00013732     aakg-1
# 6912  0.466667       15  intron  WBGene00013732     aakg-1
# 6913  0.533333       15  intron  WBGene00013732     aakg-1
# 6926  0.923077       13  intron  WBGene00013732     aakg-1
# 6927  0.153846       13  intron  WBGene00013732     aakg-1
# 6932  0.692308       13  intron  WBGene00013732     aakg-1
# 6934  0.187500       16  intron  WBGene00013732     aakg-1
# 7009  0.133333       15  intron  WBGene00013732     aakg-1
#
# [14 rows x 23 columns]

# %% [markdown]
# # Look at the pie chart to see the distributions
# - These are for WS257 annotations... we can ignore this section if we decide to keep ws254 for the paper

# %%
def get_region(row):
    """
    Returns the genic region given my annotation string.
    """
    try:
        if 'INTERGENIC' in row['priority']:
            return 'intergenic'
        else:
            return row['priority'].split(':')[4]
    except Exception as e:
        print(e, row['priority'])
        
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = list(new_ws257['Region'].value_counts().keys())
sizes = list(new_ws257['Region'].value_counts())

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# # Look at intron retention among the introns called as edited.

# %%
# first find the sj out files
SJOuts = glob.glob(os.path.join(rnaseq_dir,"*.rmRep.bamSJ.out.tab"))
SJOuts
# Out:
# ['/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/GSF973-Hundley-SarahD-1_S1_R1_001.polyATrim.adapterTrim.rmRep.bamSJ.out.tab',
#  '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/GSF973-Hundley-SarahD-6_S6_R1_001.polyATrim.adapterTrim.rmRep.bamSJ.out.tab',
#  '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/GSF973-Hundley-SarahD-2_S2_R1_001.polyATrim.adapterTrim.rmRep.bamSJ.out.tab',
#  '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/GSF973-Hundley-SarahD-5_S5_R1_001.polyATrim.adapterTrim.rmRep.bamSJ.out.tab',
#  '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/GSF973-Hundley-SarahD-7_S7_R1_001.polyATrim.adapterTrim.rmRep.bamSJ.out.tab',
#  '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/GSF973-Hundley-SarahD-4_S4_R1_001.polyATrim.adapterTrim.rmRep.bamSJ.out.tab',
#  '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/GSF973-Hundley-SarahD-3_S3_R1_001.polyATrim.adapterTrim.rmRep.bamSJ.out.tab']

# %%
wt1 = '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/GSF973-Hundley-SarahD-1_S1_R1_001.polyATrim.adapterTrim.rmRep.bamSJ.out.tab'
wt3 = '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/GSF973-Hundley-SarahD-3_S3_R1_001.polyATrim.adapterTrim.rmRep.bamSJ.out.tab'
wt6 = '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/GSF973-Hundley-SarahD-6_S6_R1_001.polyATrim.adapterTrim.rmRep.bamSJ.out.tab'

sjout_names = ['chrom','start','end','n_strand','motif','annotated','unique','multi','max_spliced_overhang']

def strand(row):
    """
    Converts numeric strand info to canonical.
    """
    if row['n_strand'] == 0:
        return 'x'
    elif row['n_strand'] == 1:
        return '+'
    elif row['n_strand'] == 2:
        return '-'
    else:
        return 'x'
        
def read(fn):
    """
    Read in sj.out.tab file, return just introns whose strand is 
    determined and who has at least 10 reads supporting it.
    """
    df = pd.read_table(fn, names=sjout_names)
    df['strand'] = df.apply(strand, axis=1)
    df['start'] = df['start'] - 1 # turn one based start into 0 based 
    print('number of introns with undefined strand (discarding): ', df[df['strand']=='x'].shape)
    df = df[df['unique']>=10]
    df = df[df['strand']!='x']
    return df

wts = [wt1, wt3, wt6]


wt1_df = read(wts[0])
print("Number of introns discovered in WT1 sample: ", wt1_df.shape)
wt3_df = read(wts[1])
print("Number of introns discovered in WT3 sample: ", wt3_df.shape)
wt6_df = read(wts[2])
print("Number of introns discovered in WT6 sample: ", wt6_df.shape)

# merge all and drop duplicates, returning the set of all introns in the combined WT sample.
merged = pd.concat([wt1_df, wt3_df, wt6_df], axis=0).drop_duplicates(['chrom','start','end','strand'])
print("Number of introns discovered in WT sample: ", merged.shape)
# Out:
# ('number of introns with undefined strand (discarding): ', (253, 10))
# ('Number of introns discovered in WT1 sample: ', (63091, 10))
# ('number of introns with undefined strand (discarding): ', (209, 10))
# ('Number of introns discovered in WT3 sample: ', (63681, 10))
# ('number of introns with undefined strand (discarding): ', (132, 10))
# ('Number of introns discovered in WT6 sample: ', (63328, 10))
# ('Number of introns discovered in WT sample: ', (75965, 10))

# %%
# Save all background introns as a bedfile (tabbed)
out_bed = os.path.join(wd,'WT.introns.bed')
merged[['chrom','start','end','annotated','unique','strand']].to_csv(
    out_bed, sep='\t', header=False, index=False
)

# %% [markdown]
# # Run junction counter to count number of reads supporting splicing/intron retention for ALL discovered introns
# - https://github.com/byee4/junction-counter

# %%
junc = '/home/bay001/projects/codebase/junction-counter/junction_counter/count_junctions.py'
bam = os.path.join(wd,'WT.sorted.rmdup.readfiltered.bam')
outfile = os.path.join(wd,'WT.jxc')

# %%
cmd = 'python {} '.format(junc)
cmd = cmd + '--bed {} '.format(out_bed)
cmd = cmd + '--bam {} '.format(bam)
cmd = cmd + '--min_overlap {} '.format(10)
cmd = cmd + '--library {} '.format('reverse_se')
cmd = cmd + '--outfile {}'.format(outfile)
! $cmd
# Out:
# 100%|####################################9| 75958/75965 [10:13<00:00, 97.15it/s]

# %% [markdown]
# # Run junction counter to count number of reads supporting splicing/intron retention for edited introns

# %%
editing_sites = pd.read_table(
    os.path.join(wd, 'filtered.bed.annotated'),
    names=['chrom','start','stop','name','score','strand','priority','annotation']
) # this comes from the 'final analysis notebook'
editing_sites.head()
# Out:
#   chrom   start    stop       name     score strand  \
# 0  chrI  454105  454106  5|A>G|0.8  1.000000      +
# 1  chrI  454110  454111  5|A>G|0.4  0.999408      +
# 2  chrI  454112  454113  5|A>G|0.6  0.999996      +
# 3  chrI  454117  454118  5|A>G|0.6  0.999996      +
# 4  chrI  454329  454330  5|A>G|0.4  0.999408      +
#
#                                             priority  \
# 0  C07F11.1:451461:455355:+:intron:WBGene00006593...
# 1  C07F11.1:451461:455355:+:intron:WBGene00006593...
# 2  C07F11.1:451461:455355:+:intron:WBGene00006593...
# 3  C07F11.1:451461:455355:+:intron:WBGene00006593...
# 4  C07F11.1:451461:455355:+:intron:WBGene00006593...
#
#                                           annotation
# 0  C07F11.1:443998:461605:+:transcript:WBGene0000...
# 1  C07F11.1:443998:461605:+:transcript:WBGene0000...
# 2  C07F11.1:443998:461605:+:transcript:WBGene0000...
# 3  C07F11.1:443998:461605:+:transcript:WBGene0000...
# 4  C07F11.1:443998:461605:+:transcript:WBGene0000...

# %%
def get_annotation(row):
    """
    parses annotation string to get the region
    """
    if row['priority'] == 'INTERGENIC':
        return 'INTERGENIC'
    else:
        return row['priority'].split(':')[4]
    
def get_intron_start(row):
    """
    parses annotation string to get the intron start
    """
    if row['priority'] == 'INTERGENIC':
        return 'INTERGENIC'
    else:
        return int(row['priority'].split(':')[1]) -1

def get_intron_stop(row):
    """
    parses annotation string to get the intron stop
    """
    if row['priority'] == 'INTERGENIC':
        return 'INTERGENIC'
    else:
        return row['priority'].split(':')[2]
    
editing_sites['region'] = editing_sites.apply(get_annotation, axis=1)
editing_sites['intron_start'] = editing_sites.apply(get_intron_start, axis=1)
editing_sites['intron_stop'] = editing_sites.apply(get_intron_stop, axis=1)
print(editing_sites.ix[1]['annotation'])
editing_sites
# Out:
# C07F11.1:443998:461605:+:transcript:WBGene00006593:C07F11.1:protein_coding:feature_contains_query|C07F11.1:451461:455355:+:intron:WBGene00006593:C07F11.1:protein_coding:feature_contains_query
#      chrom     start      stop                name     score strand  \
# 0     chrI    454105    454106           5|A>G|0.8  1.000000      +
# 1     chrI    454110    454111           5|A>G|0.4  0.999408      +
# 2     chrI    454112    454113           5|A>G|0.6  0.999996      +
# 3     chrI    454117    454118           5|A>G|0.6  0.999996      +
# 4     chrI    454329    454330           5|A>G|0.4  0.999408      +
# 5     chrI    454330    454331           5|A>G|0.6  0.999996      +
# 6     chrI    454331    454332           5|A>G|0.4  0.999408      +
# 7     chrI    454465    454466          8|A>G|0.25  0.997969      +
# 8     chrI    622492    622493           5|A>G|0.8  1.000000      +
# 9     chrI    622493    622494           5|A>G|0.6  0.999996      +
# 10    chrI    622509    622510           5|A>G|0.4  0.999408      +
# 11    chrI    622525    622526   6|A>G|0.333333333  0.999020      +
# 12    chrI    622536    622537   6|A>G|0.666666667  1.000000      +
# 13    chrI    622579    622580           6|A>G|0.5  0.999990      +
# 14    chrI    622931    622932           5|A>G|0.4  0.999408      +
# 15    chrI    622974    622975           5|A>G|0.8  1.000000      +
# 16    chrI    622978    622979           5|A>G|0.4  0.999408      +
# 17    chrI    788771    788772   6|A>G|0.666666667  1.000000      +
# 18    chrI    999813    999814   6|A>G|0.666666667  1.000000      +
# 19    chrI    999818    999819   7|A>G|0.428571429  0.999980      +
# 20    chrI    999839    999840   7|A>G|0.714285714  1.000000      +
# 21    chrI    999878    999879           5|A>G|0.4  0.999408      +
# 22    chrI   1000780   1000781           5|A>G|0.4  0.999408      +
# 23    chrI   1358464   1358465  26|A>G|0.423076923  1.000000      +
# 24    chrI   1358478   1358479  22|A>G|0.136363636  0.998838      +
# 25    chrI   1358488   1358489   21|A>G|0.19047619  0.999957      +
# 26    chrI   1358500   1358501  22|A>G|0.727272727  1.000000      +
# 27    chrI   1358501   1358502  22|A>G|0.727272727  1.000000      +
# 28    chrI   1358504   1358505  23|A>G|0.130434783  0.998664      +
# 29    chrI   1358513   1358514  24|A>G|0.541666667  1.000000      +
# ...    ...       ...       ...                 ...       ...    ...
# 7332  chrX   8577887   8577888   6|T>C|0.833333333  1.000000      -
# 7333  chrX   8577888   8577889   6|T>C|0.833333333  1.000000      -
# 7334  chrX   8578421   8578422   7|T>C|0.571428571  1.000000      -
# 7335  chrX   8578422   8578423   7|T>C|0.714285714  1.000000      -
# 7336  chrX   8578423   8578424   7|T>C|0.285714286  0.998540      -
# 7337  chrX   8578434   8578435   7|T>C|0.428571429  0.999980      -
# 7338  chrX   8578436   8578437   7|T>C|0.571428571  1.000000      -
# 7339  chrX   8578438   8578439   7|T>C|0.857142857  1.000000      -
# 7340  chrX   8578449   8578450   7|T>C|0.714285714  1.000000      -
# 7341  chrX   8578458   8578459   7|T>C|0.285714286  0.998540      -
# 7342  chrX  15270337  15270338   6|T>C|0.333333333  0.999020      -
# 7343  chrX  15534202  15534203   7|T>C|0.428571429  0.999980      -
# 7344  chrX  15534203  15534204   7|T>C|0.428571429  0.999980      -
# 7345  chrX  15534212  15534213          8|T>C|0.25  0.997969      -
# 7346  chrX  15989199  15989200   9|T>C|0.222222222  0.997310      -
# 7347  chrX  15989209  15989210   9|T>C|0.222222222  0.997310      -
# 7348  chrX  15989254  15989255   6|T>C|0.333333333  0.999020      -
# 7349  chrX  16750105  16750106   7|T>C|0.285714286  0.998540      -
# 7350  chrX  16750138  16750139          8|T>C|0.25  0.997969      -
# 7351  chrX  16750142  16750143           8|T>C|0.5  1.000000      -
# 7352  chrX  16750159  16750160   6|T>C|0.833333333  1.000000      -
# 7353  chrX  16750164  16750165           6|T>C|0.5  0.999990      -
# 7354  chrX  16750165  16750166           6|T>C|0.5  0.999990      -
# 7355  chrX  16750186  16750187   6|T>C|0.333333333  0.999020      -
# 7356  chrX  16750187  16750188   6|T>C|0.333333333  0.999020      -
# 7357  chrX  16750203  16750204   6|T>C|0.833333333  1.000000      -
# 7358  chrX  16750221  16750222   7|T>C|0.285714286  0.998540      -
# 7359  chrX  16750386  16750387           5|T>C|0.4  0.999408      -
# 7360  chrX  16903215  16903216           5|T>C|0.8  1.000000      -
# 7361  chrX  16903220  16903221           5|T>C|0.4  0.999408      -
#
#                                                priority  \
# 0     C07F11.1:451461:455355:+:intron:WBGene00006593...
# 1     C07F11.1:451461:455355:+:intron:WBGene00006593...
# 2     C07F11.1:451461:455355:+:intron:WBGene00006593...
# 3     C07F11.1:451461:455355:+:intron:WBGene00006593...
# 4     C07F11.1:451461:455355:+:intron:WBGene00006593...
# 5     C07F11.1:451461:455355:+:intron:WBGene00006593...
# 6     C07F11.1:451461:455355:+:intron:WBGene00006593...
# 7     C07F11.1:451461:455355:+:intron:WBGene00006593...
# 8     F56A6.1b:621172:623172:+:downstream_gene:WBGen...
# 9     F56A6.1b:621172:623172:+:downstream_gene:WBGen...
# 10    F56A6.1b:621172:623172:+:downstream_gene:WBGen...
# 11    F56A6.1b:621172:623172:+:downstream_gene:WBGen...
# 12    F56A6.1b:621172:623172:+:downstream_gene:WBGen...
# 13    F56A6.1b:621172:623172:+:downstream_gene:WBGen...
# 14    F56A6.1b:621172:623172:+:downstream_gene:WBGen...
# 15    F56A6.1b:621172:623172:+:downstream_gene:WBGen...
# 16    F56A6.1b:621172:623172:+:downstream_gene:WBGen...
# 17    T06A4.7:788219:790219:+:downstream_noncoding_t...
# 18    C54G6.3:997249:1002502:+:intron:WBGene00016932...
# 19    C54G6.3:997249:1002502:+:intron:WBGene00016932...
# 20    C54G6.3:997249:1002502:+:intron:WBGene00016932...
# 21    C54G6.3:997249:1002502:+:intron:WBGene00016932...
# 22    C54G6.3:997249:1002502:+:intron:WBGene00016932...
# 23    Y92H12BL.1a.2:1358416:1358517:+:three_prime_ut...
# 24    Y92H12BL.1a.2:1358416:1358517:+:three_prime_ut...
# 25    Y92H12BL.1a.2:1358416:1358517:+:three_prime_ut...
# 26    Y92H12BL.1a.2:1358416:1358517:+:three_prime_ut...
# 27    Y92H12BL.1a.2:1358416:1358517:+:three_prime_ut...
# 28    Y92H12BL.1a.2:1358416:1358517:+:three_prime_ut...
# 29    Y92H12BL.1a.2:1358416:1358517:+:three_prime_ut...
# ...                                                 ...
# 7332  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7333  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7334  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7335  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7336  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7337  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7338  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7339  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7340  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7341  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7342  F46F2.2f.2:15269726:15270659:-:intron:WBGene00...
# 7343                                         INTERGENIC
# 7344                                         INTERGENIC
# 7345                                         INTERGENIC
# 7346  C09G1.4:15988517:15989879:-:intron:WBGene00007...
# 7347  C09G1.4:15988517:15989879:-:intron:WBGene00007...
# 7348  C09G1.4:15988517:15989879:-:intron:WBGene00007...
# 7349  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7350  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7351  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7352  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7353  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7354  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7355  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7356  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7357  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7358  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7359  C10E2.4:16749928:16750642:-:intron:WBGene00015...
# 7360  F39F10.4:16903150:16904295:-:intron:WBGene0001...
# 7361  F39F10.4:16903150:16904295:-:intron:WBGene0001...
#
#                                              annotation  \
# 0     C07F11.1:443998:461605:+:transcript:WBGene0000...
# 1     C07F11.1:443998:461605:+:transcript:WBGene0000...
# 2     C07F11.1:443998:461605:+:transcript:WBGene0000...
# 3     C07F11.1:443998:461605:+:transcript:WBGene0000...
# 4     C07F11.1:443998:461605:+:transcript:WBGene0000...
# 5     C07F11.1:443998:461605:+:transcript:WBGene0000...
# 6     C07F11.1:443998:461605:+:transcript:WBGene0000...
# 7     C07F11.1:443998:461605:+:transcript:WBGene0000...
# 8     Y65B4A.4:622187:624187:+:downstream_gene:WBGen...
# 9     Y65B4A.4:622187:624187:+:downstream_gene:WBGen...
# 10    Y65B4A.4:622187:624187:+:downstream_gene:WBGen...
# 11    Y65B4A.4:622187:624187:+:downstream_gene:WBGen...
# 12    Y65B4A.4:622187:624187:+:downstream_gene:WBGen...
# 13    Y65B4A.4:622187:624187:+:downstream_gene:WBGen...
# 14    Y65B4A.4:622187:624187:+:downstream_gene:WBGen...
# 15    Y65B4A.4:622187:624187:+:downstream_gene:WBGen...
# 16    Y65B4A.4:622187:624187:+:downstream_gene:WBGen...
# 17    T06A4.7:788219:790219:+:downstream_noncoding_t...
# 18    C54G6.3:996044:1005066:+:transcript:WBGene0001...
# 19    C54G6.3:996044:1005066:+:transcript:WBGene0001...
# 20    C54G6.3:996044:1005066:+:transcript:WBGene0001...
# 21    C54G6.3:996044:1005066:+:transcript:WBGene0001...
# 22    C54G6.3:996044:1005066:+:transcript:WBGene0001...
# 23    Y92H12BL.1a.2:1348502:1359595:+:transcript:WBG...
# 24    Y92H12BL.1a.2:1348502:1359595:+:transcript:WBG...
# 25    Y92H12BL.1a.2:1348502:1359595:+:transcript:WBG...
# 26    Y92H12BL.1a.2:1348502:1359595:+:transcript:WBG...
# 27    Y92H12BL.1a.2:1348502:1359595:+:transcript:WBG...
# 28    Y92H12BL.1a.2:1348502:1359595:+:transcript:WBG...
# 29    Y92H12BL.1a.2:1348502:1359595:+:transcript:WBG...
# ...                                                 ...
# 7332  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7333  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7334  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7335  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7336  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7337  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7338  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7339  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7340  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7341  F18E9.8:8576584:8578584:-:downstream_gene:WBGe...
# 7342  F46F2.2f.2:15269073:15277764:-:transcript:WBGe...
# 7343                                         INTERGENIC
# 7344                                         INTERGENIC
# 7345                                         INTERGENIC
# 7346  C09G1.4:15987970:15996936:-:transcript:WBGene0...
# 7347  C09G1.4:15987970:15996936:-:transcript:WBGene0...
# 7348  C09G1.4:15987970:15996936:-:transcript:WBGene0...
# 7349  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7350  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7351  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7352  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7353  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7354  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7355  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7356  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7357  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7358  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7359  C10E2.4:16749754:16751110:-:transcript:WBGene0...
# 7360  F39F10.4:16902390:16904332:-:transcript:WBGene...
# 7361  F39F10.4:16902390:16904332:-:transcript:WBGene...
#
#                                region intron_start intron_stop
# 0                              intron       451460      455355
# 1                              intron       451460      455355
# 2                              intron       451460      455355
# 3                              intron       451460      455355
# 4                              intron       451460      455355
# 5                              intron       451460      455355
# 6                              intron       451460      455355
# 7                              intron       451460      455355
# 8                     downstream_gene       621171      623172
# 9                     downstream_gene       621171      623172
# 10                    downstream_gene       621171      623172
# 11                    downstream_gene       621171      623172
# 12                    downstream_gene       621171      623172
# 13                    downstream_gene       621171      623172
# 14                    downstream_gene       621171      623172
# 15                    downstream_gene       621171      623172
# 16                    downstream_gene       621171      623172
# 17    downstream_noncoding_transcript       788218      790219
# 18                             intron       997248     1002502
# 19                             intron       997248     1002502
# 20                             intron       997248     1002502
# 21                             intron       997248     1002502
# 22                             intron       997248     1002502
# 23                    three_prime_utr      1358415     1358517
# 24                    three_prime_utr      1358415     1358517
# 25                    three_prime_utr      1358415     1358517
# 26                    three_prime_utr      1358415     1358517
# 27                    three_prime_utr      1358415     1358517
# 28                    three_prime_utr      1358415     1358517
# 29                    three_prime_utr      1358415     1358517
# ...                               ...          ...         ...
# 7332                  downstream_gene      8576583     8578584
# 7333                  downstream_gene      8576583     8578584
# 7334                  downstream_gene      8576583     8578584
# 7335                  downstream_gene      8576583     8578584
# 7336                  downstream_gene      8576583     8578584
# 7337                  downstream_gene      8576583     8578584
# 7338                  downstream_gene      8576583     8578584
# 7339                  downstream_gene      8576583     8578584
# 7340                  downstream_gene      8576583     8578584
# 7341                  downstream_gene      8576583     8578584
# 7342                           intron     15269725    15270659
# 7343                       INTERGENIC   INTERGENIC  INTERGENIC
# 7344                       INTERGENIC   INTERGENIC  INTERGENIC
# 7345                       INTERGENIC   INTERGENIC  INTERGENIC
# 7346                           intron     15988516    15989879
# 7347                           intron     15988516    15989879
# 7348                           intron     15988516    15989879
# 7349                           intron     16749927    16750642
# 7350                           intron     16749927    16750642
# 7351                           intron     16749927    16750642
# 7352                           intron     16749927    16750642
# 7353                           intron     16749927    16750642
# 7354                           intron     16749927    16750642
# 7355                           intron     16749927    16750642
# 7356                           intron     16749927    16750642
# 7357                           intron     16749927    16750642
# 7358                           intron     16749927    16750642
# 7359                           intron     16749927    16750642
# 7360                           intron     16903149    16904295
# 7361                           intron     16903149    16904295
#
# [7362 rows x 11 columns]

# %% [markdown]
# ### Keep only the 'intronic' edited sites and convert into a BED file

# %%
edited_introns_bed = os.path.join(wd, 'intronic_sites.bed')
introns = editing_sites[editing_sites['region']=='intron'][['chrom','intron_start','intron_stop','name','score','strand']]
print("number of total sites edited: ", introns.shape)
introns.drop_duplicates(['chrom','intron_start','intron_stop','strand'], inplace=True)
print("number of unique introns: ", introns.shape)
introns.to_csv(
    edited_introns_bed,
    sep='\t', header=False, index=False
)
introns
# Out:
# ('number of total sites edited: ', (3644, 6))
# ('number of unique introns: ', (387, 6))
#      chrom intron_start intron_stop                name     score strand
# 0     chrI       451460      455355           5|A>G|0.8  1.000000      +
# 18    chrI       997248     1002502   6|A>G|0.666666667  1.000000      +
# 64    chrI      1358516     1359412         28|A>G|0.75  1.000000      +
# 215   chrI      1553881     1554796  13|A>G|0.153846154  0.993825      +
# 229   chrI      1574490     1577386           5|A>G|0.8  1.000000      +
# 236   chrI      1751858     1752603  13|A>G|0.307692308  0.999995      +
# 268   chrI      1768498     1769864         12|A>G|0.25  0.999845      +
# 281   chrI      1770068     1783691   7|A>G|0.428571429  0.999980      +
# 289   chrI      1809713     1811061  11|A>G|0.363636364  0.999998      +
# 316   chrI      1882233     1883334           5|A>G|0.6  0.999996      +
# 318   chrI      1899425     1900017   6|A>G|0.333333333  0.999020      +
# 321   chrI      1935004     1941130  12|A>G|0.166666667  0.994820      +
# 354   chrI      2076391     2076690  45|A>G|0.244444444  1.000000      +
# 388   chrI      2081308     2082813   7|A>G|0.285714286  0.998540      +
# 421   chrI      2083028     2084338           5|A>G|0.4  0.999408      +
# 429   chrI      2143089     2144877   7|A>G|0.428571429  0.999980      +
# 437   chrI      2197283     2200009   7|A>G|0.571428571  1.000000      +
# 445   chrI      2295210     2296229   7|A>G|0.714285714  1.000000      +
# 469   chrI      2296638     2297081  39|A>G|0.230769231  1.000000      +
# 490   chrI      2415278     2415841  58|A>G|0.103448276  0.999977      +
# 505   chrI      2415948     2417181           5|A>G|0.4  0.999408      +
# 507   chrI      2417573     2418370   9|A>G|0.444444444  0.999999      +
# 513   chrI      2616077     2617090         20|A>G|0.15  0.999141      +
# 514   chrI      2715057     2717229           5|A>G|0.4  0.999408      +
# 524   chrI      2733432     2735136          8|A>G|0.25  0.997969      +
# 557   chrI      2925943     2926558           5|A>G|0.6  0.999996      +
# 560   chrI      3026783     3028130           5|A>G|0.4  0.999408      +
# 573   chrI      3033887     3034595   9|A>G|0.333333333  0.999946      +
# 624   chrI      3506239     3508221           5|A>G|0.4  0.999408      +
# 638   chrI      4484418     4498007   6|A>G|0.333333333  0.999020      +
# ...    ...          ...         ...                 ...       ...    ...
# 6559  chrV      6417715     6422216   9|T>C|0.444444444  0.999999      -
# 6579  chrV      7215144     7217650   9|T>C|0.222222222  0.997310      -
# 6582  chrV      8011725     8012160          10|T>C|0.3  0.999920      -
# 6589  chrV      8303078     8304410          10|T>C|0.2  0.996564      -
# 6889  chrV      8924027     8924353  12|T>C|0.333333333  0.999997      -
# 6931  chrV     11324402    11326283           5|T>C|0.4  0.999408      -
# 6937  chrV     13037087    13038661  47|T>C|0.595744681  1.000000      -
# 7026  chrV     13470803    13473380   7|T>C|0.285714286  0.998540      -
# 7039  chrV     13997955    13998947           5|T>C|0.6  0.999996      -
# 7059  chrV     15551765    15552448           6|T>C|0.5  0.999990      -
# 7068  chrV     17941005    17943128           5|T>C|0.6  0.999996      -
# 7075  chrV     18054053    18054841           5|T>C|0.6  0.999996      -
# 7082  chrV     18062438    18063226           5|T>C|0.4  0.999408      -
# 7090  chrV     18776711    18779590           5|T>C|0.8  1.000000      -
# 7096  chrV     18896763    18898251           5|T>C|0.4  0.999408      -
# 7097  chrV     19521845    19531465           5|T>C|0.4  0.999408      -
# 7098  chrV     19882520    19887179   9|T>C|0.222222222  0.997310      -
# 7101  chrV     19887499    19888336           5|T>C|0.4  0.999408      -
# 7104  chrV     19890994    19892169           5|T>C|0.6  0.999996      -
# 7148  chrV     20251002    20251964          8|T>C|0.25  0.997969      -
# 7226  chrV     20331024    20335216   7|T>C|0.714285714  1.000000      -
# 7241  chrV     20498241    20499001  13|T>C|0.153846154  0.993825      -
# 7272  chrX      3029119     3030612          8|T>C|0.25  0.997969      -
# 7277  chrX      3106945     3107794           5|T>C|0.6  0.999996      -
# 7279  chrX      4767744     4768349   6|T>C|0.333333333  0.999020      -
# 7329  chrX      8183598     8185031           5|T>C|0.4  0.999408      -
# 7342  chrX     15269725    15270659   6|T>C|0.333333333  0.999020      -
# 7346  chrX     15988516    15989879   9|T>C|0.222222222  0.997310      -
# 7349  chrX     16749927    16750642   7|T>C|0.285714286  0.998540      -
# 7360  chrX     16903149    16904295           5|T>C|0.8  1.000000      -
#
# [387 rows x 6 columns]

# %% [markdown]
# #

# %%
outfile = os.path.join(wd,'WT.edited.jxc')
cmd = 'python {} '.format(junc)
cmd = cmd + '--bed {} '.format(edited_introns_bed)
cmd = cmd + '--bam {} '.format(bam)
cmd = cmd + '--min_overlap {} '.format(10)
cmd = cmd + '--library {} '.format('reverse_se')
cmd = cmd + '--outfile {}'.format(outfile)
! $cmd
# Out:
# 100%|#########################################| 387/387 [00:03<00:00, 97.01it/s]

# %% [markdown]
# # Emily's code goes here...

# %% [markdown]
# # Minor point 5
# ##### Can the authors speculate on why they identified 87 editing sites by Sanger sequencing that were not found by SAILOR? What does this say about the sensitivity of their pipeline? Possibly these sites would have been found using less stringent parameters?
# - use code from analysis notebook to gather the 87 sites

# %%
editing_sites.head()
# Out:
#   chrom   start    stop       name     score strand  \
# 0  chrI  454105  454106  5|A>G|0.8  1.000000      +
# 1  chrI  454110  454111  5|A>G|0.4  0.999408      +
# 2  chrI  454112  454113  5|A>G|0.6  0.999996      +
# 3  chrI  454117  454118  5|A>G|0.6  0.999996      +
# 4  chrI  454329  454330  5|A>G|0.4  0.999408      +
#
#                                             priority  \
# 0  C07F11.1:451461:455355:+:intron:WBGene00006593...
# 1  C07F11.1:451461:455355:+:intron:WBGene00006593...
# 2  C07F11.1:451461:455355:+:intron:WBGene00006593...
# 3  C07F11.1:451461:455355:+:intron:WBGene00006593...
# 4  C07F11.1:451461:455355:+:intron:WBGene00006593...
#
#                                           annotation  region intron_start  \
# 0  C07F11.1:443998:461605:+:transcript:WBGene0000...  intron       451460
# 1  C07F11.1:443998:461605:+:transcript:WBGene0000...  intron       451460
# 2  C07F11.1:443998:461605:+:transcript:WBGene0000...  intron       451460
# 3  C07F11.1:443998:461605:+:transcript:WBGene0000...  intron       451460
# 4  C07F11.1:443998:461605:+:transcript:WBGene0000...  intron       451460
#
#   intron_stop
# 0      455355
# 1      455355
# 2      455355
# 3      455355
# 4      455355

# %%
validation_comparisons = os.path.join(wd,'validation_comparisons.txt')
validated_df = pd.read_table(validation_comparisons)
vdf = validated_df.fillna('NONE')
print("Number of sites not captured by pipeline but discovered to be edited via sanger: {}".format(vdf[
    (vdf['Identified in Sanger Sequencing']=='Yes') &
    (vdf['0.0.3 % edited (RNA seq)']=='NONE')
].shape[0]))
print("Number of sites captured by pipeline AND discovered to be edited via sanger: {}".format(vdf[
    (vdf['Identified in Sanger Sequencing']=='Yes') &
    (vdf['0.0.3 % edited (RNA seq)']!='NONE')
].shape[0]))
# Out:
# Number of sites not captured by pipeline but discovered to be edited via sanger: 87
# Number of sites captured by pipeline AND discovered to be edited via sanger: 86

# %%
notfound = vdf[
    (vdf['Identified in Sanger Sequencing']=='Yes') &
    (vdf['0.0.3 % edited (RNA seq)']=='NONE')
][['Chromosome','Editing site position']]
notfound['start'] = notfound['Editing site position'].astype(int) -1
notfound['end'] = notfound['Editing site position'].astype(int)
notfound = notfound[['Chromosome','start','end']]
notfound.head()
# Out:
#    Chromosome    start      end
# 90       chrI  2033865  2033866
# 91       chrI  2033892  2033893
# 92       chrI  2033893  2033894
# 93       chrI  2034070  2034071
# 94       chrI  2034071  2034072

# %%
notfound_bed = os.path.join(wd,'validation_comparisons.notfound.bed')
notfound.to_csv(
    notfound_bed,
    sep='\t',
    index=False,
    header=False
)

# %% [markdown]
# # of the 87 sites, how many of them don't have sufficient coverage?

# %%
bam = '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/WT.bam'
outfile = os.path.join(wd,'depth.txt')
cmd = 'samtools depth '
cmd = cmd + '-b {} '.format(notfound_bed)
cmd = cmd + '{} '.format(bam) # bam is the original combined WT bam
cmd = cmd + '> {}'.format(outfile)
! $cmd

# %%
df = pd.read_table(outfile, names=['chrom','position','depth'])
print("number of sites with coverage greater than 100: {}".format(df[df['depth']>100].shape[0]))
print("number of sites with coverage less than 5: {}".format(df[df['depth']<5].shape[0]))

ax = df['depth'].hist(bins=300)
ax.set_xlim(0,100)
ax.set_xlabel('Depth')
ax.set_ylabel('Number of sites')
# Out:
# number of sites with coverage greater than 100: 19
# number of sites with coverage less than 5: 27

# %% [markdown]
# # Of the sites with sufficient coverage, how many just miss conf cutoff?
# - 30 sites had a confidence score, which means that it was an editing candidate. Of these:
#     - (1) site had a zero confidence score because it was 100% edited and was called as a possible snp
#     - 20 sites had a confidence score above 90%

# %%
# format the bedfile
out_filtered_bed = os.path.join(wd,'filtered.bed')
fwd_bed = os.path.join(
    editing_calls_dir, 'WT.fwd.sorted.rmdup.readfiltered.formatted.varfiltered.snpfiltered.ranked.bed'
)
rev_bed = os.path.join(
    editing_calls_dir, 'WT.rev.sorted.rmdup.readfiltered.formatted.varfiltered.snpfiltered.ranked.bed'
)

fwd = pd.read_table(fwd_bed, names=['chrom','start','end','name','score','strand'])
rev = pd.read_table(rev_bed, names=['chrom','start','end','name','score','strand'])

bed = pd.concat([fwd, rev])

df_sufficient_coverage = df[df['depth']>=5]
lowly_scored = pd.merge(
    df_sufficient_coverage, bed, how='left', 
    left_on=['chrom','position'], right_on=['chrom','end']
)
lowly_scored_90 = lowly_scored[lowly_scored['score']>0.9]
print("Number of sites that did not meet our cutoffs: {}".format(lowly_scored.dropna().shape[0]))
print("Number of sites that have greater than 90% confidence: {}".format(lowly_scored_90.shape[0]))
ax = lowly_scored.dropna()['score'].hist(bins=100)
ax.set_xlabel('Confidence')
ax.set_ylabel('Number of sites')
# Out:
# Number of sites that did not meet our cutoffs: 30
# Number of sites that have greater than 90% confidence: 20

# %%
others = lowly_scored.fillna(-1)
others = others[others['score']==-1]
others = others[['chrom','position','strand']]
others['position-1'] = others['position'] - 1
others['name'] = 'unscored'
others['score'] = 0
others = others[['chrom','position-1','position','name','score','strand']]
others.to_csv(os.path.join(wd,'unscored_editing_candidates.bed'),sep='\t', index=False, header=False)

# %%
# look at pileup of the other regions
out_file = os.path.join(wd,'unscored_editing_candidates.vcf')
cmd = 'samtools mpileup '
cmd = cmd + '--positions {} '.format(os.path.join(wd,'unscored_editing_candidates.bed'))
cmd = cmd + '-o {} '.format(out_file)
cmd = cmd + '-u '
cmd = cmd + '-v {}'.format(bam)
cmd
# Out:
# 'samtools mpileup --positions /projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/editor_response_minor_1/ws257/unscored_editing_candidates.bed -o /projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/editor_response_minor_1/ws257/unscored_editing_candidates.vcf -u -v /projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/WT.bam'

# %%
bam
# Out:
# '/projects/ps-yeolab3/bay001/hundley_rnae_20160210/analysis/rnae_v6/WT.bam'

# %%
import pandas as pd
import os
import numpy as np

# %%
df = pd.read_table(
    '/home/bay001/projects/codebase/rbp-maps/examples/se/RBFOX2-BGHLV26-HepG2-excluded-upon-knockdown'
)
df.head()
# Out:
#       ID              GeneID geneSymbol   chr strand  exonStart_0base  \
# 0  15020  ENSG00000160087.16     UBE2J2  chr1      -          1206889
# 1  21705  ENSG00000074964.12  ARHGEF10L  chr1      +         17961042
# 2   2287  ENSG00000159023.14      EPB41  chr1      +         29386933
# 3  45823  ENSG00000116350.11      SRSF4  chr1      -         29476614
# 4  40673  ENSG00000134686.12       PHC2  chr1      -         33800766
#
#     exonEnd  upstreamES  upstreamEE  downstreamES         ...          \
# 0   1207017     1203135     1203372       1209045         ...
# 1  17961057    17958815    17958961      17961329         ...
# 2  29386996    29379615    29379824      29391493         ...
# 3  29476704    29474254    29475738      29481207         ...
# 4  33800960    33799690    33799893      33815197         ...
#
#    SJC_SAMPLE_1  IJC_SAMPLE_2 SJC_SAMPLE_2 IncFormLen SkipFormLen    PValue  \
# 0         51,49           0,8        26,16        199         100  0.000585
# ...

# %%
# df['exonStart_0base'] = df['exonStart_0base'] + 1
df['exonEnd'] = df['exonEnd'] + 1
# df['upstreamES'] = df['upstreamES'] + 1
df['upstreamEE'] = df['upstreamEE'] + 1
# df['downstreamES'] = df['downstreamES'] + 1
df['downstreamEE'] = df['downstreamEE'] + 1

# %%
df.to_csv(
    '/home/bay001/projects/codebase/rbp-maps/examples/se/RBFOX2-BGHLV26-HepG2-excluded-upon-knockdown.0baseInclusive',
    sep='\t', index=False
)

# %%
import pandas as pd
import numpy as np
import os

# %%
pd.read_table(
    '/projects/ps-yeolab3/bay001/maps/current_annotations/se/TROVE2-BGHLV16-HepG2.set16.SE.MATS.JunctionCountOnly.significant.txt'
)[['IJC_SAMPLE_1','IJC_SAMPLE_2','SJC_SAMPLE_1','SJC_SAMPLE_2','IncLevelDifference']].sort_values('IncLevelDifference', ascending=False)
# Out:
#    IJC_SAMPLE_1 IJC_SAMPLE_2 SJC_SAMPLE_1 SJC_SAMPLE_2  IncLevelDifference
# 1         38,46        17,22        33,48        85,87               0.244
# 19       124,96       86,101        19,16        35,45               0.217
# 3       217,204      128,166        47,49       68,108               0.213
# 17          9,1          1,0         13,3        20,39               0.211
# 11      114,145      152,174        21,30        80,77               0.210
# 4         22,26         3,15        29,36        52,61               0.205
# 2       208,174      181,162      111,113      213,245               0.188
# 18      161,203      161,128        68,93      121,150               0.184
# 12      137,166      181,204        21,30        80,77               0.177
# 0         62,90        21,20      219,270      447,455               0.145
# 13         12,5          0,0        32,32        46,49               0.142
# ...

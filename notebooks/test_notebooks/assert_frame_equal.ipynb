# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
from pandas.util.testing import assert_frame_equal

# %%
df1 = pd.read_table(
    '/oasis/tscc/scratch/bay001/parp13_20171015/shashank/KO_Arsenite_vs_293_WT_deseq2_results.csv',
    sep=',', index_col=0
)
df1.sort_index(inplace=True)
print(df1.shape)
df1.head()
# Out:
# (19927, 6)
#                        baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003.10  1192.966631        0.275676  0.113575  2.427251  0.015214
# ENSG00000000005.5     11.378028       -1.290347  0.731324 -1.764398  0.077665
# ENSG00000000419.8   1102.933177        0.237184  0.099967  2.372626  0.017662
# ENSG00000000457.9    407.010774       -0.389379  0.159173 -2.446265  0.014434
# ENSG00000000460.12   562.526193        0.010158  0.157602  0.064454  0.948609
#
#                         padj
# ENSG00000000003.10  0.151355
# ENSG00000000005.5   0.392004
# ENSG00000000419.8   0.166487
# ENSG00000000457.9   0.146454
# ENSG00000000460.12  0.988557

# %%
df2 = pd.read_table(
    '/home/bay001/projects/parp13_ago2_20171015/permanent_data/chang_newdata/deseq2/20171107/ko_vs_wt/counts.Arsenite.multimap.diffexp.txt',
    sep=',', index_col=0
)
print(df2.shape)
df2.sort_index(inplace=True)
df2.head()
# Out:
# (19927, 6)
#                        baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003.10  1192.966631        0.275655  0.145353  1.896444  0.057901
# ENSG00000000005.5     11.378028       -1.291572  0.835014 -1.546767  0.121920
# ENSG00000000419.8   1102.933177        0.237191  0.143591  1.651858  0.098564
# ENSG00000000457.9    407.010774       -0.389391  0.184771 -2.107426  0.035081
# ENSG00000000460.12   562.526193        0.010153  0.173780  0.058426  0.953409
#
#                         padj
# ENSG00000000003.10  0.463673
# ENSG00000000005.5   0.632572
# ENSG00000000419.8   0.582293
# ENSG00000000457.9   0.356115
# ENSG00000000460.12  0.995455

# %%
df3 = pd.read_table(
    '/home/bay001/projects/parp13_ago2_20171015/permanent_data/chang_newdata/deseq2/20171107/ko_vs_wt_useallcounts/counts.Arsenite.multimap.diffexp.txt',
    sep=',', index_col=0
)
print(df3.shape)
df3.sort_index(inplace=True)
df3.head()
# Out:
# (38955, 6)
#                        baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSG00000000003.10  1122.107693        0.272599  0.151506  1.799262  0.071977
# ENSG00000000005.5      8.462827       -1.294811  0.807375 -1.603730  0.108774
# ENSG00000000419.8    980.925660        0.234061  0.154715  1.512856  0.130316
# ENSG00000000457.9    347.453731       -0.392381  0.164236 -2.389121  0.016889
# ENSG00000000460.12   517.991579        0.007186  0.155698  0.046155  0.963187
#
#                         padj
# ENSG00000000003.10  0.858087
# ENSG00000000005.5   1.000000
# ENSG00000000419.8   1.000000
# ENSG00000000457.9   0.399212
# ENSG00000000460.12  1.000000

# %%
# assert_frame_equal(df1,df2)

# %%
pd.merge(df1[['log2FoldChange']], df3[['log2FoldChange']], how='outer', left_index=True, right_index=True).corr()
# Out:
#                   log2FoldChange_x  log2FoldChange_y
# log2FoldChange_x               1.0               1.0
# log2FoldChange_y               1.0               1.0

# %%
pd.merge(df1[['padj']], df2[['padj']], how='inner', left_index=True, right_index=True).corr()
# Out:
#           padj_x    padj_y
# padj_x  1.000000  0.945947
# padj_y  0.945947  1.000000

# %% [markdown]
# # Norm count correlaton

# %%
df1 = pd.read_table(
    '/oasis/tscc/scratch/bay001/parp13_20171015/shashank/KO_Arsenite_vs_293_WT_deseq2_normalized_counts.csv',
    sep=',', index_col=0
)
df1.sort_index(inplace=True)
print(df1.shape)
df1.head()
# Out:
# (19927, 4)
#                     X293_PARP13_KO_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1327.255572
# ENSG00000000005.5                                            3.385856
# ENSG00000000419.8                                         1202.825362
# ENSG00000000457.9                                          363.979525
# ENSG00000000460.12                                         590.831881
#
#                     X293_PARP13_KO_Arsenite_rep2.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1285.895968
# ENSG00000000005.5                                            9.784877
# ENSG00000000419.8                                         1183.970162
# ENSG00000000457.9                                          340.839895
# ENSG00000000460.12                                         538.168256
#
#                     X293_WT_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1131.214179
# ENSG00000000005.5                                           15.711308
# ENSG00000000419.8                                         1018.817899
# ENSG00000000457.9                                          500.344733
# ENSG00000000460.12                                         610.323889
#
#                     X293_WT_Arsenite_rep2.polyATrim.adapterTrim.rmRep.sorted.rg.bam
# ENSG00000000003.10                                        1027.500805
# ENSG00000000005.5                                           16.630071
# ENSG00000000419.8                                         1006.119286
# ENSG00000000457.9                                          422.878944
# ENSG00000000460.12                                         510.780747

# %%
df2 = pd.read_table(
    '/home/bay001/projects/parp13_ago2_20171015/permanent_data/chang_newdata/deseq2/20171107/ko_vs_wt_useallcounts/counts.Arsenite.multimap.diffexp.txt.norm_counts',
    sep=',', index_col=0
)
print(df2.shape)
df2.sort_index(inplace=True)
df2.head()
# Out:
# (38955, 10)
#                     X293_PARP13_KO_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1263.446351
# ENSG00000000005.5                                            3.223077
# ENSG00000000419.8                                         1144.998256
# ENSG00000000457.9                                          346.480823
# ENSG00000000460.12                                         562.427011
#
#                     X293_PARP13_KO_Arsenite_rep2.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1222.246656
# ENSG00000000005.5                                            9.300545
# ENSG00000000419.8                                         1125.365976
# ENSG00000000457.9                                          323.968993
# ENSG00000000460.12                                         511.529989
#
#                     X293_PARP13_KO_CAAX_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1175.652403
# ENSG00000000005.5                                            2.165106
# ENSG00000000419.8                                         1028.425214
# ENSG00000000457.9                                          336.673939
# ENSG00000000460.12                                         530.450900
#
#                     X293_PARP13_KO_CAAX_Arsenite_rep2.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                         891.223096
# ENSG00000000005.5                                            4.395675
# ENSG00000000419.8                                          750.561497
# ENSG00000000457.9                                          313.191840
# ENSG00000000460.12                                         473.633976
#
#                     X293_PARP13_KO_Q_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1268.948481
# ENSG00000000005.5                                            9.454086
# ENSG00000000419.8                                         1078.816300
# ENSG00000000457.9                                          324.590299
# ENSG00000000460.12                                         503.167485
#
#                     X293_PARP13_KO_Q_Arsenite_rep2.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1113.427148
# ENSG00000000005.5                                            8.050811
# ENSG00000000419.8                                          949.995687
# ENSG00000000457.9                                          312.371463
# ENSG00000000460.12                                         515.251898
#
#                     X293_PARP13_KO_WT_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1066.774685
# ENSG00000000005.5                                            9.546082
# ENSG00000000419.8                                          928.356493
# ENSG00000000457.9                                          317.407233
# ENSG00000000460.12                                         532.194082
#
#                     X293_PARP13_KO_WT_Arsenite_rep2.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1161.604232
# ENSG00000000005.5                                            7.661034
# ENSG00000000419.8                                          872.400211
# ENSG00000000457.9                                          319.848156
# ENSG00000000460.12                                         482.645122
#
#                     X293_WT_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam  \
# ENSG00000000003.10                                        1076.981550
# ENSG00000000005.5                                           14.958077
# ENSG00000000419.8                                          969.973767
# ENSG00000000457.9                                          476.357224
# ENSG00000000460.12                                         581.063763
#
#                     X293_WT_Arsenite_rep2.polyATrim.adapterTrim.rmRep.sorted.rg.bam
# ENSG00000000003.10                                         980.772331
# ENSG00000000005.5                                           15.873772
# ENSG00000000419.8                                          960.363196
# ENSG00000000457.9                                          403.647341
# ENSG00000000460.12                                         487.551563

# %%
dfx = pd.merge(
    df1[['X293_PARP13_KO_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam']], 
    df2[['X293_PARP13_KO_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam']],
    left_index=True, right_index=True
)
dfx.corr()
# Out:
#                                                     X293_PARP13_KO_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam_x  \
# X293_PARP13_KO_Arsenite_rep1.polyATrim.adapterT...                                                1.0
# X293_PARP13_KO_Arsenite_rep1.polyATrim.adapterT...                                                1.0
#
#                                                     X293_PARP13_KO_Arsenite_rep1.polyATrim.adapterTrim.rmRep.sorted.rg.bam_y
# X293_PARP13_KO_Arsenite_rep1.polyATrim.adapterT...                                                1.0
# X293_PARP13_KO_Arsenite_rep1.polyATrim.adapterT...                                                1.0

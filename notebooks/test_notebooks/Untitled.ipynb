# %%
import pandas as pd

# %%
df1 = pd.read_table('/home/bay001/projects/codebase/batch_correction/scran/data/pbmc_10X.expressionMatrix.txt.normed.txt', sep='\t')
df1.head()
# Out:
#               AAACATACAACCAC  AAACATTGAGCTAC  AAACATTGATCAGC  AAACCGTGCTTCCG  \
# MIR1302-10               0.0             0.0             0.0             0.0
# FAM138A                  0.0             0.0             0.0             0.0
# OR4F5                    0.0             0.0             0.0             0.0
# RP11-34P13.7             0.0             0.0             0.0             0.0
# RP11-34P13.8             0.0             0.0             0.0             0.0
#
#               AAACCGTGTATGCG  AAACGCACTGGTAC  AAACGCTGACCAGT  AAACGCTGGTTCTT  \
# MIR1302-10               0.0             0.0             0.0             0.0
# FAM138A                  0.0             0.0             0.0             0.0
# OR4F5                    0.0             0.0             0.0             0.0
# RP11-34P13.7             0.0             0.0             0.0             0.0
# RP11-34P13.8             0.0             0.0             0.0             0.0
#
# ...

# %%
df2 = pd.read_table('/home/bay001/projects/codebase/batch_correction/scran/data/pbmc_10X.expressionMatrix.txt.normed.txt', sep='\t')
df2.head()
# Out:
#               AAACATACAACCAC  AAACATTGAGCTAC  AAACATTGATCAGC  AAACCGTGCTTCCG  \
# MIR1302-10               0.0             0.0             0.0             0.0
# FAM138A                  0.0             0.0             0.0             0.0
# OR4F5                    0.0             0.0             0.0             0.0
# RP11-34P13.7             0.0             0.0             0.0             0.0
# RP11-34P13.8             0.0             0.0             0.0             0.0
#
#               AAACCGTGTATGCG  AAACGCACTGGTAC  AAACGCTGACCAGT  AAACGCTGGTTCTT  \
# MIR1302-10               0.0             0.0             0.0             0.0
# FAM138A                  0.0             0.0             0.0             0.0
# OR4F5                    0.0             0.0             0.0             0.0
# RP11-34P13.7             0.0             0.0             0.0             0.0
# RP11-34P13.8             0.0             0.0             0.0             0.0
#
# ...

# %%
print(df2.shape)
print(df2.dropna().shape)
# Out:
# (32738, 2638)
# (29613, 2638)

# %%
import h5py

# %%
f = h5py.File("file.h5", "w")

# %%
f.create_dataset()

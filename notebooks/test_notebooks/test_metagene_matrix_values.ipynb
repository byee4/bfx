# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_table(
    '/home/bay001/projects/codebase/rbp-maps/examples/metagene/204_01.metagene.cell.normed_matrix.txt',
    sep=',',
    index_col=0
)
df.sum(axis=1).sort_values(ascending=False).head()
# Out:
# ENSG00000272658.1     53.765152
# ENSG00000073060.11    33.178571
# ENSG00000115317.7     27.414141
# ENSG00000169718.13    26.681818
# ENSG00000109184.10    25.969328
# dtype: float64

# %%
plt.scatter(range(161), pd.DataFrame(df.ix['ENSG00000272658.1']))

# %%
fig, ax = plt.subplots(figsize=(25,25))
sns.heatmap(df, yticklabels=False, xticklabels=False, cmap='Blues', ax=ax)

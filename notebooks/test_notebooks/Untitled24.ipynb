# %%
import pandas as pd

# %%
df = pd.read_table(
    '/home/bay001/projects/laura_kristin_HuR_20180925/permanent_data/mm9/for_kristin_20190125/outputs/eCLIP_GO/CML_eCLIP_GO.go.all.txt'
)
df
# Out:
#      GO term accession                                GO Term Description  \
# 0           GO:0060216                             definitive hemopoiesis
# 1           GO:0005634                                            nucleus
# 2           GO:0005515                                    protein binding
# 3           GO:0000166                                 nucleotide binding
# 4           GO:0005737                                          cytoplasm
# 5           GO:0003723                                        RNA binding
# 6           GO:0003677                                        DNA binding
# 7           GO:0006355         regulation of transcription, DNA-dependent
# 8           GO:0006397                                    mRNA processing
# 9           GO:0045944  positive regulation of transcription from RNA ...
# 10          GO:0003682                                  chromatin binding
# 11          GO:0005524                                        ATP binding
# ...

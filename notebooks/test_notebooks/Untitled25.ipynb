# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
df = pd.read_table('/home/ndefores/scratch/raw_data/hnRBPA2_B1/WT_hnRNPA2_B1/hnRNPA2B1_Fernando_eCLIPs.tsv')
df.head()
# Out:
#    Unnamed: 0 Hiseq_file_name                 ENCODE_ID        RBP inline_1  \
# 0          92      F1_IN_A2B1  F1_IN_mnCLIP_A2B1_high_1  hnRNPA2B1     none
# 1          93      F1_IP_A2B1  F1_IP_mnCLIP_A2B1_high_1  hnRNPA2B1      A01
# 2          94      F2_IN_A2B1  F2_IN_mnCLIP_A2B1_high_2  hnRNPA2B1     none
# 3          95      F2_IP_A2B1  F2_IP_mnCLIP_A2B1_high_2  hnRNPA2B1      C01
# 4          96      F3_IN_A2B1   F3_IN_mnCLIP_A2B1_med_1  hnRNPA2B1     none
#
#    inline_2  index_1  index_2  Lane  \
# 0      none      501      701  L008
# 1       B06      501      702  L008
# 2      none      501      703  L008
# 3  D08fixed      501      704  L008
# 4      none      501      705  L008
#
#                                        file_location  \
# 0  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 1  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 2  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# 3  /projects/ps-yeolab/seqdata/igm-storage1.ucsd....
# ...

# %%
df.ix[6,['r1']].values
# Out:
# array(['/projects/ps-yeolab/seqdata/igm-storage1.ucsd.edu/150406_D00611_0100_AC6DB4ANXX/Data/Unaligned_L5/Project_C6DB4ANXX/Sample_F4_IN_A2B1/F4_IN_A2B1_ATTACTCG-ATAGAGGC_L008_R1.fastq.gz'],
#       dtype=object)

# %%
df.ix[5,['file_location']].values
# Out:
# array(['/projects/ps-yeolab/seqdata/igm-storage1.ucsd.edu/150406_D00611_0100_AC6DB4ANXX/Data/Unaligned_L5/Project_C6DB4ANXX'],
#       dtype=object)

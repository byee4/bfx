# %%
# %matplotlib inline
import pandas as pd
from matplotlib_venn import venn2

# %%
no = pd.read_table(
    '/home/bay001/projects/nazia_clipseq_20170627/permanent_data/eCLIP-0.1.5/idr/GT_T1.compressed.bed.entropy.full',
    names=['chrom','start','end','name','ipreads','inpreads',
           '.','.','.','.','l10p','l2fc','.']
)
no.head()
# Out:
#   chrom      start        end                            name  ipreads  \
# 0  chr7  130834476  130834480  chr7:130834476-130834480:+:0.0    13868
# 1  chr7  130834468  130834476  chr7:130834468-130834476:+:0.0    16645
# 2  chr7  130834446  130834468  chr7:130834446-130834468:+:0.0    21123
# 3  chr7  130834437  130834446  chr7:130834437-130834446:+:0.0    20426
# 4  chr7  123220025  123220035  chr7:123220025-123220035:+:0.0      580
#
#    inpreads             .               ..1 ..2       ..3        l10p  \
# 0       136  0.000000e+00  4882.58921094515   C  enriched  400.000000
# 1       194  0.000000e+00  5793.99786647215   C  enriched  400.000000
# 2       467  0.000000e+00   6870.6738829261   C  enriched  400.000000
# 3       462  0.000000e+00  6620.42590878783   C  enriched  400.000000
# 4         1  1.930091e-78                 F   F  enriched   77.714422
#
#        l2fc       ..4
# 0  5.252967  0.020525
# 1  5.003846  0.023466
# 2  4.080206  0.024283
# 3  4.047328  0.023292
# 4  7.760867  0.001268

# %%
no = no[(no['l10p']>=3) & (no['l2fc']>=3)]
no.sort_values(by=['chrom','start','end']).head()
# Out:
#       chrom     start       end                                         name  \
# 14961  chr1  10232276  10232328   chr1:10232276-10232328:-:1.30309084567e-99
# 15007  chr1  10232600  10232653   chr1:10232600-10232653:-:3.34563398246e-34
# 15015  chr1  13372431  13372461   chr1:13372431-13372461:-:3.20343676235e-38
# 14929  chr1  13372850  13372923  chr1:13372850-13372923:-:6.01299051983e-180
# 14926  chr1  13372970  13373047  chr1:13372970-13373047:-:2.14887933237e-193
#
#        ipreads  inpreads             . ..1 ..2       ..3       l10p      l2fc  \
# 14961       71         1  5.073896e-09   F   F  enriched   8.294658  4.730705
# 15007       44         2  1.003234e-04   F   F  enriched   3.998598  3.040389
# 15015       35         1  2.412996e-04   F   F  enriched   3.617443  3.710241
# 14929      125         1  2.950125e-16   F   F  enriched  15.530160  5.546742
# 14926      133         1  2.732818e-17   F   F  enriched  16.563389  5.636240
#
#             ..4
# 14961  0.000095
# 15007  0.000038
# 15015  0.000037
# 14929  0.000195
# 14926  0.000211

# %%
np = pd.read_table(
    '/home/bay001/projects/nazia_clipseq_20170627/permanent_data/eCLIP-0.1.5/clip_analysis/20171121/GT.IP_T1.---.r-.fqTrTrU-SoMaSoCoSoMeV2ClNpCoFc3Pv3.bed.thickStartEnd.bed',
    names=['chrom','start','end','name','score','strand','tstart','tend']
)
np.shape
# Out:
# (3528, 8)

# %%
np.sort_values(by=['chrom','start','end']).head()
# Out:
#     chrom     start       end       name     score strand    tstart      tend
# 517  chr1  10232276  10232328   8.294658  4.730734      -  10232276  10232328
# 558  chr1  10232600  10232653   3.998598  3.040407      -  10232600  10232653
# 563  chr1  13372431  13372461   3.617443  3.710255      -  13372431  13372461
# 491  chr1  13372850  13372923  15.306348  5.535205      -  13372850  13372923
# 488  chr1  13372970  13373047  16.563389  5.636294      -  13372970  13373047

# %%
npstart = set(np['start'])
nostart = set(no['start'])

# %%
venn2([npstart, nostart], ['Gabe','Eric'])
# Out:
# <matplotlib_venn._common.VennDiagram instance at 0x2b77c39de2d8>

# %% [markdown]
# # peaks mostly overlap... but I suspect that the V3 (gabe's version) is cutting out peaks that should be kept in.

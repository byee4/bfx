# %%
import pandas as pd

# %%
df1 = pd.read_table(
    '/home/bay001/projects/nazia_clipseq_20170627/permanent_data/eCLIP-0.1.5/idr/GT_T1.idrpeaks_inputnormed_01.bed',
    names=['chrom','start','end','name','score','strand']
)
df1[(df1['name']>=3) & (df1['score']>=3)].shape
# Out:
# (4287, 6)

# %%
df1 = pd.read_table(
    '/home/bay001/projects/nazia_clipseq_20170627/permanent_data/eCLIP-0.1.5/idr/GT_T2.idrpeaks_inputnormed_02.bed',
    names=['chrom','start','end','name','score','strand']
)
df1[(df1['name']>=3) & (df1['score']>=3)].shape
# Out:
# (13914, 6)

# %%
pd.read_table(
    '/home/bay001/projects/nazia_clipseq_20170627/permanent_data/eCLIP-0.1.7/00_QC/outputs/T.annotated.csv',
    sep=','
)
# Out:
#         Unnamed: 0  Input Reads Round 1  Reads Written Round 2  \
# 0  GT.INPUT_T1.NIL            5109023.0              5044198.0
# 1  GT.INPUT_T2.NIL           22851278.0             21767825.0
# 2     GT.IP_T1.---                  NaN                    NaN
# 3     GT.IP_T1.C01           27703396.0             25961028.0
# 4     GT.IP_T1.D8f            9391730.0              9010984.0
# 5     GT.IP_T2.---                  NaN                    NaN
# 6     GT.IP_T2.A01            5837772.0              5366592.0
# 7     GT.IP_T2.B06            4634808.0              4300001.0
#
#    Repetitive Reads  Reads Passing Quality Filter  Uniquely Mapped Reads  \
# 0         1703499.0                     3340699.0              1366721.0
# 1         6435026.0                    15332799.0              7985626.0
# 2               NaN                           NaN                    NaN
# 3         9311895.0                    16649133.0              3325570.0
# ...

# %%
pd.read_table(
    '/home/bay001/projects/nazia_clipseq_20170627/permanent_data/eCLIP-0.1.7/00_QC/outputs/DDX5.annotated.csv',
    sep=','
)
# Out:
#       Unnamed: 0  Input Reads Round 1  Reads Written Round 2  \
# 0  DDX5.INP1.NIL           24229575.0             23228599.0
# 1  DDX5.INP2.NIL           21200247.0             20195364.0
# 2  DDX5.REP1.---                  NaN                    NaN
# 3  DDX5.REP1.A01           14976050.0             14599377.0
# 4  DDX5.REP1.B06           14964679.0             14626153.0
# 5  DDX5.REP2.---                  NaN                    NaN
# 6  DDX5.REP2.C01           13383192.0             13001893.0
# 7  DDX5.REP2.D8f            8913534.0              8742112.0
#
#    Repetitive Reads  Reads Passing Quality Filter  Uniquely Mapped Reads  \
# 0         3961895.0                    19266704.0              5903304.0
# 1         2434577.0                    17760787.0              5406008.0
# 2               NaN                           NaN                    NaN
# 3         6215517.0                     8383860.0              1742921.0
# ...

# %%
df = pd.read_table(
    '/home/bay001/projects/nazia_clipseq_20170627/permanent_data/eCLIP-0.1.7/pipeline_outputs/GT_T/results/finals/'
)

# %% [markdown]
# # Basic download from encode script.
# - Current stats as of 2-28:
#     - 526 Hg19 bams total (254 HepG2, 272 K562).
#     - 474 Hg19 bams (230 HepG2, 244 K562)
#     - 52 control Hg19 bams (24 HepG2, 28 K562)
#     - 2 missing possible controls (TIA1 K562 and PPIL4 K562)

# %%
import pandas as pd
import urllib
import json
import requests
import os
from collections import defaultdict
import qtools
from tqdm import tnrange, tqdm_notebook

pd.set_option("display.max_columns",500)
host = 'https://www.encodeproject.org'
experiments = "https://www.encodeproject.org/experiments/"
date = '3-9-2017'
annotated_manifest_hepg2 = '/home/bay001/projects/maps_20160420/permanent_data/RNASeq_final_exp_list_HepG2.csv'
annotated_manifest_k562 = '/home/bay001/projects/maps_20160420/permanent_data/RNASeq_final_exp_list_K562.csv'
downloaded_dir = '/projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/'
aligner = 'ambiguous' # graveley lab pipeline doesn't adhere to the same file name structure as encode processing pipeline, but we trust that it's all tophat-aligned.
lab = 'brenton-graveley' # or 'encode-processing-pipeline'

# %% [markdown]
# # Do some checks on how many samples we have from the two lists.

# %%
hepg2_df = pd.read_table(annotated_manifest_hepg2)
k562_df = pd.read_table(annotated_manifest_k562)

print("number of k562 rnaseq: ",k562_df.shape[0])
print("number of RBPs in K562",len(set(k562_df['Official_RBP'])))
print("number of Expts in K562",len(set(k562_df['RNA-Seq on K562'])))
print("number of Expts in Hepg2",len(set(hepg2_df['RNA-Seq on HepG2'])))
print("number of hepg2 rnaseq: ",hepg2_df.shape[0])
print("number of RBPs in Hepg2",len(set(hepg2_df['Official_RBP'])))
hepg2_df.head()
# Out:
# ('number of k562 rnaseq: ', 224)
# ('number of RBPs in K562', 224)
# ('number of Expts in K562', 224)
# ('number of Expts in Hepg2', 228)
# ('number of hepg2 rnaseq: ', 228)
# ('number of RBPs in Hepg2', 228)
#   Official_RBP      GENCODE_v19_ID       target    RBP RNA-Seq on HepG2  \
# 0         AARS  ENSG00000090861.11   AARS-human   AARS      ENCSR547NWD
# 1         AATF   ENSG00000108270.6   AATF-human   AATF      ENCSR424YSV
# 2        ABCF1   ENSG00000204574.8  ABCF1-human  ABCF1      ENCSR610VTA
# 3         ACO1  ENSG00000122729.14   ACO1-human   ACO1      ENCSR511SYK
# 4         ADAR  ENSG00000160710.11   ADAR-human   ADAR      ENCSR104OLN
#
#                    EXP
# 0   AARS-BGHLV17-HepG2
# 1   AATF-BGHLV14-HepG2
# 2  ABCF1-BGHLV30-HepG2
# 3   ACO1-BGHLV31-HepG2
# 4   ADAR-BGHLV20-HepG2

# %%
def star_or_tophat(link):
    """
    from the link, reads and returns whether or not STAR or TOPHAT are in the filename.
    """
    # print("LINK",os.path.basename(link))
    if os.path.basename(link).find('star') > -1:
        return 'STAR'
    if os.path.basename(link).find('tophat') > -1:
        return 'TOPHAT'
    return 'ambiguous'

def exists(fpath, current):
    """
    returns whether or not the file (fpath) exists in the directory(current)
    """
    base = os.path.basename(fpath.rstrip())
    if not os.path.exists(os.path.join(current,fpath)):
        return False
    else:
        return True
    
def exists_and_return_fullpath(fpath, current):
    """
    returns whether or not the file (fpath) exists in the directory(current)
    """
    base = os.path.basename(fpath.rstrip())
    if not os.path.exists(os.path.join(current,fpath)):
        return False
    else:
        return os.path.join(current,fpath)
    
def get_bams_from_expt_id(
    expt_id, assembly, aligner, lab
):
    """
    Given an expt id, return a list: [rbp name, [rep1bam, rep2bam], control_expt_id]
    
    control_expt_id is None if the expt_id given to this function is itself a control.
    
    """
    sample_bams = []
    control_expts = []
    
    experiments = "https://www.encodeproject.org/experiments/"
    url = experiments+expt_id+"/?format=json"
    response = urllib.urlopen(url)
    data = json.loads(response.read())
    if 'code' in data.keys():
        next
    else:
        for i in range(0,len(data['files'])):
            
            if (
                (host+data['files'][i]['href']).endswith('bam') & 
                (data['files'][i]['output_type'] == u'alignments') &
                (data['files'][i]['lab'][u'name'] == lab) &
                (star_or_tophat(data['files'][i]['submitted_file_name']) == aligner)
            ):
                if(data['files'][i]['assembly'] == assembly):
                    sample_bams.append(
                        {
                            os.path.basename(data['files'][i]['href']):data['files'][i]['md5sum']
                        }
                    )
        try:
            control_expts.append(data['possible_controls'][0]['accession'])
        except IndexError:
            pass
            # print("this is a control")
    if(len(control_expts) > 1):
        print("Warning, this expt {} has more than 1 associated control expt".format(expt_id))
    return data['target']['label'], sample_bams, control_expts

def make_expt_dataframe_from_expt_list(expt_list, assembly='hg19', aligner='STAR', lab='encode-processing-pipeline'):
    """
    Given a list of expt ids, return the reps and controls (and md5sums in case we need to check)
    """
    x = tnrange(len(expt_list))
    samples = defaultdict(dict)
    for h in expt_list:
        x.update(1)
        sname, s, control_expt = get_bams_from_expt_id(
            h, assembly, aligner, lab
        ) # gets the sample name, sample, and control expt id
        cname, c, _ = get_bams_from_expt_id(
            control_expt[0], assembly, aligner, lab
        ) # gets the control name, control
        for i in range(0,len(s)):
            samples_key = 'expt_rep{}'.format(i+1)
            samples_md5sum_key = 'expt_rep{}_md5sum'.format(i+1)
            control_key = 'control_rep{}'.format(i+1)
            controls_md5sum_key = 'control_rep{}_md5sum'.format(i+1)
            name_key = 'name'
            samples[h][name_key] = sname
            samples[h][samples_key] = s[i].keys()[0]
            samples[h][control_key] = c[i].keys()[0]
            samples[h][samples_md5sum_key] = s[i].values()[0]
            samples[h][controls_md5sum_key] = c[i].values()[0]
    bams = pd.DataFrame(samples).T
    return bams

# %% [markdown]
# # Make a list of expt IDs

# %%
hepg2_expts = list(set(hepg2_df['RNA-Seq on HepG2']))
k562_expts = list(set(k562_df['RNA-Seq on K562']))

# %%
hepg2_bams = make_expt_dataframe_from_expt_list(hepg2_expts)
k562_bams = make_expt_dataframe_from_expt_list(k562_expts)
print(hepg2_bams.shape)
print(k562_bams.shape)
# Out:
# (228, 9)
# (224, 9)

# %%
hepg2_bams.to_csv(
    '/projects/ps-yeolab3/encode/hepg2_{}_{}_bams_for_integrated_analysis.txt'.format(lab, aligner),sep='\t'
)
k562_bams.to_csv(
    '/projects/ps-yeolab3/encode/k562_{}_{}_bams_for_integrated_analysis.txt'.format(lab, aligner),sep='\t'
)

# %% [markdown]
# # Check md5sum and file existance.
# - If I've done this once, I don't need to do it again.

# %%
def already_checked_md5sum(filepath, md5sum_checked_file):
    """
    given filepaths list, check the md5sum_checked_file to see if any file has been checked.
    Parameters
    ----------
    filepath : list
        list of files
    md5sum_checked_file : file
        dataframe of files
        
    returns list of files that haven't been checked.
    """
    exists_in_file = ! grep $filepath $md5sum_checked_file
    if len(exists_in_file) > 0:
        if "no such file" not in exists_in_file[0]:
            # print(exists_in_file)
            return True
        else:
            return False
    else:
        return False

def is_md5sum_equal(row, rep, downloaded_dir):
    """
    Takes a row in a bams dataframe and the rep prefix and determines
    whether or not the md5sum is equal to what has been downloaded.
    """
    website_md5sum = row['{}_md5sum'.format(rep)]
    filepath = exists_and_return_fullpath(row[rep],downloaded_dir)
    calculated_md5sum = ! md5sum $filepath
    if website_md5sum != calculated_md5sum[0].split(' ')[0]:
        print('TROUBLE: {}, {}, {}'.format(filepath, website_md5sum, calculated_md5sum))
        return False
    else:
        return True
    
def check_all_bams_for_existance(bams, downloaded_dir, to_download_file='download.sh'):
    """
    Writes and prints the files that don't exist to a file
    
    Parameters
    ----------
    bams : pandas.DataFrame
        dataframe of bams with columns defined in cols.
    to_download_file : string
        file to download (download.sh)
        
    """
    encodeproject_prefix = 'https://www.encodeproject.org/files/'
    o = open(to_download_file,'w')
    cols = ['expt_rep1','expt_rep2','control_rep1','control_rep2']
    for unused,row in bams.iterrows():
        for c in cols:
            if not(exists(row[c],downloaded_dir)):
                # print(row[c], " doesn't exist.")
                print("mv /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown/{} ./".format(row[c]))
                o.write(
                    encodeproject_prefix + "{}/@@download/{}\n".format(
                        os.path.splitext(row[c])[0],
                        row[c]
                    )
                )
    o.close()
    
def check_md5sums(bams, downloaded_dir, md5sums_checked_file):
    """
    Checks the md5sums of the bams file
    """
    cols = ['expt_rep1','expt_rep2','control_rep1','control_rep2']
    x = tnrange(bams.shape[0])
    
    for _, row in bams.iterrows():
        x.update(1)
        for t in tnrange(len(cols), leave=False):
            c = cols[t]
            filepath = exists_and_return_fullpath(row[c], downloaded_dir)
            if filepath:
                if not already_checked_md5sum(
                    os.path.join(downloaded_dir,row[c]),
                    md5sums_checked_file
                ):
                    if is_md5sum_equal(row, c, downloaded_dir):
                        with open(md5sums_checked_file,'a') as o:
                            o.write(os.path.join(downloaded_dir,row[c]) + '\n')
                    else:
                        print(row[c], "needs to be downloaded again.")

# %% [markdown]
# # Check for existence of file, otherwise create a list to download.

# %%
# use: xargs -n 1 curl -O -L < FILE to download these...
def check_all_bams():
    download_hepg2_file = '/projects/ps-yeolab3/encode/rnaseq/shrna_knockdown/to_download_{}_hepg2_{}_{}'.format(aligner,lab,date)
    download_k562_file = '/projects/ps-yeolab3/encode/rnaseq/shrna_knockdown/to_download_{}_k562_{}_{}'.format(aligner,lab,date)
    check_all_bams_for_existance(hepg2_bams, downloaded_dir, download_hepg2_file)
    check_all_bams_for_existance(k562_bams, downloaded_dir, download_k562_file)

# %%
check_all_bams()

# %% [markdown]
# # Check md5sum of the ones we need to download (or just all of them)

# %%
# periods indicate row progress, commas indicate rep progress
# ENCSR916WOI  ENCFF529ZHW.bam  d063a40258df81222e50ecb4541edd09     TRA2A
# ENCSR921KDS  ENCFF441MQQ.bam  0b0e42513f0ba5112c1985b48758df64      RCC2
# ENCSR925RNE  ENCFF246KQB.bam  ec457fe555f6ec387e7a8c0fe9a1f3cc    SERBP1
# ENCSR927TSP  ENCFF953IZH.bam  da69132c7ea9b318b233bf7be0761f00     TIAL1
# ENCSR927XBT  ENCFF204APB.bam  a6b0a23a6f0d1e2123f63603d560f751    NUSAP1
# ENCSR943LIB  ENCFF193SZZ.bam  4ff32e805f86a74f5568acfd9e4e1513  SNRNP200
# ENCSR945GUR  ENCFF414BQP.bam  8bf7422814bfd2a5b02d2f93ea920fa3     NAA15
# ENCSR947OIM  ENCFF535LRB.bam  c239ace2a2ffd38702a3b4dce7bcb008     RBM22
# ENCSR952QDQ  ENCFF371TVY.bam  1480adf72f3817db30575c1620320c61    METAP2
# ENCSR952RRH  ENCFF519XDG.bam  685a67ae00026fc05d7c666f4f064fa0   IGF2BP2
# ENCSR954HAY  ENCFF488MVU.bam  d75cfc2683f51a0fe04253a7781d69a3     SART3
# ENCSR958NDU  ENCFF836SGI.bam  fb47f84207a8625d73c8429b8cf04902      HLTF
# ENCSR961YAG  ENCFF211TCF.bam  e86966f0ca77facf5a3e23a1e7e77cb1    EIF4A3
# ENCSR963RLK  ENCFF236LSH.bam  5215d582d345555b249236d2b2dacb26  APOBEC3C
# ENCSR967QNT  ENCFF152ZSQ.bam  a7174bf579eb5598c49c08c65e95508b     GPKOW
# ENCSR973QSV  ENCFF437YII.bam  1f14fc46203bf78bb751a111db534b5b      AATF
# ENCSR978CSQ  ENCFF085ZVA.bam  3bb1915140afe5dd27a729492f6cb158       PKM
# ENCSR984CLJ  ENCFF144BCM.bam  87325cbdf7c098259f835f4826acc8cc     CCAR2
#
# [224 rows x 9 columns]

# %% [markdown]
# # Run FeatureCounts

# %%
all_k562_bams = set(
    k562_bams['control_rep1'].append(
        k562_bams['control_rep2'].append(
            k562_bams['expt_rep1'].append(
                k562_bams['expt_rep2']
            )
        )
    )
)
all_hepg2_bams = set(
    hepg2_bams['control_rep1'].append(
        hepg2_bams['control_rep2'].append(
            hepg2_bams['expt_rep1'].append(
                hepg2_bams['expt_rep2']
            )
        )
    )
)
print(len(all_k562_bams))
print(len(all_hepg2_bams))
# Out:
# 498
# 508

# %%
i = 0
jobs = ['_k562','_hepg2']
# jobs = ['_hepg2']
for bams in [k562_bams, hepg2_bams]:
    cmds = []
    for unused,row in bams.iterrows():
        p = '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts'
        s = '/home/bay001/projects/encode/analysis/featureCounts/individual_expts/'
        o = '/home/bay001/projects/encode/analysis/featureCounts/individual_expts/{}{}.counts.txt'.format(row['name'],jobs[i])
        a = '/projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf'
        ctrl_rep1 = exists_and_return_fullpath(row['control_rep1'],downloaded_dir)
        ctrl_rep2 = exists_and_return_fullpath(row['control_rep2'],downloaded_dir)
        expt_rep1 = exists_and_return_fullpath(row['expt_rep1'],downloaded_dir)
        expt_rep2 = exists_and_return_fullpath(row['expt_rep2'],downloaded_dir)
        cmd = '{} -s 2 --tmpDir {} -p -a {} -o {} {} {} {} {}'.format(
            p, s, a, o, ctrl_rep1, ctrl_rep2, expt_rep1, expt_rep2
        )
        cmds.append(cmd)
    qtools.Submitter(
        cmds, jobs[i], array=True, nodes=1, ppn=1, walltime='4:00:00', submit=True, queue='home-scrm', sh=s+'{}.sh'.format(jobs[i])
    )
    i = i + 1
# Out:
# running 224 tasks as an array-job.
# Wrote commands to /home/bay001/projects/encode/analysis/featureCounts/individual_expts/_k562.sh.
# 8000665[].tscc-mgr.local
# Submitted script to queue home-scrm.
#  Job ID: 8000665
# 8000667[].tscc-mgr.local
# running 228 tasks as an array-job.
# Wrote commands to /home/bay001/projects/encode/analysis/featureCounts/individual_expts/_hepg2.sh.
# Submitted script to queue home-scrm.
#  Job ID: 8000667
# ['/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/RPLP0_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF534AWV.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF134QUL.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF992YGD.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF126RPY.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/SNRNP200_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF988VWE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF893QHC.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF831XLU.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF194QUZ.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/DNAJC2_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF460AAE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF058QDT.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF582HPV.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF601DMY.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/FXR1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF052HTH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF857QSU.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF865GTN.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF569MFV.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/HLTF_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF499UUZ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF326XKY.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF120YPA.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF791RLG.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/SART3_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF481PMW.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF610JDV.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF172AYP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF099GGP.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/APOBEC3C_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF481PMW.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF610JDV.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF887JLA.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF772ENG.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/AKAP1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF052HTH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF857QSU.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF426DHN.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF108HHU.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/NPM1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF988VWE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF893QHC.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF590AIM.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF698DFA.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/PCBP2_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF499UUZ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF326XKY.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF979AOI.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF918BEM.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/PA2G4_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF628UPI.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF561UZL.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF148JEE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF393QIH.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/NCBP2_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF052HTH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF857QSU.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF974BIC.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF664TKJ.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/TRA2A_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF499UUZ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF326XKY.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF593MYQ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF578EXH.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/CALR_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF379PKN.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF304DEE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF495QHS.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF418UCJ.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/FAM120A_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF628UPI.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF561UZL.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF459FNF.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF681TRC.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/HNRNPC_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF460AAE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF058QDT.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF031QZG.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF531AUK.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/TIA1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF571ARP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF755GKJ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF690DUO.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF143PAE.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ESF1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF124DWE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF774FAK.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF501BAP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF252NEG.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/PTBP1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF571ARP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF755GKJ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF155FIK.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF527FPF.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/DDX1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF460AAE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF058QDT.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF516CJR.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF562PGS.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/G3BP1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF052HTH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF857QSU.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF012GYQ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF433ERW.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/CCAR1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF772LMC.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF711NDL.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF654XYV.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF900XSL.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ZRANB2_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF499UUZ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF326XKY.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF095LYX.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF563FGQ.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/SMN1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF460AAE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF058QDT.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF781TAZ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF269ZGN.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/SRSF1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF571ARP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF755GKJ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF707GZQ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF223XHU.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ADAR_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF460AAE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF058QDT.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF087IGP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF841CBS.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/MARK2_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF505HKR.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF142SQX.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF393QCL.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF865DXQ.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/EIF2S2_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF124DWE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF774FAK.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF137QNH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF084VUF.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/SAFB2_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF460AAE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF058QDT.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF205GZW.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF434WKD.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/FIP1L1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF124DWE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF774FAK.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF551ACF.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF546TSA.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/GNB2L1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCF
bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/DDX52_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF628UPI.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF561UZL.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF246WQT.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF756RDZ.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/CSTF2T_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF383QRK.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF712XJM.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF352MST.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF187JOD.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/BOP1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF231NKH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF893QAU.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF998VON.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF722HDV.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/FUS_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF499UUZ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF326XKY.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF162PMY.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF382DXD.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/LIN28B_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF505HKR.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF142SQX.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF170MXT.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF732IMS.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/CEBPZ_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF124DWE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF774FAK.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF391FXZ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF925SHM.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/NELFE_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF571ARP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF755GKJ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF269RNF.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF957GUJ.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ILF3_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF481PMW.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF610JDV.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF415JGN.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF603VPF.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/G3BP2_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF052HTH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF857QSU.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF035NBS.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF562NOS.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/PUM1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF829TUN.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF350VVR.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF656HFZ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF005EIM.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/TROVE2_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF628UPI.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF561UZL.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF565GTX.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF099TTE.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/EIF4A3_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF052HTH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF857QSU.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF224ALJ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF037BCP.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/AKAP8_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF776ARB.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF975SQY.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF093STD.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF285YDY.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/DDX55_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF038LUH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF705LNP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF799DYJ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF935XLF.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/GPKOW_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF231NKH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF893QAU.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF270TJD.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF235AOH.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/DROSHA_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF843QOP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF432WNR.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF954PQI.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF523OXV.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/METAP2_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF628UPI.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF561UZL.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF095WYC.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF682JKD.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/HNRNPM_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF124DWE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF774FAK.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF833UFJ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF303DFN.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/SUPV3L1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF038LUH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF705LNP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF192VFW.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF078QOX.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/SMNDC1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF499UUZ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF326XKY.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF455QQB.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF360CYQ.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/SUB1_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF499UUZ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF326XKY.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF785OWH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF147AZH.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/PRPF8_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF038LUH.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF705LNP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF556JQE.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF082BNK.bam',
#  '/home/bay001/software/subread-1.5.1-Linux-x86_64/bin/featureCounts -s 2 --tmpDir /home/bay001/projects/encode/analysis/featureCounts/individual_expts/ -p -a /projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf -o /home/bay001/projects/encode/analysis/featureCounts/individual_expts/TAF15_hepg2.counts.txt /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF571ARP.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF755GKJ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF970XIQ.bam /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF166NGR.bam']

# %%
annotation = '/projects/ps-yeolab/genomes/hg19/gencode_v19/gencode.v19.annotation.gtf'
k562_outfile = '/home/bay001/projects/encode/permanent_data/_k562_hg19_featurecounts_intersect_CLIP_RNASEQ.txt'
hepg2_outfile = '/home/bay001/projects/encode/permanent_data/_hepg2_hg19_featurecounts_intersect_CLIP_RNASEQ.txt'

hepg2_cmd = "featureCounts -T 8 -a {} -s 2 -p -o {}".format(annotation, hepg2_outfile)
for bam in all_hepg2_bams:
    hepg2_cmd = hepg2_cmd + '{} '.format(os.path.join(exists_and_return_fullpath(bam, downloaded_dir)))
"""qtools.Submitter(
    hepg2_cmd, 'k562_featureCounts', array=False, nodes=1, ppn=8, walltime='48:00:00', submit=True, queue='home-scrm'
)"""

k562_cmd = "featureCounts -T 8 -a {} -s 2 -p -o {}".format(annotation, k562_outfile)
for bam in all_k562_bams:
    k562_cmd = k562_cmd + '{} '.format(os.path.join(exists_and_return_fullpath(bam, downloaded_dir)))
"""qtools.Submitter(
    cmd, 'hepg2_featureCounts', array=False, nodes=1, ppn=8, walltime='48:00:00', submit=True, queue='home-scrm'
)"""

# %%
# see what's going on...
jobid = 7893144
for i in range(0,86):
    ! qpeek $jobid[$i]

# %% [markdown]
# # Check that we have downloaded shRNA BAM and rMATS files for each replicate

# %%
import pandas as pd
import numpy as np
import os
import glob
from tqdm import tnrange, tqdm_notebook
from IPython.core.display import display, HTML
from collections import defaultdict

# %%
fns = glob.glob('/projects/ps-yeolab3/encode/rnaseq/differential_expression/DESeq_output/current/*DESeq_output.txt')
for fn in fns:
    if os.path.basename(fn).startswith('HepG2') or os.path.basename(fn).startswith('K562'):
        pass
    else:
        ! rm $fn

# %%
from_xintao_20180329 = pd.read_table(
    '/projects/ps-yeolab3/encode/rnaseq/HepG2_fileID_table_set39.20180329.txt'
)
print(from_xintao_20180329.columns)

from_xintao_20171211 = pd.read_table(
    '/projects/ps-yeolab3/encode/rnaseq/HepG2_fileID_table.20171211.txt',
    comment='#'
)
print(from_xintao_20171211.columns)
# Out:
# Index([u'Experiment_ID', u'RBP', u'Cell_line', u'Replicate', u'FASTQ_R1',
#        u'FASTQ_R2', u'BAM', u'TSV'],
#       dtype='object')
# Index([u'Experiment_ID', u'RBP', u'Cell_line', u'Replicate', u'FASTQ_R1',
#        u'FASTQ_R2', u'BAM', u'TSV'],
#       dtype='object')

# %%
rnaseq_dir = '/projects/ps-yeolab3/encode/rnaseq/'
deseq_dir = '/projects/ps-yeolab3/encode/rnaseq/differential_expression/DESeq_output/current/'
output_dir = '/projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat'

# %%
download_file = os.path.join(rnaseq_dir, 'HepG2_fileID_table.20171211.sh')
with open(download_file, 'w') as o:
    for bam in from_xintao_20171211['BAM']:
        target_file = os.path.join(output_dir, bam + '.bam')
        if not os.path.exists(target_file):
            o.write('wget https://www.encodeproject.org/files/{}/@@download/{}.bam -O {}\n'.format(bam, bam, target_file))

# %%
download_file = os.path.join(rnaseq_dir, 'HepG2_fileID_table_set39.20180329.sh')
with open(download_file, 'w') as o:
    for bam in from_xintao_20180329['BAM']:
        target_file = os.path.join(output_dir, bam + '.bam')
        if not os.path.exists(target_file):
            o.write('wget https://www.encodeproject.org/files/{}/@@download/{}.bam -O {}\n'.format(bam, bam, target_file))

# %% [markdown]
# # K562 now

# %%
from_xintao_20180329 = pd.read_table(
    os.path.join(rnaseq_dir, 'K562_fileID_table_set39.20180329.txt'),
    comment='#'
)
print(from_xintao_20180329.columns)

from_xintao_20171211 = pd.read_table(
    os.path.join(rnaseq_dir, 'K562_fileID_table.20171211.txt'),
    comment='#'
)
print(from_xintao_20171211.columns)
# Out:
# Index([u'Experiment_ID', u'RBP', u'Cell_line', u'Replicate', u'FASTQ_R1',
#        u'FASTQ_R2', u'BAM', u'TSV'],
#       dtype='object')
# Index([u'Experiment_ID', u'RBP', u'Cell_line', u'Replicate', u'FASTQ_R1',
#        u'FASTQ_R2', u'BAM', u'TSV'],
#       dtype='object')

# %%
from_xintao_20171211[from_xintao_20171211['RBP']=='SRSF9']
# Out:
# Empty DataFrame
# Columns: [Experiment_ID, RBP, Cell_line, Replicate, FASTQ_R1, FASTQ_R2, BAM, TSV]
# Index: []

# %%
download_file = os.path.join(rnaseq_dir, 'K562_fileID_table.20171211.sh')
with open(download_file, 'w') as o:
    for bam in from_xintao_20171211['BAM']:
        target_file = os.path.join(output_dir, bam + '.bam')
        if not os.path.exists(target_file):
            o.write('wget https://www.encodeproject.org/files/{}/@@download/{}.bam -O {}\n'.format(bam, bam, target_file))

# %%
download_file = os.path.join(rnaseq_dir, 'K562_fileID_table_set39.20180329.sh')
with open(download_file, 'w') as o:
    for bam in from_xintao_20180329['BAM']:
        target_file = os.path.join(output_dir, bam + '.bam')
        if not os.path.exists(target_file):
            o.write('wget https://www.encodeproject.org/files/{}/@@download/{}.bam -O {}\n'.format(bam, bam, target_file))

# %% [markdown]
# # Check md5sums according to ENCODE

# %%
hepg2_from_xintao_20180329 = pd.read_table(
    os.path.join(rnaseq_dir, 'HepG2_fileID_table_set39.20180329.txt')
)
hepg2_from_xintao_20171211 = pd.read_table(
    os.path.join(rnaseq_dir, 'HepG2_fileID_table.20171211.txt'),
    comment='#'
)
k562_from_xintao_20180329 = pd.read_table(
    os.path.join(rnaseq_dir, 'K562_fileID_table_set39.20180329.txt')
)
k562_from_xintao_20171211 = pd.read_table(
    os.path.join(rnaseq_dir, 'K562_fileID_table.20171211.txt'),
    comment='#'
)

# %%
import urllib
import json
import requests
experiments = "https://www.encodeproject.org/experiments/"

def write_md5sums(df, out_file):
    o = open(out_file, 'w') 
    progress = tnrange(len(set(df['BAM'])))
    for h in set(df['BAM']): # queries every experiment
        url = experiments+h+"/?format=json"
        response = urllib.urlopen(url)
        data = json.loads(response.read())
        if 'code' in data.keys():
            next
        else:
            o.write('{}\t{}\n'.format(h, data[u'md5sum']))
        progress.update(1)
    o.close()

# %%
# we only need to grab the md5sums once

# write_md5sums(hepg2_from_xintao_20180329, os.path.join(rnaseq_dir, 'HepG2_fileID_table_set39.20180329.encode_md5sums'))
# write_md5sums(hepg2_from_xintao_20171211, os.path.join(rnaseq_dir, 'HepG2_fileID_table.20171211.encode_md5sums'))
# write_md5sums(k562_from_xintao_20180329,  os.path.join(rnaseq_dir, 'K562_fileID_table_set39.20180329.encode_md5sums'))
# write_md5sums(k562_from_xintao_20171211, os.path.join(rnaseq_dir, 'K562_fileID_table.20171211.encode_md5sums'))

# %% [markdown]
# # Check md5sums according to local
# - check md5sums for every bam file we've downloaded (may have more bam files than end up being used)

# %%
# ! md5sum /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/*.bam > md5sums-20180330

# %% [markdown]
# # Compare the md5sums reported on encodeproject.org with the md5sums we got from our local dir

# %%
# just reading one to see what the format is
local = pd.read_table(
    os.path.join(output_dir, 'md5sums-20180330'),
    names=['md5sum_local','bam'], sep='  '
)
local.head()
# Out:
# /home/bay001/anaconda2/envs/brian/lib/python2.7/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
#                        md5sum_local              bam
# 0  f975e267cf67083d4fafe1e2ad94e347  ENCFF005EIM.bam
# 1  1d2d6469725a3610afb8c391f66cde71  ENCFF011BRT.bam
# 2  96c0821c39a0a1d3fb4811b7fa044d86  ENCFF011SYE.bam
# 3  f138fe9ca9d2108f09264609541afd59  ENCFF012GYQ.bam
# 4  86f7cc4b04fbea00f311a67bf27235b5  ENCFF012WHT.bam

# %%
# just reading one to see what the format is
remote = pd.read_table(
    os.path.join(rnaseq_dir, 'HepG2_fileID_table_set39.20180329.encode_md5sums'),
    names=['bam','md5sum_remote'], sep='\t'
)
remote['bam'] = remote['bam'] + '.bam'
remote.head()
# Out:
#                bam                     md5sum_remote
# 0  ENCFF265NOS.bam  fa7fe7949c178398afaa9255a1065ead
# 1  ENCFF996LFJ.bam  9d92b876914f36372be667f985e126ab
# 2  ENCFF654TTY.bam  98930ca94aa2e2343c6646a5a1bf92c5
# 3  ENCFF644TFQ.bam  6c3c67853a57abdc76abbe8301160ac4
# 4  ENCFF444CHN.bam  03a9b5e6a9bb79662cbd6eb1d408cc5b

# %%
def compare_local_and_remote(local_file, remote_file):
    """ Compares the two md5sum files and returns bam files which are different """
    local = pd.read_table(
        local_file,
        names=['md5sum_local','bam'], sep='  '
    )
    remote = pd.read_table(
        remote_file,
        names=['bam','md5sum_remote'], sep='\t'
    )
    remote['bam'] = remote['bam'] + '.bam'
    merged = pd.merge(remote, local, how='left', left_on='bam', right_on='bam')
    return merged[merged['md5sum_remote']!=merged['md5sum_local']]

# %%
# for each file generated from expected md5sums, compare against the md5sums we got
# shape should be 0 for all
for remote in [
    os.path.join(rnaseq_dir, 'HepG2_fileID_table_set39.20180329.encode_md5sums'),
    os.path.join(rnaseq_dir, 'HepG2_fileID_table.20171211.encode_md5sums'),
    os.path.join(rnaseq_dir, 'K562_fileID_table_set39.20180329.encode_md5sums'),
    os.path.join(rnaseq_dir, 'K562_fileID_table.20171211.encode_md5sums')
]:
    merged = compare_local_and_remote(
        os.path.join(output_dir, 'md5sums-20180330'),
        remote
    )
    print(display(HTML(merged.to_html())))
# Out:
# /home/bay001/anaconda2/envs/brian/lib/python2.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bam</th>
#       <th>md5sum_remote</th>
#       <th>md5sum_local</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# None
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bam</th>
#       <th>md5sum_remote</th>
#       <th>md5sum_local</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# None
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bam</th>
#       <th>md5sum_remote</th>
#       <th>md5sum_local</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# None
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bam</th>
#       <th>md5sum_remote</th>
#       <th>md5sum_local</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# None

# %% [markdown]
# # There is one different bam file (ENCFF742IJE.bam)
# - double check to make sure the md5sum reported is accurate
# - redownload if necessary
# - actually this link doesn't exist, instead shown as ENCFF893QAU.bam
# - downloaded ENCFF893QAU.bam manually and confirmed it matches remote md5sum
# - MANUALLY change /projects/ps-yeolab3/encode/rnaseq/HepG2_fileID_table.20171211
# - rerun this notebook to make sure everything matches now

# %%
# manually check this md5sum
! md5sum /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF893QAU.bam
# Out:
# 94cf6b7e3be9c6c3828af1ec3b0731d7  /projects/ps-yeolab3/encode/rnaseq/shrna_knockdown_graveley_tophat/ENCFF893QAU.bam

# %%
# manually lookup md5sum of remote file
experiments = "https://www.encodeproject.org/experiments/"

url = experiments+"ENCFF893QAU"+"/?format=json"
response = urllib.urlopen(url)
data = json.loads(response.read())
if 'code' in data.keys():
    next
else:
    print(data[u'md5sum'])
# Out:
# 94cf6b7e3be9c6c3828af1ec3b0731d7

# %% [markdown]
# # (re)move any BAM files that don't belong to these lists
# The following bam files have been removed (20180402):
# - ENCFF394JPI.bam (RBM15, removed/archived file on encodeproject.org, accessed 20180402)
# - ENCFF839HZQ.bam (RBM15, removed/archived file on encodeproject.org, accessed 20180402)
# - ENCFF992OHI.bam (U2AF2, removed per email 20171211)
# - ENCFF374PNQ.bam (PES1, removed/archived file on encodeproject.org, accessed 20180402)
# - ENCFF742IJE.bam (Control, confirmed as ENCFF893QAU.bam so removed from directory)
# - ENCFF959LXB.bam (PES1, removed/archived file on encodeproject.org, accessed 20180402)
# - ENCFF057UPR.bam (U2AF2, removed per email 20181211)
# - ENCFF985GAR.bam (RPS3, removed per email 20180330)
# - ENCFF403FGR.bam (RPS3, removed per email 20180330)
# - ENCFF152BOQ.bam (SRSF4, removed per email 20180330)
# - ENCFF631XDT.bam (SRSF4, removed per email 20180330)
# - ENCFF792MXQ.bam (SRSF9, removed per email 20180330)
# - ENCFF990JSY.bam (SRSF9, removed per email 20180330)

# %%
# get a list of all bam files specified in each manifest

list_of_all_bam_files_used = []

for bam in set(hepg2_from_xintao_20171211['BAM']):
    list_of_all_bam_files_used.append(os.path.join(output_dir, bam + '.bam'))
for bam in set(k562_from_xintao_20171211['BAM']):
    list_of_all_bam_files_used.append(os.path.join(output_dir, bam + '.bam'))
for bam in set(hepg2_from_xintao_20180329['BAM']):
    list_of_all_bam_files_used.append(os.path.join(output_dir, bam + '.bam'))
for bam in set(k562_from_xintao_20180329['BAM']):
    list_of_all_bam_files_used.append(os.path.join(output_dir, bam + '.bam'))
    
print("Total number of bam files (hepg2 20171211): {}".format(len(set(hepg2_from_xintao_20171211['BAM']))))
print("Total number of bam files (k562 20171211): {}".format(len(set(k562_from_xintao_20171211['BAM']))))
print("Total number of bam files (hepg2 20180329): {}".format(len(set(hepg2_from_xintao_20180329['BAM']))))
print("Total number of bam files (k562 20180329): {}".format(len(set(k562_from_xintao_20180329['BAM']))))

print("Total number of bam files: {}".format(len(set(list_of_all_bam_files_used))))
# Out:
# Total number of bam files (hepg2 20171211): 508
# Total number of bam files (k562 20171211): 492
# Total number of bam files (hepg2 20180329): 24
# Total number of bam files (k562 20180329): 36
# Total number of bam files: 1060

# %%
# get a list of all bam files downloaded so far

list_of_all_bam_files_downloaded = glob.glob(
    os.path.join(output_dir, '*.bam')
)

len(list_of_all_bam_files_downloaded)
# Out:
# 1060

# %%
# differences should be any manual corrections made post-manifest
# bam files that were downloaded previously but are not being used are moved to: path/to/output/deprecated_manually_removed
print(
    "Number of used bams that have not been downloaded: ",
    len(set(list_of_all_bam_files_used).difference(set(list_of_all_bam_files_downloaded)))
)
print(
    "Number of downloaded bams that are not used: ",
    len(set(list_of_all_bam_files_downloaded).difference(set(list_of_all_bam_files_used)))
)

for bam in set(list_of_all_bam_files_downloaded).difference(set(list_of_all_bam_files_used)):
    prefix = os.path.splitext(bam)[0]
    ! mv $prefix* $output_dir/deprecated_manually_removed/
    print(bam)
# Out:
# ('Number of used bams that have not been downloaded: ', 0)
# ('Number of downloaded bams that are not used: ', 0)

# %% [markdown]
# # Make sure we have all the RMATS files too

# %%
rmats_dir = '/projects/ps-yeolab3/encode/rnaseq/alt_splicing/graveley_rmats_current'

# %% [markdown]
# # Softlink known differences between APOBEC3C and APOBE accessions
# - per email 20171218

# %%
! ln -s $rmats_dir/APOBE-BGHLV22-HepG2.set22.SE.MATS.JunctionCountOnly.txt $rmats_dir/APOBEC3C-BGHLV22-HepG2.set22.SE.MATS.JunctionCountOnly.txt
! ln -s $rmats_dir/APOBE-BGHLV22-HepG2.set22.A3SS.MATS.JunctionCountOnly.txt $rmats_dir/APOBEC3C-BGHLV22-HepG2.set22.A3SS.MATS.JunctionCountOnly.txt
! ln -s $rmats_dir/APOBE-BGHLV22-HepG2.set22.A5SS.MATS.JunctionCountOnly.txt $rmats_dir/APOBEC3C-BGHLV22-HepG2.set22.A5SS.MATS.JunctionCountOnly.txt
! ln -s $rmats_dir/APOBE-BGHLV22-HepG2.set22.MXE.MATS.JunctionCountOnly.txt $rmats_dir/APOBEC3C-BGHLV22-HepG2.set22.MXE.MATS.JunctionCountOnly.txt
! ln -s $rmats_dir/APOBE-BGHLV22-HepG2.set22.RI.MATS.JunctionCountOnly.txt $rmats_dir/APOBEC3C-BGHLV22-HepG2.set22.RI.MATS.JunctionCountOnly.txt
# Out:
# ln: creating symbolic link `/projects/ps-yeolab3/encode/rnaseq/alt_splicing/graveley_rmats_current/APOBEC3C-BGHLV22-HepG2.set22.SE.MATS.JunctionCountOnly.txt': File exists
# ln: creating symbolic link `/projects/ps-yeolab3/encode/rnaseq/alt_splicing/graveley_rmats_current/APOBEC3C-BGHLV22-HepG2.set22.A3SS.MATS.JunctionCountOnly.txt': File exists
# ln: creating symbolic link `/projects/ps-yeolab3/encode/rnaseq/alt_splicing/graveley_rmats_current/APOBEC3C-BGHLV22-HepG2.set22.A5SS.MATS.JunctionCountOnly.txt': File exists
# ln: creating symbolic link `/projects/ps-yeolab3/encode/rnaseq/alt_splicing/graveley_rmats_current/APOBEC3C-BGHLV22-HepG2.set22.MXE.MATS.JunctionCountOnly.txt': File exists
# ln: creating symbolic link `/projects/ps-yeolab3/encode/rnaseq/alt_splicing/graveley_rmats_current/APOBEC3C-BGHLV22-HepG2.set22.RI.MATS.JunctionCountOnly.txt': File exists

# %%
se_rmats_files = glob.glob(os.path.join(rmats_dir, '*SE.MATS.JunctionCountOnly.txt'))
a3ss_rmats_files = glob.glob(os.path.join(rmats_dir, '*A3SS.MATS.JunctionCountOnly.txt'))
a5ss_rmats_files = glob.glob(os.path.join(rmats_dir, '*A5SS.MATS.JunctionCountOnly.txt'))
mxe_rmats_files = glob.glob(os.path.join(rmats_dir, '*MXE.MATS.JunctionCountOnly.txt'))
ri_rmats_files = glob.glob(os.path.join(rmats_dir, '*RI.MATS.JunctionCountOnly.txt'))

for f in [
    se_rmats_files,
    a3ss_rmats_files,
    a5ss_rmats_files,
    mxe_rmats_files,
    ri_rmats_files
]:
    print(len(f))
# Out:
# 473
# 473
# 473
# 473
# 473

# %% [markdown]
# # Check any duplicated rmats files
# - make sure we have only one rmats file per rbp/cell combo, and resolve here if necessary

# %%
rbps = defaultdict(list)
for se in se_rmats_files:
    kdset = os.path.basename(se).split('.')[1]
    rbp, uid, cell = os.path.basename(se).split('.')[0].split('-')
    key = '{}-{}'.format(rbp, cell)
    rbps[key].append({'RBP':rbp, 'uID':uid, 'cell':cell, 'kdset':kdset, 'fullpath':se})

for key, vals in rbps.iteritems():
    if len(vals) > 1:
        for val in vals:
            print(key, val)

# %%
rbps['ASCC-HepG2']
# Out:
# []

# %% [markdown]
# # Manually move duplicated rmats files to deprecated_unused
# - move the non-set39 ones per email 20180330

# %%
! mv $rmats_dir/SRSF9-LV11-K562.set11.*.MATS.JunctionCountOnly.txt $rmats_dir/deprecated_manually_removed
! mv $rmats_dir/SRSF4-BGKLV13-K562.set13.*.MATS.JunctionCountOnly.txt $rmats_dir/deprecated_manually_removed
# Out:
# mv: cannot stat `/projects/ps-yeolab3/encode/rnaseq/alt_splicing/graveley_rmats_current/SRSF9-LV11-K562.set11.*.MATS.JunctionCountOnly.txt': No such file or directory
# mv: cannot stat `/projects/ps-yeolab3/encode/rnaseq/alt_splicing/graveley_rmats_current/SRSF4-BGKLV13-K562.set13.*.MATS.JunctionCountOnly.txt': No such file or directory

# %% [markdown]
# # Concat all separate manifests together
# - makes it easier to combine/integrate other assay/files together

# %%
merged = hepg2_from_xintao_20171211

for df in [
    k562_from_xintao_20171211,
    hepg2_from_xintao_20180329,
    k562_from_xintao_20180329
]:
    merged = pd.concat([
        merged,
        df
    ], axis=0)
merged.columns = ['RNASEQ_'+c for c in merged.columns]
print(merged.shape)
merged.head()
# Out:
# (1060, 8)
#   RNASEQ_Experiment_ID RNASEQ_RBP RNASEQ_Cell_line RNASEQ_Replicate  \
# 0          ENCSR547NWD       AARS            HepG2   AARS_BGHLV17_1
# 1          ENCSR547NWD       AARS            HepG2   AARS_BGHLV17_2
# 2          ENCSR424YSV       AATF            HepG2   AATF_BGHLV14-3
# 3          ENCSR424YSV       AATF            HepG2   AATF_BGHLV14-4
# 4          ENCSR610VTA      ABCF1            HepG2  ABCF1_BGHLV30-3
#
#   RNASEQ_FASTQ_R1 RNASEQ_FASTQ_R2   RNASEQ_BAM   RNASEQ_TSV
# 0     ENCFF488SPX     ENCFF464UID  ENCFF604SNM  ENCFF739CVP
# 1     ENCFF499YCP     ENCFF950IJN  ENCFF255RNW  ENCFF530DUY
# 2     ENCFF094WZU     ENCFF434WFA  ENCFF159JHT  ENCFF894KMA
# 3     ENCFF495VXI     ENCFF695STL  ENCFF800WEJ  ENCFF204TFW
# 4     ENCFF067AQF     ENCFF390FTP  ENCFF015TIY  ENCFF724GZU

# %% [markdown]
# # Add DESeq2 results

# %%
# get batch_id.. no these accession numbers are not consistent w/ each other.
# def isolate_batchid_from_replicate_id(row):
#     try:
#         return row['RNASEQ_Replicate'].split('_')[1].split('-')[0]
#    except IndexError:
#         return row['RNASEQ_Replicate'].split('-')[1]
#     
# merged['RNASEQ_Batch_ID'] = merged.apply(isolate_batchid_from_replicate_id, axis=1)
# merged.head()

# %%
deseq_dict = defaultdict(list)

all_deseq_files = glob.glob(
    os.path.join(deseq_dir, '*DESeq_output.txt')
)
print(len(all_deseq_files))

# for every deseq2 file, get the name and teh cell type from the filename
for deseq_file in all_deseq_files:
    parts = os.path.basename(deseq_file).split('_')
    cell_line = parts[0]
    rbp = parts[1]
    batch_id = parts[2]
    deseq_dict['{}-{}'.format(cell_line, rbp)].append(os.path.basename(deseq_file))
print(len(deseq_dict.keys()))

def get_deseq_file_from_row_info(row, deseq_dict=deseq_dict):
    """
    Using the row's cell line and RBP columns, return the deseq2 file associated with it.
    Prints any RBP/cell line that has more than 1 associated file
    Returns - for any RBP/cell line that's missing (should only apply to nontarget controls)
    """
    try:
        matching_files = deseq_dict['{}-{}'.format(row['RNASEQ_Cell_line'], row['RNASEQ_RBP'])]
        if len(matching_files) == 1:
            return matching_files[0]
        elif len(matching_files) == 0:
            if row['RNASEQ_RBP'] != 'non-target':
                print(row['RNASEQ_RBP'])
            return '-'
        else:
            print(row['RNASEQ_RBP'], row['RNASEQ_Cell_line'])
            return matching_files[0]
    except KeyError:
        return '-'
    
merged['RNASEQ_DESeq2'] = merged.apply(get_deseq_file_from_row_info, axis=1)
merged.head()
# Out:
# 472
# 472
#   RNASEQ_Experiment_ID RNASEQ_RBP RNASEQ_Cell_line RNASEQ_Replicate  \
# 0          ENCSR547NWD       AARS            HepG2   AARS_BGHLV17_1
# 1          ENCSR547NWD       AARS            HepG2   AARS_BGHLV17_2
# 2          ENCSR424YSV       AATF            HepG2   AATF_BGHLV14-3
# 3          ENCSR424YSV       AATF            HepG2   AATF_BGHLV14-4
# 4          ENCSR610VTA      ABCF1            HepG2  ABCF1_BGHLV30-3
#
#   RNASEQ_FASTQ_R1 RNASEQ_FASTQ_R2   RNASEQ_BAM   RNASEQ_TSV  \
# 0     ENCFF488SPX     ENCFF464UID  ENCFF604SNM  ENCFF739CVP
# 1     ENCFF499YCP     ENCFF950IJN  ENCFF255RNW  ENCFF530DUY
# 2     ENCFF094WZU     ENCFF434WFA  ENCFF159JHT  ENCFF894KMA
# 3     ENCFF495VXI     ENCFF695STL  ENCFF800WEJ  ENCFF204TFW
# 4     ENCFF067AQF     ENCFF390FTP  ENCFF015TIY  ENCFF724GZU
#
#                           RNASEQ_DESeq2
# 0   HepG2_AARS_BGHLV17_DESeq_output.txt
# 1   HepG2_AARS_BGHLV17_DESeq_output.txt
# 2   HepG2_AATF_BGHLV14_DESeq_output.txt
# 3   HepG2_AATF_BGHLV14_DESeq_output.txt
# 4  HepG2_ABCF1_BGHLV30_DESeq_output.txt

# %%
merged[(merged['RNASEQ_DESeq2']=='-') & (merged['RNASEQ_RBP']!='non-target')]
# Out:
# Empty DataFrame
# Columns: [RNASEQ_Experiment_ID, RNASEQ_RBP, RNASEQ_Cell_line, RNASEQ_Replicate, RNASEQ_FASTQ_R1, RNASEQ_FASTQ_R2, RNASEQ_BAM, RNASEQ_TSV, RNASEQ_DESeq2]
# Index: []

# %% [markdown]
# # Pair KD expts with their controls

# %%
exp2ctrl = {}

with open(os.path.join(rnaseq_dir, 'HepG2_expID_table.20171211.txt'), 'r') as f:
    f.readline() # skip header
    for line in f:
        line = line.rstrip().split('\t')
        exp2ctrl[line[3]] = line[4]

with open(os.path.join(rnaseq_dir, 'K562_expID_table.20171211.txt'), 'r') as f:
    f.readline() # skip header
    for line in f:
        line = line.rstrip().split('\t')
        exp2ctrl[line[3]] = line[4]

with open(os.path.join(rnaseq_dir, 'HepG2_expID_table_set39.20180329.txt'), 'r') as f:
    f.readline() # skip header
    for line in f:
        line = line.rstrip().split('\t')
        exp2ctrl[line[3]] = line[4]

with open(os.path.join(rnaseq_dir, 'K562_expID_table_set39.20180329.txt'), 'r') as f:
    f.readline() # skip header
    for line in f:
        line = line.rstrip().split('\t')
        exp2ctrl[line[3]] = line[4]
        
print("Total number of paired expts", len(exp2ctrl.keys()))
# Out:
# ('Total number of paired expts', 475)

# %% [markdown]
# # Add replicate info
# - This is perhaps not the true replicate number, but per a previous email the lower number should be rep1 while the higher number is rep2

# %%
exp2ctrl['ENCSR715QWM']
# Out:
# 'ENCSR521WAI'

# %%
def assign_rep_number(row):
    bam = row['RNASEQ_BAM']
    url = experiments+bam+"/?format=json"
    response = urllib.urlopen(url)
    data = json.loads(response.read())
    if 'code' in data.keys():
        next
    else:
        print('.'),
        return data[u'biological_replicates'][0]
    
merged['Rep'] = merged.apply(assign_rep_number, axis=1)
merged.head()
# Out:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#   RNASEQ_Experiment_ID RNASEQ_RBP RNASEQ_Cell_line RNASEQ_Replicate  \
# 0          ENCSR547NWD       AARS            HepG2   AARS_BGHLV17_1
# 1          ENCSR547NWD       AARS            HepG2   AARS_BGHLV17_2
# 2          ENCSR424YSV       AATF            HepG2   AATF_BGHLV14-3
# 3          ENCSR424YSV       AATF            HepG2   AATF_BGHLV14-4
# 4          ENCSR610VTA      ABCF1            HepG2  ABCF1_BGHLV30-3
#
#   RNASEQ_FASTQ_R1 RNASEQ_FASTQ_R2   RNASEQ_BAM   RNASEQ_TSV  \
# 0     ENCFF488SPX     ENCFF464UID  ENCFF604SNM  ENCFF739CVP
# 1     ENCFF499YCP     ENCFF950IJN  ENCFF255RNW  ENCFF530DUY
# 2     ENCFF094WZU     ENCFF434WFA  ENCFF159JHT  ENCFF894KMA
# 3     ENCFF495VXI     ENCFF695STL  ENCFF800WEJ  ENCFF204TFW
# 4     ENCFF067AQF     ENCFF390FTP  ENCFF015TIY  ENCFF724GZU
#
#                           RNASEQ_DESeq2  Rep
# 0   HepG2_AARS_BGHLV17_DESeq_output.txt    1
# 1   HepG2_AARS_BGHLV17_DESeq_output.txt    2
# 2   HepG2_AATF_BGHLV14_DESeq_output.txt    1
# 3   HepG2_AATF_BGHLV14_DESeq_output.txt    2
# 4  HepG2_ABCF1_BGHLV30_DESeq_output.txt    1

# %% [markdown]
# # separate the controls and the expts

# %%
expt = merged[merged['RNASEQ_RBP']!='non-target']
ctrl = merged[merged['RNASEQ_RBP']=='non-target']
print("Total number of expt bam files", expt.shape[0])
print("Total number of ctrl bam files", ctrl.shape[0])
# Out:
# ('Total number of expt bam files', 944)
# ('Total number of ctrl bam files', 116)

# %%
def return_ctrl(row, exp2ctrl=exp2ctrl):
    try:
        return exp2ctrl[row['RNASEQ_Experiment_ID']]
    except KeyError: 
        return '-'
    
expt['RNASEQ_Control_Experiment_ID'] = expt.apply(return_ctrl, axis=1)
expt.head()
# Out:
# /home/bay001/anaconda2/envs/brian/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#   RNASEQ_Experiment_ID RNASEQ_RBP RNASEQ_Cell_line RNASEQ_Replicate  \
# 0          ENCSR547NWD       AARS            HepG2   AARS_BGHLV17_1
# 1          ENCSR547NWD       AARS            HepG2   AARS_BGHLV17_2
# 2          ENCSR424YSV       AATF            HepG2   AATF_BGHLV14-3
# 3          ENCSR424YSV       AATF            HepG2   AATF_BGHLV14-4
# 4          ENCSR610VTA      ABCF1            HepG2  ABCF1_BGHLV30-3
#
#   RNASEQ_FASTQ_R1 RNASEQ_FASTQ_R2   RNASEQ_BAM   RNASEQ_TSV  \
# 0     ENCFF488SPX     ENCFF464UID  ENCFF604SNM  ENCFF739CVP
# 1     ENCFF499YCP     ENCFF950IJN  ENCFF255RNW  ENCFF530DUY
# 2     ENCFF094WZU     ENCFF434WFA  ENCFF159JHT  ENCFF894KMA
# 3     ENCFF495VXI     ENCFF695STL  ENCFF800WEJ  ENCFF204TFW
# 4     ENCFF067AQF     ENCFF390FTP  ENCFF015TIY  ENCFF724GZU
#
#                           RNASEQ_DESeq2  Rep RNASEQ_Control_Experiment_ID
# 0   HepG2_AARS_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
# 1   HepG2_AARS_BGHLV17_DESeq_output.txt    2                  ENCSR856ZRV
# 2   HepG2_AATF_BGHLV14_DESeq_output.txt    1                  ENCSR003EKR
# 3   HepG2_AATF_BGHLV14_DESeq_output.txt    2                  ENCSR003EKR
# 4  HepG2_ABCF1_BGHLV30_DESeq_output.txt    1                  ENCSR067GHD

# %%
ctrl.columns = [c.replace('RNASEQ_','CONTROL_') for c in ctrl.columns]
merged = pd.merge(
    expt, 
    ctrl, 
    how='outer', 
    left_on=['RNASEQ_Control_Experiment_ID','Rep'],
    right_on=['CONTROL_Experiment_ID', 'Rep']
)
merged.head()
# Out:
#   RNASEQ_Experiment_ID RNASEQ_RBP RNASEQ_Cell_line  RNASEQ_Replicate  \
# 0          ENCSR547NWD       AARS            HepG2    AARS_BGHLV17_1
# 1          ENCSR570CWH      BCCIP            HepG2  BCCIP_BGHLV17_45
# 2          ENCSR481AYC     BCLAF1            HepG2  BCLAF1_BGHLV17_5
# 3          ENCSR815JDY      CSTF2            HepG2  CSTF2_BGHLV17_10
# 4          ENCSR210RWL      DDX27            HepG2  DDX27_BGHLV17_53
#
#   RNASEQ_FASTQ_R1 RNASEQ_FASTQ_R2   RNASEQ_BAM   RNASEQ_TSV  \
# 0     ENCFF488SPX     ENCFF464UID  ENCFF604SNM  ENCFF739CVP
# 1     ENCFF291SQT     ENCFF225QRN  ENCFF022PCS  ENCFF938GXB
# 2     ENCFF182RAD     ENCFF863SFE  ENCFF775APS  ENCFF670VTV
# 3     ENCFF041YGN     ENCFF909LAP  ENCFF116TYA  ENCFF568ZNU
# 4     ENCFF265RYO     ENCFF554LIG  ENCFF495SBM  ENCFF311UBJ
#
#                            RNASEQ_DESeq2  Rep RNASEQ_Control_Experiment_ID  \
# 0    HepG2_AARS_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
# 1   HepG2_BCCIP_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
# 2  HepG2_BCLAF1_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
# 3   HepG2_CSTF2_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
# 4   HepG2_DDX27_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
#
#   CONTROL_Experiment_ID CONTROL_RBP CONTROL_Cell_line CONTROL_Replicate  \
# 0           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 1           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 2           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 3           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 4           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
#
#   CONTROL_FASTQ_R1 CONTROL_FASTQ_R2  CONTROL_BAM  CONTROL_TSV CONTROL_DESeq2
# 0      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG              -
# 1      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG              -
# 2      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG              -
# 3      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG              -
# 4      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG              -

# %% [markdown]
# # Append rmats files
# - combine using RBP name and cell line
# - if there are any missing rmats files, this block will print what they are

# %%
def get_junctioncountonly(row, rbps=rbps):
    """
    Returns the basename of the rmats file associated with the row, given its RBP name and cell line.
    Returns - if an exception was found.
    """
    key = '{}-{}'.format(row['RNASEQ_RBP'], row['RNASEQ_Cell_line'])
    try:
        return os.path.basename(rbps[key][0]['fullpath'])
    except Exception as e:
        if row['RNASEQ_RBP'] != 'non-target':
            print(e, row['RNASEQ_RBP'], row['RNASEQ_Cell_line']) # print missing rmats file
        return '-'
    
merged['SE_jxc_file'] = merged.apply(get_junctioncountonly, axis=1)
merged.head()
# Out:
#   RNASEQ_Experiment_ID RNASEQ_RBP RNASEQ_Cell_line  RNASEQ_Replicate  \
# 0          ENCSR547NWD       AARS            HepG2    AARS_BGHLV17_1
# 1          ENCSR570CWH      BCCIP            HepG2  BCCIP_BGHLV17_45
# 2          ENCSR481AYC     BCLAF1            HepG2  BCLAF1_BGHLV17_5
# 3          ENCSR815JDY      CSTF2            HepG2  CSTF2_BGHLV17_10
# 4          ENCSR210RWL      DDX27            HepG2  DDX27_BGHLV17_53
#
#   RNASEQ_FASTQ_R1 RNASEQ_FASTQ_R2   RNASEQ_BAM   RNASEQ_TSV  \
# 0     ENCFF488SPX     ENCFF464UID  ENCFF604SNM  ENCFF739CVP
# 1     ENCFF291SQT     ENCFF225QRN  ENCFF022PCS  ENCFF938GXB
# 2     ENCFF182RAD     ENCFF863SFE  ENCFF775APS  ENCFF670VTV
# 3     ENCFF041YGN     ENCFF909LAP  ENCFF116TYA  ENCFF568ZNU
# 4     ENCFF265RYO     ENCFF554LIG  ENCFF495SBM  ENCFF311UBJ
#
#                            RNASEQ_DESeq2  Rep  \
# 0    HepG2_AARS_BGHLV17_DESeq_output.txt    1
# 1   HepG2_BCCIP_BGHLV17_DESeq_output.txt    1
# 2  HepG2_BCLAF1_BGHLV17_DESeq_output.txt    1
# 3   HepG2_CSTF2_BGHLV17_DESeq_output.txt    1
# 4   HepG2_DDX27_BGHLV17_DESeq_output.txt    1
#
#                          ...                         CONTROL_Experiment_ID  \
# 0                        ...                                   ENCSR856ZRV
# 1                        ...                                   ENCSR856ZRV
# 2                        ...                                   ENCSR856ZRV
# 3                        ...                                   ENCSR856ZRV
# 4                        ...                                   ENCSR856ZRV
#
#   CONTROL_RBP CONTROL_Cell_line CONTROL_Replicate CONTROL_FASTQ_R1  \
# 0  non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 1  non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 2  non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 3  non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 4  non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
#
#   CONTROL_FASTQ_R2  CONTROL_BAM  CONTROL_TSV CONTROL_DESeq2  \
# 0      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG              -
# 1      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG              -
# 2      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG              -
# 3      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG              -
# 4      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG              -
#
#                                          SE_jxc_file
# 0  AARS-BGHLV17-HepG2.set17.SE.MATS.JunctionCount...
# 1  BCCIP-BGHLV17-HepG2.set17.SE.MATS.JunctionCoun...
# 2  BCLAF1-BGHLV17-HepG2.set17.SE.MATS.JunctionCou...
# 3  CSTF2-BGHLV17-HepG2.set17.SE.MATS.JunctionCoun...
# 4  DDX27-BGHLV17-HepG2.set17.SE.MATS.JunctionCoun...
#
# [5 rows x 21 columns]

# %%
merged
# Out:
#     RNASEQ_Experiment_ID RNASEQ_RBP RNASEQ_Cell_line      RNASEQ_Replicate  \
# 0            ENCSR547NWD       AARS            HepG2        AARS_BGHLV17_1
# 1            ENCSR570CWH      BCCIP            HepG2      BCCIP_BGHLV17_45
# 2            ENCSR481AYC     BCLAF1            HepG2      BCLAF1_BGHLV17_5
# 3            ENCSR815JDY      CSTF2            HepG2      CSTF2_BGHLV17_10
# 4            ENCSR210RWL      DDX27            HepG2      DDX27_BGHLV17_53
# 5            ENCSR222CSF      DDX28            HepG2      DDX28_BGHLV17_55
# 6            ENCSR964YTW      DDX55            HepG2      DDX55_BGHLV17_59
# 7            ENCSR639LKS      FKBP4            HepG2      FKBP4_BGHLV17_15
# 8            ENCSR647NYX       NONO            HepG2       NONO_BGHLV17_61
# 9            ENCSR998MZP      PRPF8            HepG2      PRPF8_BGHLV17_23
# 10           ENCSR471GIS       RRP9            HepG2       RRP9_BGHLV17_25
# 11           ENCSR167JPY      SRP68            HepG2      SRP68_BGHLV17_29
# 12           ENCSR995RPB    SUPV3L1            HepG2    SUPV3L1_BGHLV17_31
# 13           ENCSR573UBF     TFIP11            HepG2     TFIP11_BGHLV17_33
# 14           ENCSR684HTV      UCHL5            HepG2      UCHL5_BGHLV17_37
# 15           ENCSR318OXM       UPF2            HepG2       UPF2_BGHLV17_39
# 16           ENCSR347ZHQ       XRN2            HepG2       XRN2_BGHLV17_41
# 17           ENCSR547NWD       AARS            HepG2        AARS_BGHLV17_2
# 18           ENCSR570CWH      BCCIP            HepG2      BCCIP_BGHLV17_46
# 19           ENCSR481AYC     BCLAF1            HepG2      BCLAF1_BGHLV17_6
# 20           ENCSR815JDY      CSTF2            HepG2       CSTF2_BGHLV17_9
# 21           ENCSR210RWL      DDX27            HepG2      DDX27_BGHLV17_54
# 22           ENCSR222CSF      DDX28            HepG2      DDX28_BGHLV17_56
# 23           ENCSR964YTW      DDX55            HepG2      DDX55_BGHLV17_60
# 24           ENCSR639LKS      FKBP4            HepG2      FKBP4_BGHLV17_16
# 25           ENCSR647NYX       NONO            HepG2       NONO_BGHLV17_62
# 26           ENCSR998MZP      PRPF8            HepG2      PRPF8_BGHLV17_24
# 27           ENCSR471GIS       RRP9            HepG2       RRP9_BGHLV17_26
# 28           ENCSR167JPY      SRP68            HepG2      SRP68_BGHLV17_30
# 29           ENCSR995RPB    SUPV3L1            HepG2    SUPV3L1_BGHLV17_32
# ..                   ...        ...              ...                   ...
# 914          ENCSR215FRI      PRPF4            HepG2   R-PRPF4-BGHLV37-42B
# 915          ENCSR696JWA      ZC3H8            HepG2  R-ZC3H8-BGHLV37-116B
# 916          ENCSR952OOP      CKAP4             K562      CKAP4-BGKLV36-9B
# 917          ENCSR952OOP      CKAP4             K562     CKAP4-BGKLV36-10B
# 918          ENCSR406SEH     EXOSC5             K562    EXOSC5-BGKcLV06-13
# 919          ENCSR354RSR    HNRNPH1             K562   HNRNPH1-BGKcLV06-15
# 920          ENCSR105LOV      PCBP3             K562     PCBP3-BGKcLV06-23
# 930     ENCFF757NXE     ENCFF736GGP  ENCFF976ZBW  ENCFF480QUD
# 931     ENCFF981FSJ     ENCFF130DUK  ENCFF797KWX  ENCFF448RPM
# 932     ENCFF698RES     ENCFF313AOD  ENCFF460WNJ  ENCFF846MMM
# 933     ENCFF049FJJ     ENCFF056BCC  ENCFF978PHH  ENCFF804ISR
# 934     ENCFF817WSL     ENCFF808HXX  ENCFF583XZV  ENCFF357CSV
# 935     ENCFF299OYE     ENCFF390LQU  ENCFF285OYX  ENCFF664RKO
# 936     ENCFF078GVE     ENCFF735MYQ  ENCFF040COG  ENCFF825EXV
# 937     ENCFF700VXB     ENCFF193XLA  ENCFF796QBE  ENCFF199BHE
# 938     ENCFF544FKV     ENCFF690FYM  ENCFF473QLA  ENCFF997TCP
# 939     ENCFF485AVX     ENCFF097YET  ENCFF804MGA  ENCFF351WXH
# 940     ENCFF777RYQ     ENCFF657EQL  ENCFF527EHR  ENCFF808CUS
# 941     ENCFF103ZTW     ENCFF191FIB  ENCFF924ECF  ENCFF052ZHR
# 942     ENCFF706KHZ     ENCFF514EBL  ENCFF352JTG  ENCFF277YMR
# 943     ENCFF166XSJ     ENCFF077APU  ENCFF360HRC  ENCFF875OIH
#
#                                RNASEQ_DESeq2  Rep  \
# 0        HepG2_AARS_BGHLV17_DESeq_output.txt    1
# 1       HepG2_BCCIP_BGHLV17_DESeq_output.txt    1
# 2      HepG2_BCLAF1_BGHLV17_DESeq_output.txt    1
# 3       HepG2_CSTF2_BGHLV17_DESeq_output.txt    1
# 4       HepG2_DDX27_BGHLV17_DESeq_output.txt    1
# 5       HepG2_DDX28_BGHLV17_DESeq_output.txt    1
# 6       HepG2_DDX55_BGHLV17_DESeq_output.txt    1
# 7       HepG2_FKBP4_BGHLV17_DESeq_output.txt    1
# 8        HepG2_NONO_BGHLV17_DESeq_output.txt    1
# 9       HepG2_PRPF8_BGHLV17_DESeq_output.txt    1
# 10       HepG2_RRP9_BGHLV17_DESeq_output.txt    1
# 11      HepG2_SRP68_BGHLV17_DESeq_output.txt    1
# 12    HepG2_SUPV3L1_BGHLV17_DESeq_output.txt    1
# 13     HepG2_TFIP11_BGHLV17_DESeq_output.txt    1
# 14      HepG2_UCHL5_BGHLV17_DESeq_output.txt    1
# 15       HepG2_UPF2_BGHLV17_DESeq_output.txt    1
# 16       HepG2_XRN2_BGHLV17_DESeq_output.txt    1
# 17       HepG2_AARS_BGHLV17_DESeq_output.txt    2
# 18      HepG2_BCCIP_BGHLV17_DESeq_output.txt    2
# 19     HepG2_BCLAF1_BGHLV17_DESeq_output.txt    2
# 20      HepG2_CSTF2_BGHLV17_DESeq_output.txt    2
# 21      HepG2_DDX27_BGHLV17_DESeq_output.txt    2
# 22      HepG2_DDX28_BGHLV17_DESeq_output.txt    2
# 23      HepG2_DDX55_BGHLV17_DESeq_output.txt    2
# 24      HepG2_FKBP4_BGHLV17_DESeq_output.txt    2
# 25       HepG2_NONO_BGHLV17_DESeq_output.txt    2
# 26      HepG2_PRPF8_BGHLV17_DESeq_output.txt    2
# 27       HepG2_RRP9_BGHLV17_DESeq_output.txt    2
# 28      HepG2_SRP68_BGHLV17_DESeq_output.txt    2
# 29    HepG2_SUPV3L1_BGHLV17_DESeq_output.txt    2
# ..                                       ...  ...
# 914   HepG2_PRPF4_BGHLV37_B_DESeq_output.txt    2
# 915   HepG2_ZC3H8_BGHLV37_B_DESeq_output.txt    2
# 916    K562_CKAP4_BGKLV36_B_DESeq_output.txt    1
# 917    K562_CKAP4_BGKLV36_B_DESeq_output.txt    2
# 918    K562_EXOSC5_BGKcLV06_DESeq_output.txt    1
# 919   K562_HNRNPH1_BGKcLV06_DESeq_output.txt    1
# 920     K562_PCBP3_BGKcLV06_DESeq_output.txt    1
# 921    K562_POLR2G_BGKcLV06_DESeq_output.txt    1
# 922      K562_SAFB_BGKcLV06_DESeq_output.txt    1
# 923     K562_SDAD1_BGKcLV06_DESeq_output.txt    1
# 924     K562_SRSF9_BGKcLV06_DESeq_output.txt    1
# 925   K562_SYNCRIP_BGKcLV06_DESeq_output.txt    1
# 926  K562_TRNAU1AP_BGKcLV06_DESeq_output.txt    1
# 927    K562_ZNF800_BGKcLV06_DESeq_output.txt    1
# 928    K562_EXOSC5_BGKcLV06_DESeq_output.txt    2
# 929   K562_HNRNPH1_BGKcLV06_DESeq_output.txt    2
# 930     K562_PCBP3_BGKcLV06_DESeq_output.txt    2
# 931    K562_POLR2G_BGKcLV06_DESeq_output.txt    2
# 932      K562_SAFB_BGKcLV06_DESeq_output.txt    2
# 933     K562_SDAD1_BGKcLV06_DESeq_output.txt    2
# 934     K562_SRSF9_BGKcLV06_DESeq_output.txt    2
# 935   K562_SYNCRIP_BGKcLV06_DESeq_output.txt    2
# 936  K562_TRNAU1AP_BGKcLV06_DESeq_output.txt    2
# 937    K562_ZNF800_BGKcLV06_DESeq_output.txt    2
# 938    K562_RPS3_BGKcLV04_B_DESeq_output.txt    1
# 939   K562_SRSF4_BGKcLV04_B_DESeq_output.txt    1
# 940    K562_RPS3_BGKcLV04_B_DESeq_output.txt    2
# 941   K562_SRSF4_BGKcLV04_B_DESeq_output.txt    2
# 942     K562_UTP3_BGKLV38_B_DESeq_output.txt    1
# 943     K562_UTP3_BGKLV38_B_DESeq_output.txt    2
#
#                            ...                         CONTROL_Experiment_ID  \
# 0                          ...                                   ENCSR856ZRV
# 1                          ...                                   ENCSR856ZRV
# 2                          ...                                   ENCSR856ZRV
# 3                          ...                                   ENCSR856ZRV
# 4                          ...                                   ENCSR856ZRV
# 5                          ...                                   ENCSR856ZRV
# 6                          ...                                   ENCSR856ZRV
# 7                          ...                                   ENCSR856ZRV
# 8                          ...                                   ENCSR856ZRV
# 9                          ...                                   ENCSR856ZRV
# 10                         ...                                   ENCSR856ZRV
# 11                         ...                                   ENCSR856ZRV
# 12                         ...                                   ENCSR856ZRV
# 13                         ...                                   ENCSR856ZRV
# 14                         ...                                   ENCSR856ZRV
# 15                         ...                                   ENCSR856ZRV
# 16                         ...                                   ENCSR856ZRV
# 17                         ...                                   ENCSR856ZRV
# 18                         ...                                   ENCSR856ZRV
# 19                         ...                                   ENCSR856ZRV
# 20                         ...                                   ENCSR856ZRV
# 21                         ...                                   ENCSR856ZRV
# 22                         ...                                   ENCSR856ZRV
# 23                         ...                                   ENCSR856ZRV
# 24                         ...                                   ENCSR856ZRV
# 25                         ...                                   ENCSR856ZRV
# 26                         ...                                   ENCSR856ZRV
# 27                         ...                                   ENCSR856ZRV
# 28                         ...                                   ENCSR856ZRV
# 29                         ...                                   ENCSR856ZRV
# ..                         ...                                           ...
# 914                        ...                                   ENCSR584UYK
# 915                        ...                                   ENCSR584UYK
# 916                        ...                                   ENCSR324WIS
# 917                        ...                                   ENCSR324WIS
# 918                        ...                                   ENCSR341TTW
# 919                        ...                                   ENCSR341TTW
# 920                        ...                                   ENCSR341TTW
# 921                        ...                                   ENCSR341TTW
# 922                        ...                                   ENCSR341TTW
# 923                        ...                                   ENCSR341TTW
# 924                        ...                                   ENCSR341TTW
# 925                        ...                                   ENCSR341TTW
# 926                        ...                                   ENCSR341TTW
# 927                        ...                                   ENCSR341TTW
# 928                        ...                                   ENCSR341TTW
# 929                        ...                                   ENCSR341TTW
# 930                        ...                                   ENCSR341TTW
# 931                        ...                                   ENCSR341TTW
# 932                        ...                                   ENCSR341TTW
# 933                        ...                                   ENCSR341TTW
# 934                        ...                                   ENCSR341TTW
# 935                        ...                                   ENCSR341TTW
# 936                        ...                                   ENCSR341TTW
# 937                        ...                                   ENCSR341TTW
# 938                        ...                                   ENCSR772DUM
# 939                        ...                                   ENCSR772DUM
# 940                        ...                                   ENCSR772DUM
# 941                        ...                                   ENCSR772DUM
# 942                        ...                                   ENCSR024FOF
# 943                        ...                                   ENCSR024FOF
#
#     CONTROL_RBP CONTROL_Cell_line CONTROL_Replicate CONTROL_FASTQ_R1  \
# 0    non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 1    non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 2    non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 3    non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 4    non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 5    non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 6    non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 7    non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 8    non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 9    non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 10   non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 11   non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 12   non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 13   non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 14   non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 15   non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 16   non-target             HepG2     NT_BGHLV17_63      ENCFF385GEX
# 941  SRSF4-BGKcLV04-K562.set39_K.SE.MATS.JunctionCo...
# 942  UTP3-BGKLV38-K562.set39_K.SE.MATS.JunctionCoun...
# 943  UTP3-BGKLV38-K562.set39_K.SE.MATS.JunctionCoun...
#
# [944 rows x 21 columns]

# %% [markdown]
# # Create master manifest file (including eCLIP files)

# %%
final_submitted_eclip_manifest = pd.read_table(
    '/projects/ps-yeolab3/bay001/reference_data/misc_ENCODE/eCLIP_finalstatus_20180404_ENCODE.tsv' # should be 2018, but same file so oh well
)
final_submitted_eclip_manifest.columns = ['eCLIP_'+c.replace(' ','_') for c in final_submitted_eclip_manifest.columns]
final_submitted_eclip_manifest[['eCLIP_uID']] = final_submitted_eclip_manifest[['eCLIP_uID']].astype('string')
final_submitted_eclip_manifest.head()
# Out:
#   eCLIP_uID eCLIP_Official_Gene_Symbol eCLIP_Final_internal_accession  \
# 0       284                      DDX21                    284x4000fix
# 1       406                     PABPC4                            406
# 2       416                        WRN                            416
# 3       218                      TRA2A                            218
# 4       220                    IGF2BP1                            220
#
#             eCLIP_Submission_status eCLIP_Antibody_Cat_# eCLIP_Antibody_Lot_#  \
# 0  DONE - 2 reps submitted 11/02/17              RN090PW                  001
# 1  DONE - 2 reps submitted 11/02/17            A301-466A                  001
# 2  DONE - 2 reps submitted 11/02/17            GTX101081                39812
# 3   DONE - 2 reps submitted 6/28/15            A303-779A                  001
# 4   DONE - 2 reps submitted 6/28/15               RN007P                  003
#
#   eCLIP_Cell_Line
# 0            K562
# 1            K562
# 2            K562
# 3           HepG2
# 4            K562

# %%
final_submitted_eclip_manifest
# Out:
#     eCLIP_uID eCLIP_Official_Gene_Symbol eCLIP_Final_internal_accession  \
# 0         284                      DDX21                    284x4000fix
# 1         406                     PABPC4                            406
# 2         416                        WRN                            416
# 3         218                      TRA2A                            218
# 4         220                    IGF2BP1                            220
# 5         222                     HNRNPM                            222
# 6         223                      FKBP4                            223
# 7         224                     HNRNPM                            224
# 8         226                    IGF2BP2                            226
# 9         230                      BCCIP                            230
# 10        236                       FMR1                            236
# 11        240                      TRA2A                            240
# 12        241                      DDX42                            241
# 13        242                      U2AF2                            242
# 14        243                      LARP7                            243
# 15        244                      U2AF1                            244
# 16        245                       XRN2                            245
# 17        247                    HNRNPA1                            247
# 18        249                     HNRNPU                            249
# 19        256                       SLTM                            256
# 20        258                      CPSF6                            258
# 21        260                     EIF4G2                            260
# 22        262                       SLBP                            262
# 23        267                      SAFB2                            267
# 24        278                      PRPF8                            278
# 25        281                     HNRNPU                            281
# 26        283                    HNRNPA1                            283
# 27        205                    IGF2BP1                            205
# 28        211                    IGF2BP3                            211
# 29        215                       TIA1                            215
# ..        ...                        ...                            ...
# 193       614                      RPS11                            614
# 194       617                      TBRG4                            617
# 195       624                       AARS                            624
# 196       625                      EIF3D                            625
# 197       628                      GRWD1                            628
# 198       629                      UCHL5                            629
# 199       631                     EFTUD2                            631
# 200       641                    ZC3H11A                            641
# 201       235                       XRN2                       235x4000
# 202       493                       ILF3                            493
# 203       571                      FUBP3                            571
# 204       572                      CSTF2                            572
# 205       575                     DROSHA                            575
# 206       610                      UCHL5                            610
# 207       632                       SUB1                           632x
# 208       649                    FASTKD2                            649
# 209       650                    SUPV3L1                            650
# 210       652                      SUGP2                            652
# 211       654                      DHX30                            654
# 212       655                       XPO5                            655
# 213       668                       PUS1                            668
# 214       676                     RBFOX2                            676
# 215       677                     GEMIN5                            677
# 216       678                     HNRNPL                            678
# 217       682                      DHX30                            682
# 218       684                    ZC3H11A                            684
# 219       693                     SERBP1                            693
# 220       695                      MATR3                            695
# 221       696                      PTBP1                            696
# 222       414                      PPIL4                            414
#
#               eCLIP_Submission_status eCLIP_Antibody_Cat_#  \
# 0    DONE - 2 reps submitted 11/02/17              RN090PW
# 1    DONE - 2 reps submitted 11/02/17            A301-466A
# 2    DONE - 2 reps submitted 11/02/17            GTX101081
# 3     DONE - 2 reps submitted 6/28/15            A303-779A
# 4     DONE - 2 reps submitted 6/28/15               RN007P
# 5     DONE - 2 reps submitted 6/28/15             SC-20001
# 6     DONE - 2 reps submitted 6/28/15            A301-427A
# 7     DONE - 2 reps submitted 6/28/15             SC-20001
# 8     DONE - 2 reps submitted 6/28/15               RN008P
# 9     DONE - 2 reps submitted 6/28/15            A302-196A
# 10    DONE - 2 reps submitted 6/28/15               RN016P
# 11    DONE - 2 reps submitted 6/28/15            A303-779A
# 12    DONE - 2 reps submitted 6/28/15            A303-353A
# 13    DONE - 2 reps submitted 6/28/15            A303-665A
# 14    DONE - 2 reps submitted 6/28/15            A303-723A
# 15    DONE - 2 reps submitted 6/28/15            A302-079A
# 16    DONE - 2 reps submitted 6/28/15            A301-103A
# 17    DONE - 2 reps submitted 6/28/15              sc32301
# 18    DONE - 2 reps submitted 6/28/15              sc32315
# 19    DONE - 2 reps submitted 6/28/15            A302-834A
# 20    DONE - 2 reps submitted 6/28/15            A301-356A
# 21    DONE - 2 reps submitted 6/28/15               RN003P
# 22    DONE - 2 reps submitted 6/28/15               RN045P
# 23    DONE - 2 reps submitted 6/28/15            A301-112A
# 24    DONE - 2 reps submitted 6/28/15            A303-921A
# 25    DONE - 2 reps submitted 6/28/15             sc-32315
# 26    DONE - 2 reps submitted 6/28/15             sc-32301
# 27   DONE - 2 reps submitted 6/28/15                RN007P
# 28   DONE - 2 reps submitted 6/28/15                RN009P
# 29   DONE - 2 reps submitted 6/28/15                RN014P
# ..                                ...                  ...
# 193         DONE - submitted 20160315            A303-936A
# 194         DONE - submitted 20160315            A301-392A
# 195         DONE - submitted 20160315            A303-475A
# 196         DONE - submitted 20160315            A301-758A
# 197         DONE - submitted 20160315            A301-576A
# 198         DONE - submitted 20160315            A304-099A
# 199         DONE - submitted 20160315            A300-957A
# 200         DONE - submitted 20160315            A301-524A
# 201    DONE - submitted 20160315 4000            A301-103A
# 202         DONE - submitted 20160730            A303-651A
# 203         DONE - submitted 20160730            A303-012A
# 204         DONE - submitted 20160730            A301-092A
# 205         DONE - submitted 20160730            A301-886A
# 206         DONE - submitted 20160730            A304-099A
# 207         DONE - submitted 20160730            A301-161A
# 208         DONE - submitted 20160730            A303-788A
# 209         DONE - submitted 20160730            A303-056A
# 210         DONE - submitted 20160730            A301-607A
# 211         DONE - submitted 20160730            A302-218A
# 212         DONE - submitted 20160730            A303-991A
# 213         DONE - submitted 20160730            A301-651A
# 214         DONE - submitted 20160730            A300-864A
# 215         DONE - submitted 20160730            A301-325A
# 216         DONE - submitted 20160730               ab6106
# 217         DONE - submitted 20160730            A302-218A
# 218         DONE - submitted 20160730            A301-524A
# 219         DONE - submitted 20160730              RN056PW
# 220         DONE - submitted 20160730             ab151714
# 221         DONE - submitted 20160730               RN011P
# 222           DONE submitted 20160305            GTX117014
#
#     eCLIP_Antibody_Lot_# eCLIP_Cell_Line
# 0                    001            K562
# 1                    001            K562
# 2                  39812            K562
# 3                    001           HepG2
# 4                    003            K562
# 5                  D1304           HepG2
# 6                    001           HepG2
# 7                  D1304            K562
# 8                    002            K562
# 9                    001           HepG2
# 10                   001            K562
# 11                   001            K562
# 12                   001            K562
# 13                   001            K562
# 14                   001            K562
# 15                   001            K562
# 16                   001            K562
# 17                 12413            K562
# 18                 C3012            K562
# 19                   001            K562
# 20                   001            K562
# 21                   001            K562
# 22                   001            K562
# 23                   001            K562
# 24                   001            K562
# 25                 C3102           HepG2
# 26                 12413           HepG2
# 27                   003           HepG2
# 28                   002           HepG2
# 29                   001           HepG2
# ..                   ...             ...
# 193                  001            K562
# 194                  001           HepG2
# 195                  001            K562
# 196                  001           HepG2
# 197                  001           HepG2
# 198                  001           HepG2
# 199                  001           HepG2
# 200                  001           HepG2
# 201                  001           HepG2
# 202                  001           HepG2
# 203                  001           HepG2
# 204                  001           HepG2
# 205                  001           HepG2
# 206                  001            K562
# 207                  001           HepG2
# 208                  001           HepG2
# 209                  001           HepG2
# 210                  001           HepG2
# 211                  001           HepG2
# 212                  001           HepG2
# 213                  001            K562
# 214                  002            K562
# 215                  001            K562
# 216           GR30383-24           HepG2
# 217                  001            K562
# 218                  001            K562
# 219                  001            K562
# 220           GR108745-9           HepG2
# 221                  001           HepG2
# 222                40555            K562
#
# [223 rows x 7 columns]

# %%
del merged['CONTROL_DESeq2']

# %% [markdown]
# # Amend official RBP names vs Xintao's names

# %%
merged.head()
# Out:
#   RNASEQ_Experiment_ID RNASEQ_RBP RNASEQ_Cell_line  RNASEQ_Replicate  \
# 0          ENCSR547NWD       AARS            HepG2    AARS_BGHLV17_1
# 1          ENCSR570CWH      BCCIP            HepG2  BCCIP_BGHLV17_45
# 2          ENCSR481AYC     BCLAF1            HepG2  BCLAF1_BGHLV17_5
# 3          ENCSR815JDY      CSTF2            HepG2  CSTF2_BGHLV17_10
# 4          ENCSR210RWL      DDX27            HepG2  DDX27_BGHLV17_53
#
#   RNASEQ_FASTQ_R1 RNASEQ_FASTQ_R2   RNASEQ_BAM   RNASEQ_TSV  \
# 0     ENCFF488SPX     ENCFF464UID  ENCFF604SNM  ENCFF739CVP
# 1     ENCFF291SQT     ENCFF225QRN  ENCFF022PCS  ENCFF938GXB
# 2     ENCFF182RAD     ENCFF863SFE  ENCFF775APS  ENCFF670VTV
# 3     ENCFF041YGN     ENCFF909LAP  ENCFF116TYA  ENCFF568ZNU
# 4     ENCFF265RYO     ENCFF554LIG  ENCFF495SBM  ENCFF311UBJ
#
#                            RNASEQ_DESeq2  Rep RNASEQ_Control_Experiment_ID  \
# 0    HepG2_AARS_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
# 1   HepG2_BCCIP_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
# 2  HepG2_BCLAF1_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
# 3   HepG2_CSTF2_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
# 4   HepG2_DDX27_BGHLV17_DESeq_output.txt    1                  ENCSR856ZRV
#
#   CONTROL_Experiment_ID CONTROL_RBP CONTROL_Cell_line CONTROL_Replicate  \
# 0           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 1           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 2           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 3           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 4           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
#
#   CONTROL_FASTQ_R1 CONTROL_FASTQ_R2  CONTROL_BAM  CONTROL_TSV  \
# 0      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG
# 1      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG
# 2      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG
# 3      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG
# 4      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG
#
#                                          SE_jxc_file
# 0  AARS-BGHLV17-HepG2.set17.SE.MATS.JunctionCount...
# 1  BCCIP-BGHLV17-HepG2.set17.SE.MATS.JunctionCoun...
# 2  BCLAF1-BGHLV17-HepG2.set17.SE.MATS.JunctionCou...
# 3  CSTF2-BGHLV17-HepG2.set17.SE.MATS.JunctionCoun...
# 4  DDX27-BGHLV17-HepG2.set17.SE.MATS.JunctionCoun...

# %%
x2official = {
    'CSDA':'YBX3',
    'RNASEN50':'DROSHA',
    'EIF2C1':'AGO1',
    'CUGBP1':'CELF1',
    'PKM2':'PKM',
    'KIAA1967':'CCAR2',
    'RDBP':'NELFE',
#     'GNB2L1':'RACK1',
}
def convert2official(row, x2official=x2official):
    try:
        return x2official[row['RNASEQ_RBP']]
    except KeyError:
        return row['RNASEQ_RBP']

merged['RNASEQ_Official_RBP'] = merged.apply(convert2official, axis=1)
merged.head()
# Out:
#   RNASEQ_Experiment_ID RNASEQ_RBP RNASEQ_Cell_line  RNASEQ_Replicate  \
# 0          ENCSR547NWD       AARS            HepG2    AARS_BGHLV17_1
# 1          ENCSR570CWH      BCCIP            HepG2  BCCIP_BGHLV17_45
# 2          ENCSR481AYC     BCLAF1            HepG2  BCLAF1_BGHLV17_5
# 3          ENCSR815JDY      CSTF2            HepG2  CSTF2_BGHLV17_10
# 4          ENCSR210RWL      DDX27            HepG2  DDX27_BGHLV17_53
#
#   RNASEQ_FASTQ_R1 RNASEQ_FASTQ_R2   RNASEQ_BAM   RNASEQ_TSV  \
# 0     ENCFF488SPX     ENCFF464UID  ENCFF604SNM  ENCFF739CVP
# 1     ENCFF291SQT     ENCFF225QRN  ENCFF022PCS  ENCFF938GXB
# 2     ENCFF182RAD     ENCFF863SFE  ENCFF775APS  ENCFF670VTV
# 3     ENCFF041YGN     ENCFF909LAP  ENCFF116TYA  ENCFF568ZNU
# 4     ENCFF265RYO     ENCFF554LIG  ENCFF495SBM  ENCFF311UBJ
#
#                            RNASEQ_DESeq2  Rep         ...          \
# 0    HepG2_AARS_BGHLV17_DESeq_output.txt    1         ...
# 1   HepG2_BCCIP_BGHLV17_DESeq_output.txt    1         ...
# 2  HepG2_BCLAF1_BGHLV17_DESeq_output.txt    1         ...
# 3   HepG2_CSTF2_BGHLV17_DESeq_output.txt    1         ...
# 4   HepG2_DDX27_BGHLV17_DESeq_output.txt    1         ...
#
#   CONTROL_Experiment_ID CONTROL_RBP CONTROL_Cell_line CONTROL_Replicate  \
# 0           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 1           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 2           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 3           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
# 4           ENCSR856ZRV  non-target             HepG2     NT_BGHLV17_63
#
#   CONTROL_FASTQ_R1 CONTROL_FASTQ_R2  CONTROL_BAM  CONTROL_TSV  \
# 0      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG
# 1      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG
# 2      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG
# 3      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG
# 4      ENCFF385GEX      ENCFF922CDR  ENCFF705LNP  ENCFF231SUG
#
#                                          SE_jxc_file RNASEQ_Official_RBP
# 0  AARS-BGHLV17-HepG2.set17.SE.MATS.JunctionCount...                AARS
# 1  BCCIP-BGHLV17-HepG2.set17.SE.MATS.JunctionCoun...               BCCIP
# 2  BCLAF1-BGHLV17-HepG2.set17.SE.MATS.JunctionCou...              BCLAF1
# 3  CSTF2-BGHLV17-HepG2.set17.SE.MATS.JunctionCoun...               CSTF2
# 4  DDX27-BGHLV17-HepG2.set17.SE.MATS.JunctionCoun...               DDX27
#
# [5 rows x 21 columns]

# %%
merged = pd.merge(
    final_submitted_eclip_manifest, 
    merged, 
    how='outer',
    left_on=['eCLIP_Official_Gene_Symbol', 'eCLIP_Cell_Line'],
    right_on=['RNASEQ_Official_RBP', 'RNASEQ_Cell_line']
)

merged.to_csv(
    '/projects/ps-yeolab3/bay001/reference_data/misc_ENCODE/eCLIP_finalstatus_20180406_ENCODE_combined_RNASEQ.tsv',
    sep='\t',
    index=False,
    header=True
)

# %%
rep1 = merged[merged['Rep']==1]
rep2 = merged[merged['Rep']==2]
others = merged[(merged['Rep']!=1) & (merged['Rep']!=2)]
rep1 = pd.concat([rep1, others], axis=0)
rep1.head()
# Out:
#   eCLIP_uID eCLIP_Official_Gene_Symbol eCLIP_Final_internal_accession  \
# 0       284                      DDX21                    284x4000fix
# 2       406                     PABPC4                            406
# 4       416                        WRN                            416
# 6       218                      TRA2A                            218
# 8       220                    IGF2BP1                            220
#
#             eCLIP_Submission_status eCLIP_Antibody_Cat_# eCLIP_Antibody_Lot_#  \
# 0  DONE - 2 reps submitted 11/02/17              RN090PW                  001
# 2  DONE - 2 reps submitted 11/02/17            A301-466A                  001
# 4  DONE - 2 reps submitted 11/02/17            GTX101081                39812
# 6   DONE - 2 reps submitted 6/28/15            A303-779A                  001
# 8   DONE - 2 reps submitted 6/28/15               RN007P                  003
#
#   eCLIP_Cell_Line RNASEQ_Experiment_ID RNASEQ_RBP RNASEQ_Cell_line  \
# 0            K562          ENCSR384LKC      DDX21             K562
# 2            K562          ENCSR047EEG     PABPC4             K562
# 4            K562          ENCSR165BCF        WRN             K562
# 6           HepG2          ENCSR030GZQ      TRA2A            HepG2
# 8            K562          ENCSR543LCG    IGF2BP1             K562
#
#           ...         CONTROL_Experiment_ID CONTROL_RBP CONTROL_Cell_line  \
# 0         ...                   ENCSR163JUC  non-target              K562
# 2         ...                   ENCSR344XID  non-target              K562
# 4         ...                   ENCSR718EWL  non-target              K562
# 6         ...                   ENCSR491FOC  non-target             HepG2
# 8         ...                   ENCSR163JUC  non-target              K562
#
#            CONTROL_Replicate CONTROL_FASTQ_R1 CONTROL_FASTQ_R2  CONTROL_BAM  \
# 0              NT_BGKcLV02-1      ENCFF076EAI      ENCFF478ILB  ENCFF157TKC
# 2  Nontarget-LV08-1_00003531      ENCFF759IRT      ENCFF963MPW  ENCFF092XAP
# 4               NT_BGKLV38-1      ENCFF409FXM      ENCFF698ZGA  ENCFF995IVQ
# 6               NT_BGHLV14-1      ENCFF510FRX      ENCFF409JQD  ENCFF499UUZ
# 8              NT_BGKcLV02-1      ENCFF076EAI      ENCFF478ILB  ENCFF157TKC
#
#    CONTROL_TSV                                        SE_jxc_file  \
# 0  ENCFF412XQF  DDX21-BGKcLV02-K562.BGKcLV02.SE.MATS.JunctionC...
# 2  ENCFF115OOZ  PABPC4-LV08-K562.set10.SE.MATS.JunctionCountOn...
# 4  ENCFF699ZGX  WRN-BGKLV38-K562.set38.SE.MATS.JunctionCountOn...
# 6  ENCFF043ORB  TRA2A-BGHLV14-HepG2.set14.SE.MATS.JunctionCoun...
# 8  ENCFF412XQF  IGF2BP1-BGKcLV02-K562.BGKcLV02.SE.MATS.Junctio...
#
#   RNASEQ_Official_RBP
# 0               DDX21
# 2              PABPC4
# 4                 WRN
# 6               TRA2A
# 8             IGF2BP1
#
# [5 rows x 28 columns]

# %%
merged_with_reps = pd.merge(
    rep1, 
    rep2, 
    how='outer', 
    left_on=[
        'eCLIP_uID','eCLIP_Official_Gene_Symbol','eCLIP_Final_internal_accession','eCLIP_Submission_status',
        'eCLIP_Antibody_Cat_#','eCLIP_Antibody_Lot_#','eCLIP_Cell_Line','RNASEQ_Experiment_ID',
        'RNASEQ_RBP','RNASEQ_Official_RBP','RNASEQ_Cell_line',
        'RNASEQ_DESeq2','RNASEQ_Control_Experiment_ID','CONTROL_Experiment_ID','CONTROL_RBP',
        'CONTROL_Cell_line','SE_jxc_file'
    ],
    right_on=[
        'eCLIP_uID','eCLIP_Official_Gene_Symbol','eCLIP_Final_internal_accession','eCLIP_Submission_status',
        'eCLIP_Antibody_Cat_#','eCLIP_Antibody_Lot_#','eCLIP_Cell_Line','RNASEQ_Experiment_ID',
        'RNASEQ_RBP','RNASEQ_Official_RBP','RNASEQ_Cell_line',
        'RNASEQ_DESeq2','RNASEQ_Control_Experiment_ID','CONTROL_Experiment_ID','CONTROL_RBP',
        'CONTROL_Cell_line','SE_jxc_file'
    ]
)

# %%
merged_with_reps.columns = [c.replace('_x','_rep1').replace('_y','_rep2') for c in merged_with_reps.columns]

# %%
merged_with_reps
# Out:
#     eCLIP_uID eCLIP_Official_Gene_Symbol eCLIP_Final_internal_accession  \
# 0         284                      DDX21                    284x4000fix
# 1         406                     PABPC4                            406
# 2         416                        WRN                            416
# 3         218                      TRA2A                            218
# 4         220                    IGF2BP1                            220
# 5         222                     HNRNPM                            222
# 6         223                      FKBP4                            223
# 7         224                     HNRNPM                            224
# 8         226                    IGF2BP2                            226
# 9         230                      BCCIP                            230
# 10        236                       FMR1                            236
# 11        240                      TRA2A                            240
# 12        242                      U2AF2                            242
# 13        243                      LARP7                            243
# 14        244                      U2AF1                            244
# 15        245                       XRN2                            245
# 16        247                    HNRNPA1                            247
# 17        249                     HNRNPU                            249
# 18        256                       SLTM                            256
# 19        258                      CPSF6                            258
# 20        260                     EIF4G2                            260
# 21        262                       SLBP                            262
# 22        267                      SAFB2                            267
# 23        278                      PRPF8                            278
# 24        281                     HNRNPU                            281
# 25        283                    HNRNPA1                            283
# 26        205                    IGF2BP1                            205
# 27        211                    IGF2BP3                            211
# 28        215                       TIA1                            215
# 29        216                      SRSF9                            216
# ..        ...                        ...                            ...
# 462       NaN                        NaN                            NaN
# 463       NaN                        NaN                            NaN
# 464       NaN                        NaN                            NaN
# 465       NaN                        NaN                            NaN
# 466       NaN                        NaN                            NaN
# 467       NaN                        NaN                            NaN
# 468       NaN                        NaN                            NaN
# 469       NaN                        NaN                            NaN
# 470       NaN                        NaN                            NaN
# 471       NaN                        NaN                            NaN
# 472       241                      DDX42                            241
# 473       341                      DGCR8                            341
# 474       358                       GNL3                            358
# 475       367                      YWHAG                            367
# 476       565                      NIPBL                            565
# 477       593                      STAU2                            593
# 478       602                      WDR43                            602
# 479       713                       FXR2                            713
# 480       743                     ZNF800                            743
# 481       745                       SAFB                            745
# 482       750                     PABPN1                            750
# 483       762                        AQR                            762
# 484       383                      DGCR8                            383
# 485       484                     POLR2G                            484
# 486       516                      NOLC1                            516
# 487       540                       RPS3                            540
# 488       570                     ZNF622                            570
# 489       614                      RPS11                            614
# 490       641                    ZC3H11A                            641
# 491       684                    ZC3H11A                            684
#
#               eCLIP_Submission_status   eCLIP_Antibody_Cat_#  \
# 0    DONE - 2 reps submitted 11/02/17                RN090PW
# 1    DONE - 2 reps submitted 11/02/17              A301-466A
# 2    DONE - 2 reps submitted 11/02/17              GTX101081
# 3     DONE - 2 reps submitted 6/28/15              A303-779A
# 4     DONE - 2 reps submitted 6/28/15                 RN007P
# 5     DONE - 2 reps submitted 6/28/15               SC-20001
# 6     DONE - 2 reps submitted 6/28/15              A301-427A
# 7     DONE - 2 reps submitted 6/28/15               SC-20001
# 8     DONE - 2 reps submitted 6/28/15                 RN008P
# 9     DONE - 2 reps submitted 6/28/15              A302-196A
# 10    DONE - 2 reps submitted 6/28/15                 RN016P
# 11    DONE - 2 reps submitted 6/28/15              A303-779A
# 12    DONE - 2 reps submitted 6/28/15              A303-665A
# 13    DONE - 2 reps submitted 6/28/15              A303-723A
# 14    DONE - 2 reps submitted 6/28/15              A302-079A
# 15    DONE - 2 reps submitted 6/28/15              A301-103A
# 16    DONE - 2 reps submitted 6/28/15                sc32301
# 17    DONE - 2 reps submitted 6/28/15                sc32315
# 18    DONE - 2 reps submitted 6/28/15              A302-834A
# 19    DONE - 2 reps submitted 6/28/15              A301-356A
# 20    DONE - 2 reps submitted 6/28/15                 RN003P
# 21    DONE - 2 reps submitted 6/28/15                 RN045P
# 22    DONE - 2 reps submitted 6/28/15              A301-112A
# 23    DONE - 2 reps submitted 6/28/15              A303-921A
# 24    DONE - 2 reps submitted 6/28/15               sc-32315
# 25    DONE - 2 reps submitted 6/28/15               sc-32301
# 26   DONE - 2 reps submitted 6/28/15                  RN007P
# 27   DONE - 2 reps submitted 6/28/15                  RN009P
# 28   DONE - 2 reps submitted 6/28/15                  RN014P
# 29   DONE - 2 reps submitted 6/28/15                 RN081PW
# ..                                ...                    ...
# 462                               NaN                    NaN
# 463                               NaN                    NaN
# 464                               NaN                    NaN
# 465                               NaN                    NaN
# 466                               NaN                    NaN
# 467                               NaN                    NaN
# 468                               NaN                    NaN
# 469                               NaN                    NaN
# 470                               NaN                    NaN
# 471                               NaN                    NaN
# 472   DONE - 2 reps submitted 6/28/15              A303-353A
# 473   DONE - 2 reps submitted 9/22/15              A302-468A
# 474   DONE - 2 reps submitted 9/22/15              A300-599A
# 475   DONE - 2 reps submitted 9/22/15              GTX113298
# 476         DONE - Submitted 11/02/17  custom (Yokomori lab)
# 477          DONE - submitted 11/2/17                 RN013P
# 478          DONE - submitted 11/2/17              A302-478A
# 479          DONE - submitted 11/2/17              A303-894A
# 480          DONE - submitted 11/2/17              A303-283A
# 481          DONE - submitted 11/2/17  Zen bioscience 200580
# 482          DONE - submitted 11/2/17                RN023PW
# 483          DONE - submitted 11/2/17              A302-547A
# 484         DONE - Submitted 20151210              A302-468A
# 485         DONE - Submitted 20151210              GTX108874
# 486         DONE - submitted 20160305              A302-184A
# 487         DONE - submitted 20160305              A303-840A
# 488         DONE - submitted 20160315              A304-075A
# 489         DONE - submitted 20160315              A303-936A
# 490         DONE - submitted 20160315              A301-524A
# 491         DONE - submitted 20160730              A301-524A
#
#     eCLIP_Antibody_Lot_# eCLIP_Cell_Line RNASEQ_Experiment_ID RNASEQ_RBP  \
# 0                    001            K562          ENCSR384LKC      DDX21
# 1                    001            K562          ENCSR047EEG     PABPC4
# 2                  39812            K562          ENCSR165BCF        WRN
# 3                    001           HepG2          ENCSR030GZQ      TRA2A
# 4                    003            K562          ENCSR543LCG    IGF2BP1
# 5                  D1304           HepG2          ENCSR995JMS     HNRNPM
# 6                    001           HepG2          ENCSR639LKS      FKBP4
# 7                  D1304            K562          ENCSR746NIM     HNRNPM
# 8                    002            K562          ENCSR952RRH    IGF2BP2
# 9                    001           HepG2          ENCSR570CWH      BCCIP
# 10                   001            K562          ENCSR555LCE       FMR1
# 11                   001            K562          ENCSR916WOI      TRA2A
# 12                   001            K562          ENCSR904CJQ      U2AF2
# 13                   001            K562          ENCSR770OWW      LARP7
# 14                   001            K562          ENCSR342EDG      U2AF1
# 15                   001            K562          ENCSR717SJA       XRN2
# 16                 12413            K562          ENCSR048BWH    HNRNPA1
# 17                 C3012            K562          ENCSR047IUS     HNRNPU
# 18                   001            K562          ENCSR234YMW       SLTM
# 19                   001            K562          ENCSR384BDV      CPSF6
# 20                   001            K562          ENCSR040FSN     EIF4G2
# 21                   001            K562          ENCSR112YTD       SLBP
# 22                   001            K562          ENCSR770LYW      SAFB2
# 23                   001            K562          ENCSR137HKS      PRPF8
# 24                 C3102           HepG2          ENCSR308IKH     HNRNPU
# 25                 12413           HepG2          ENCSR182DAW    HNRNPA1
# 26                   003           HepG2          ENCSR268XHM    IGF2BP1
# 27                   002           HepG2          ENCSR710NWE    IGF2BP3
# 28                   001           HepG2          ENCSR057GCF       TIA1
# 29                   001           HepG2          ENCSR597XHH      SRSF9
# ..                   ...             ...                  ...        ...
# 462                  NaN             NaN          ENCSR166MWM      RBM14
# 463                  NaN             NaN          ENCSR696JWA      ZC3H8
# 464                  NaN             NaN          ENCSR952OOP      CKAP4
# 465                  NaN             NaN          ENCSR354RSR    HNRNPH1
# 466                  NaN             NaN          ENCSR105LOV      PCBP3
# 467                  NaN             NaN          ENCSR580TGX     POLR2G
# 468                  NaN             NaN          ENCSR972AZD      SRSF9
# 469                  NaN             NaN          ENCSR680OJB    SYNCRIP
# 470                  NaN             NaN          ENCSR889MBF   TRNAU1AP
# 471                  NaN             NaN          ENCSR905NIK      SRSF4
# 472                  001            K562                  NaN        NaN
# 473                  001            K562                  NaN        NaN
# 474                  001            K562                  NaN        NaN
# 475                40128            K562                  NaN        NaN
# 476                   --            K562                  NaN        NaN
# 477                  001           HepG2                  NaN        NaN
# 478                  001           HepG2                  NaN        NaN
# 479                  001           HepG2                  NaN        NaN
# 480                  001           HepG2                  NaN        NaN
# 481                  NaN           HepG2                  NaN        NaN
# 482                  001           HepG2                  NaN        NaN
# 483                  001           HepG2                  NaN        NaN
# 484                  001           HepG2                  NaN        NaN
# 485                40023           HepG2                  NaN        NaN
# 486                  001            K562                  NaN        NaN
# 487                  001           HepG2                  NaN        NaN
# 488                  001            K562                  NaN        NaN
# 489                  001            K562                  NaN        NaN
# 490                  001           HepG2                  NaN        NaN
# 491                  001            K562                  NaN        NaN
#
#     RNASEQ_Cell_line       ...        RNASEQ_FASTQ_R1_rep2  \
# 0               K562       ...                 ENCFF704MDH
# 1               K562       ...                 ENCFF457DTV
# 2               K562       ...                 ENCFF931PKC
# 3              HepG2       ...                 ENCFF808UZU
# 4               K562       ...                 ENCFF772HHV
# 5              HepG2       ...                 ENCFF592ZZR
# 6              HepG2       ...                 ENCFF663YGQ
# 7               K562       ...                 ENCFF160TRI
# 8               K562       ...                 ENCFF255GDS
# 9              HepG2       ...                 ENCFF135KIN
# 10              K562       ...                 ENCFF199PVY
# 11              K562       ...                 ENCFF523XON
# 12              K562       ...                 ENCFF593VXV
# 13              K562       ...                 ENCFF233GFO
# 14              K562       ...                 ENCFF365IMS
# 15              K562       ...                 ENCFF878WHV
# 16              K562       ...                 ENCFF015PIM
# 17              K562       ...                 ENCFF698DQF
# 18              K562       ...                 ENCFF905SLK
# 19              K562       ...                 ENCFF928HOG
# 20              K562       ...                 ENCFF680ODC
# 21              K562       ...                 ENCFF519RFX
# 22              K562       ...                 ENCFF665ONM
# 23              K562       ...                 ENCFF664ZQE
# 24             HepG2       ...                 ENCFF057KLZ
# 25             HepG2       ...                 ENCFF196EOX
# 26             HepG2       ...                 ENCFF641TDC
# 27             HepG2       ...                 ENCFF873TWM
# 28             HepG2       ...                 ENCFF578TWY
# 29             HepG2       ...                 ENCFF763ICV
# ..               ...       ...                         ...
# 462            HepG2       ...                 ENCFF732HIC
# 463            HepG2       ...                 ENCFF993RFY
# 464             K562       ...                 ENCFF610CWD
# 465             K562       ...                 ENCFF155CZF
# 466             K562       ...                 ENCFF757NXE
# 467             K562       ...                 ENCFF981FSJ
# 468             K562       ...                 ENCFF817WSL
# 469             K562       ...                 ENCFF299OYE
# 470             K562       ...                 ENCFF078GVE
# 471             K562       ...                 ENCFF103ZTW
# 472              NaN       ...                         NaN
# 473              NaN       ...                         NaN
# 474              NaN       ...                         NaN
# 475              NaN       ...                         NaN
# 476              NaN       ...                         NaN
# 477              NaN       ...                         NaN
# 478              NaN       ...                         NaN
# 479              NaN       ...                         NaN
# 480              NaN       ...                         NaN
# 481              NaN       ...                         NaN
# 482              NaN       ...                         NaN
# 483              NaN       ...                         NaN
# 484              NaN       ...                         NaN
# 485              NaN       ...                         NaN
# 486              NaN       ...                         NaN
# 487              NaN       ...                         NaN
# 488              NaN       ...                         NaN
# 489              NaN       ...                         NaN
# 21       ENCFF804JHE      ENCFF015IHM
# 22       ENCFF583INI      ENCFF230OGW
# 23       ENCFF362TIW      ENCFF982PUC
# 24       ENCFF058QDT      ENCFF939PSG
# 25       ENCFF058QDT      ENCFF939PSG
# 26       ENCFF134QUL      ENCFF816DSO
# 27       ENCFF052HTH      ENCFF025LXR
# 28       ENCFF571ARP      ENCFF262BZV
# 29       ENCFF571ARP      ENCFF262BZV
# ..               ...              ...
# 462      ENCFF872YYA      ENCFF879PGY
# 463      ENCFF752TEZ      ENCFF502YGT
# 464      ENCFF534KMT      ENCFF200XDQ
# 465      ENCFF986GCV      ENCFF201DUU
# 466      ENCFF986GCV      ENCFF201DUU
# 467      ENCFF986GCV      ENCFF201DUU
# 468      ENCFF986GCV      ENCFF201DUU
# 469      ENCFF986GCV      ENCFF201DUU
# 470      ENCFF986GCV      ENCFF201DUU
# 471      ENCFF214DWG      ENCFF175DQA
# 472              NaN              NaN
# 473              NaN              NaN
# 474              NaN              NaN
# 475              NaN              NaN
# 476              NaN              NaN
# 477              NaN              NaN
# 478              NaN              NaN
# 479              NaN              NaN
# 480              NaN              NaN
# 481              NaN              NaN
# 482              NaN              NaN
# 483              NaN              NaN
# 484              NaN              NaN
# 485              NaN              NaN
# 486              NaN              NaN
# 487              NaN              NaN
# 488              NaN              NaN
# 489              NaN              NaN
# 490              NaN              NaN
# 491              NaN              NaN
#
# [492 rows x 39 columns]

# %%
merged_with_reps = merged_with_reps[[
    'eCLIP_uID','eCLIP_Official_Gene_Symbol','eCLIP_Final_internal_accession',
    'eCLIP_Submission_status','eCLIP_Antibody_Cat_#','eCLIP_Antibody_Lot_#',
    'eCLIP_Cell_Line',
    'RNASEQ_Experiment_ID','RNASEQ_RBP','RNASEQ_Official_RBP','RNASEQ_Cell_line',
    'RNASEQ_Control_Experiment_ID','CONTROL_RBP','CONTROL_Cell_line',
    'RNASEQ_Replicate_rep1','RNASEQ_FASTQ_R1_rep1','RNASEQ_FASTQ_R2_rep1',
    'RNASEQ_BAM_rep1','RNASEQ_TSV_rep1','Rep_rep1',
    'CONTROL_Replicate_rep1','CONTROL_FASTQ_R1_rep1','CONTROL_FASTQ_R2_rep1',
    'CONTROL_BAM_rep1','CONTROL_TSV_rep1',
    'RNASEQ_Replicate_rep2','RNASEQ_FASTQ_R1_rep2','RNASEQ_FASTQ_R2_rep2',
    'RNASEQ_BAM_rep2','RNASEQ_TSV_rep2','Rep_rep2',
    'CONTROL_Replicate_rep2','CONTROL_FASTQ_R1_rep2','CONTROL_FASTQ_R2_rep2',
    'CONTROL_BAM_rep2','CONTROL_TSV_rep2',
    'SE_jxc_file','RNASEQ_DESeq2',
]]
print(len(merged_with_reps.columns))
# Out:
# 38

# %%
merged_with_reps.columns
# Out:
# Index([u'eCLIP_uID', u'eCLIP_Official_Gene_Symbol',
#        u'eCLIP_Final_internal_accession', u'eCLIP_Submission_status',
#        u'eCLIP_Antibody_Cat_#', u'eCLIP_Antibody_Lot_#', u'eCLIP_Cell_Line',
#        u'RNASEQ_Experiment_ID', u'RNASEQ_RBP', u'RNASEQ_Official_RBP',
#        u'RNASEQ_Cell_line', u'RNASEQ_Control_Experiment_ID', u'CONTROL_RBP',
#        u'CONTROL_Cell_line', u'RNASEQ_Replicate_rep1', u'RNASEQ_FASTQ_R1_rep1',
#        u'RNASEQ_FASTQ_R2_rep1', u'RNASEQ_BAM_rep1', u'RNASEQ_TSV_rep1',
#        u'Rep_rep1', u'CONTROL_Replicate_rep1', u'CONTROL_FASTQ_R1_rep1',
#        u'CONTROL_FASTQ_R2_rep1', u'CONTROL_BAM_rep1', u'CONTROL_TSV_rep1',
#        u'RNASEQ_Replicate_rep2', u'RNASEQ_FASTQ_R1_rep2',
#        u'RNASEQ_FASTQ_R2_rep2', u'RNASEQ_BAM_rep2', u'RNASEQ_TSV_rep2',
#        u'Rep_rep2', u'CONTROL_Replicate_rep2', u'CONTROL_FASTQ_R1_rep2',
#        u'CONTROL_FASTQ_R2_rep2', u'CONTROL_BAM_rep2', u'CONTROL_TSV_rep2',
#        u'SE_jxc_file', u'RNASEQ_DESeq2'],
#       dtype='object')

# %%
merged_with_reps.to_csv(
    '/projects/ps-yeolab3/bay001/reference_data/misc_ENCODE/eCLIP_finalstatus_20180406_ENCODE_combined_RNASEQ.tsv',
    sep='\t',
    index=False,
    header=True
)

# %%
merged_with_reps[merged_with_reps['RNASEQ_Official_RBP']=='RACK1']
# Out:
# Empty DataFrame
# Columns: [eCLIP_uID, eCLIP_Official_Gene_Symbol, eCLIP_Final_internal_accession, eCLIP_Submission_status, eCLIP_Antibody_Cat_#, eCLIP_Antibody_Lot_#, eCLIP_Cell_Line, RNASEQ_Experiment_ID, RNASEQ_RBP, RNASEQ_Official_RBP, RNASEQ_Cell_line, RNASEQ_Control_Experiment_ID, CONTROL_RBP, CONTROL_Cell_line, RNASEQ_Replicate_rep1, RNASEQ_FASTQ_R1_rep1, RNASEQ_FASTQ_R2_rep1, RNASEQ_BAM_rep1, RNASEQ_TSV_rep1, Rep_rep1, CONTROL_Replicate_rep1, CONTROL_FASTQ_R1_rep1, CONTROL_FASTQ_R2_rep1, CONTROL_BAM_rep1, CONTROL_TSV_rep1, RNASEQ_Replicate_rep2, RNASEQ_FASTQ_R1_rep2, RNASEQ_FASTQ_R2_rep2, RNASEQ_BAM_rep2, RNASEQ_TSV_rep2, Rep_rep2, CONTROL_Replicate_rep2, CONTROL_FASTQ_R1_rep2, CONTROL_FASTQ_R2_rep2, CONTROL_BAM_rep2, CONTROL_TSV_rep2, SE_jxc_file, RNASEQ_DESeq2]
# Index: []
#
# [0 rows x 38 columns]

# %%
final_hepg2 = merged_with_reps[merged_with_reps[u'eCLIP_Cell_Line']=='HepG2']
final_hepg2.dropna(subset=['RNASEQ_RBP']).shape
# Out:
# (92, 38)

# %%
final_k562 = merged_with_reps[merged_with_reps[u'eCLIP_Cell_Line']=='K562']
final_k562.dropna(subset=['RNASEQ_RBP']).shape
# Out:
# (111, 38)

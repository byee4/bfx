# %%
import pandas
import urllib
import json
import requests
import os
host = 'https://www.encodeproject.org'
experiments = "https://www.encodeproject.org/experiments/"
sample_manifest = '/home/bay001/projects/encode/permanent_data/rna_seq_file_manifest_from_website.txt'
control_manifest = '/home/bay001/projects/encode/permanent_data/rna_seq_control_file_manifest_from_website.txt'
combined_sample_and_control_manifest = '/home/bay001/projects/encode/permanent_data/rna_seq_manifest.txt'
out_dir = '/projects/ps-yeolab3/encode/rnaseq/differential_expression/'
out_dir2 = '/oasis/tscc/scratch/bay001/encode/data/'
to_download = '/home/bay001/projects/encode/permanent_data/to_download.sh'
to_download2 = '/home/bay001/projects/encode/permanent_data/to_download2.sh'

# %% [markdown]
# ### You'll need and manifest file from Eric that has complete imformation on the RBP, Cell Type, CLIP and RNASeq Encode IDs for the experiments. The experiment IDS contain a Accession ID for the whole experiment and then individual ENC IDs for each replicate ( KD and control ). This goes for both CLIP and RNASeq. You'll also need the bam IDs for each replicate

# %%
def star_or_tophat(link):
    if os.path.basename(link).find('star') > -1:
        return 'STAR'
    if os.path.basename(link).find('tophat') > -1:
        return 'TOPHAT'
    return 'ambiguous'

# %%
X = pandas.read_table('/home/gpratt/Dropbox/encode_integration/20160408_ENCODE_MASTER_ID_LIST_AllDatasets.csv',index_col=0)
X.head(2)
# Out:
#    uID RBP_gID CellLine                                          CLIP_rep1  \
# 0  202   PTBP1    HepG2  /projects/ps-yeolab2/encode/analysis/encode_v1...
# 1  203  HNRNPC    HepG2  /projects/ps-yeolab2/encode/analysis/encode_v1...
#
#                                            CLIP_rep2  \
# 0  /projects/ps-yeolab2/encode/analysis/encode_v1...
# 1  /projects/ps-yeolab2/encode/analysis/encode_v1...
#
#                                                INPUT RNASEQ_ControlRep1Bam  \
# 0  /projects/ps-yeolab2/encode/analysis/encode_v1...       ENCFF571ARP.bam
# 1  /projects/ps-yeolab2/encode/analysis/encode_v1...       ENCFF460AAE.bam
#
#   RNASEQ_ControlRep2Bam RNASEQ_ControlENC RNASEQ_KDRep1Bam RNASEQ_KDRep2Bam  \
# 0       ENCFF755GKJ.bam       ENCSR603TCV  ENCFF527FPF.bam  ENCFF155FIK.bam
# 1       ENCFF058QDT.bam       ENCSR305XWT  ENCFF031QZG.bam  ENCFF531AUK.bam
#
#   RNASEQ_ENCODEAccID     selection_method            RBP_ENSG
# 0        ENCSR064DXG  polyadenylated mRNA  ENSG00000011304.12
# 1        ENCSR052IYH  polyadenylated mRNA  ENSG00000092199.13

# %%
testsubset = X[X['CellLine']=='K562']['RNASEQ_ENCODEAccID'].dropna()[:1]
testsubsetcontrol = X[X['CellLine']=='K562']['RNASEQ_ControlENC'].dropna()[:1]
testsubset
# Out:
# 13    ENCSR629EWX
# Name: RNASEQ_ENCODEAccID, dtype: object

# %%
X[X['RNASEQ_ENCODEAccID']=='ENCSR629EWX']
# Out:
#     uID  RBP_gID CellLine                                          CLIP_rep1  \
# 13  220  IGF2BP1     K562  /projects/ps-yeolab2/encode/analysis/encode_v1...
#
#                                             CLIP_rep2  \
# 13  /projects/ps-yeolab2/encode/analysis/encode_v1...
#
#                                                 INPUT RNASEQ_ControlRep1Bam  \
# 13  /projects/ps-yeolab2/encode/analysis/encode_v1...       ENCFF970PYT.bam
#
#    RNASEQ_ControlRep2Bam RNASEQ_ControlENC RNASEQ_KDRep1Bam RNASEQ_KDRep2Bam  \
# 13       ENCFF019XTR.bam       ENCSR129RWD  ENCFF281FUM.bam  ENCFF724ALC.bam
#
#    RNASEQ_ENCODEAccID     selection_method           RBP_ENSG
# 13        ENCSR629EWX  polyadenylated mRNA  ENSG00000159217.5

# %% [markdown]
# ### This block scrolls through the Encode webpage JSON code to extract the correct locations / links to the KD bam files. Links to control bam files are generated further below. For now, names of control bam files are stored in a dictionary, with the accession number as key and the bam file name as value

# %%
samples = list()
links = list()
controls = list()
error = list()
for h in X['RNASEQ_ENCODEAccID'].dropna():
    url = experiments+h+"/?format=json"
    response = urllib.urlopen(url)
    data = json.loads(response.read())
    if 'code' in data.keys():
        next
    else:
        for i in range(0,len(data['files'])):
            # for key, value in data['files'][i].iteritems():
            #     print(key)
            # print(data['files'][i].iteritems())
            # print( data['files'][i]['replicate']['biological_replicate_number'])
            if ((host+data['files'][i]['href']).endswith('bam') & 
            (data['files'][i]['output_type'] == u'alignments') &
            (data['files'][i]['lab'][u'name'] == 'encode-processing-pipeline')):
                if(list(X[X['RNASEQ_ENCODEAccID']==h]['RNASEQ_ControlENC'])[0] != data['possible_controls'][0]['accession']):
                    error.append("WARNING: CTRL VS AFF CHANGED: {}:{}:{}".format(
                        h,
                        list(X[X['RNASEQ_ENCODEAccID']==h]['RNASEQ_ControlENC'])[0],
                        data['possible_controls'][0]['accession']))
                samples.append({'biological_replicate_number':data['files'][i]['replicate']['biological_replicate_number'],
                                'submitted_expt_file_name':data['files'][i]['submitted_file_name'],
                                'expt_file_name':os.path.basename(data['files'][i]['href']),
                                'assembly':data['files'][i]['assembly'],
                                'expt_url':host+data['files'][i]['href'],
                                'RNASEQ_ControlENC':data['possible_controls'][0]['accession'],
                                'RNASEQ_ENCODEAccID':h,
                                'aligner': star_or_tophat(data['files'][i]['submitted_file_name'])
                               })
                links.append(host+data['files'][i]['href'])
        controls.append(data['possible_controls'][0]['accession'])
samples_df = pandas.DataFrame(samples)
samples_df.to_csv(sample_manifest,
                  sep='\t',
                  index=None)
samples_df
# Out:
#      RNASEQ_ControlENC RNASEQ_ENCODEAccID aligner assembly  \
# 0          ENCSR603TCV        ENCSR064DXG  TOPHAT     hg19
# 1          ENCSR603TCV        ENCSR064DXG  TOPHAT     hg19
# 2          ENCSR603TCV        ENCSR064DXG    STAR     hg19
# 3          ENCSR603TCV        ENCSR064DXG    STAR     hg19
# 4          ENCSR603TCV        ENCSR064DXG  TOPHAT   GRCh38
# 5          ENCSR603TCV        ENCSR064DXG  TOPHAT   GRCh38
# 6          ENCSR603TCV        ENCSR064DXG    STAR   GRCh38
# 7          ENCSR603TCV        ENCSR064DXG    STAR   GRCh38
# 8          ENCSR305XWT        ENCSR052IYH    STAR     hg19
# 9          ENCSR305XWT        ENCSR052IYH    STAR     hg19
# 10         ENCSR305XWT        ENCSR052IYH  TOPHAT     hg19
# 11         ENCSR305XWT        ENCSR052IYH  TOPHAT     hg19
# 12         ENCSR305XWT        ENCSR052IYH  TOPHAT   GRCh38
# 13         ENCSR305XWT        ENCSR052IYH  TOPHAT   GRCh38
# 14         ENCSR305XWT        ENCSR052IYH    STAR   GRCh38
# 15         ENCSR305XWT        ENCSR052IYH    STAR   GRCh38
# 16         ENCSR104ABF        ENCSR767LLP  TOPHAT   GRCh38
# 17         ENCSR104ABF        ENCSR767LLP  TOPHAT   GRCh38
# 18         ENCSR104ABF        ENCSR767LLP    STAR   GRCh38
# 19         ENCSR104ABF        ENCSR767LLP    STAR   GRCh38
# 20         ENCSR104ABF        ENCSR767LLP  TOPHAT     hg19
# 21         ENCSR104ABF        ENCSR767LLP  TOPHAT     hg19
# 22         ENCSR104ABF        ENCSR767LLP    STAR     hg19
# 23         ENCSR104ABF        ENCSR767LLP    STAR     hg19
# 24         ENCSR491FOC        ENCSR708GKW  TOPHAT     hg19
# 25         ENCSR491FOC        ENCSR708GKW    STAR     hg19
# 26         ENCSR491FOC        ENCSR708GKW  TOPHAT     hg19
# 27         ENCSR491FOC        ENCSR708GKW    STAR     hg19
# 28         ENCSR491FOC        ENCSR708GKW  TOPHAT   GRCh38
# 29         ENCSR491FOC        ENCSR708GKW  TOPHAT   GRCh38
# ...                ...                ...     ...      ...
# 3250       ENCSR538QOG        ENCSR296ERI    STAR   GRCh38
# 3251       ENCSR538QOG        ENCSR296ERI    STAR   GRCh38
# 3252       ENCSR538QOG        ENCSR296ERI  TOPHAT     hg19
# 3253       ENCSR538QOG        ENCSR296ERI  TOPHAT     hg19
# 3254       ENCSR538QOG        ENCSR296ERI    STAR     hg19
# 3255       ENCSR538QOG        ENCSR296ERI    STAR     hg19
# 3256       ENCSR538QOG        ENCSR511SYK  TOPHAT   GRCh38
# 3257       ENCSR538QOG        ENCSR511SYK  TOPHAT   GRCh38
# 3258       ENCSR538QOG        ENCSR511SYK    STAR   GRCh38
# 3259       ENCSR538QOG        ENCSR511SYK    STAR   GRCh38
# 3260       ENCSR538QOG        ENCSR511SYK  TOPHAT     hg19
# 3261       ENCSR538QOG        ENCSR511SYK  TOPHAT     hg19
# 3262       ENCSR538QOG        ENCSR511SYK    STAR     hg19
# 3263       ENCSR538QOG        ENCSR511SYK    STAR     hg19
# 3264       ENCSR164MUK        ENCSR530BOP  TOPHAT   GRCh38
# 3265       ENCSR164MUK        ENCSR530BOP  TOPHAT   GRCh38
# 3266       ENCSR164MUK        ENCSR530BOP    STAR   GRCh38
# 3267       ENCSR164MUK        ENCSR530BOP    STAR   GRCh38
# 3268       ENCSR164MUK        ENCSR530BOP  TOPHAT     hg19
# 3269       ENCSR164MUK        ENCSR530BOP  TOPHAT     hg19
# 3270       ENCSR164MUK        ENCSR530BOP    STAR     hg19
# 3271       ENCSR164MUK        ENCSR530BOP    STAR     hg19
# 3272       ENCSR067GHD        ENCSR355OQC  TOPHAT   GRCh38
# 3273       ENCSR067GHD        ENCSR355OQC  TOPHAT   GRCh38
# 3274       ENCSR067GHD        ENCSR355OQC    STAR   GRCh38
# 3275       ENCSR067GHD        ENCSR355OQC    STAR   GRCh38
# 3276       ENCSR067GHD        ENCSR355OQC  TOPHAT     hg19
# 3277       ENCSR067GHD        ENCSR355OQC  TOPHAT     hg19
# 3278       ENCSR067GHD        ENCSR355OQC    STAR     hg19
# 3279       ENCSR067GHD        ENCSR355OQC    STAR     hg19
#
#       biological_replicate_number   expt_file_name  \
# 0                               1  ENCFF019ZBE.bam
# 1                               2  ENCFF022QUQ.bam
# 2                               1  ENCFF145TKU.bam
# 3                               2  ENCFF855TDM.bam
# 4                               1  ENCFF246XSM.bam
# 5                               2  ENCFF709DTV.bam
# 6                               1  ENCFF211UDA.bam
# 7                               2  ENCFF854PFR.bam
# 8                               1  ENCFF181LSI.bam
# 9                               2  ENCFF497PPO.bam
# 10                              1  ENCFF123DWI.bam
# 11                              2  ENCFF590KAD.bam
# 12                              1  ENCFF458GOZ.bam
# 13                              2  ENCFF131OWY.bam
# 14                              1  ENCFF436PXG.bam
# 15                              2  ENCFF361LGV.bam
# 16                              2  ENCFF351BNR.bam
# 17                              1  ENCFF942JDC.bam
# 18                              1  ENCFF731IFF.bam
# 19                              2  ENCFF709JYV.bam
# 20                              1  ENCFF542ZHF.bam
# 21                              2  ENCFF155WNI.bam
# 22                              1  ENCFF880HKN.bam
# 23                              2  ENCFF511KFD.bam
# 24                              1  ENCFF209AXX.bam
# 25                              1  ENCFF950AED.bam
# 26                              2  ENCFF315WWX.bam
# 27                              2  ENCFF348FAA.bam
# 28                              1  ENCFF650UWJ.bam
# 29                              2  ENCFF709AOS.bam
# ...                           ...              ...
# 3250                            1  ENCFF996LET.bam
# 3251                            2  ENCFF745XZP.bam
# 3252                            1  ENCFF020ZBS.bam
# 3253                            2  ENCFF965KMK.bam
# 3254                            1  ENCFF727ATR.bam
# 3255                            2  ENCFF317YKN.bam
# 3256                            1  ENCFF817TNN.bam
# 3257                            2  ENCFF311ERL.bam
# 3258                            1  ENCFF511SHN.bam
# 3259                            2  ENCFF495RBD.bam
# 3260                            2  ENCFF639GVB.bam
# 3261                            1  ENCFF519EJD.bam
# 3262                            1  ENCFF493XEK.bam
# 3263                            2  ENCFF974YWT.bam
# 3264                            1  ENCFF934NHF.bam
# 3265                            2  ENCFF957GDU.bam
# 3266                            1  ENCFF211VLH.bam
# 3267                            2  ENCFF810CQZ.bam
# 3268                            1  ENCFF318WCE.bam
# 3269                            2  ENCFF649KZO.bam
# 3270                            1  ENCFF471JFC.bam
# 3271                            2  ENCFF273URB.bam
# 3272                            1  ENCFF928IPZ.bam
# 3273                            2  ENCFF643NQB.bam
# 3274                            1  ENCFF148IZQ.bam
# 3275                            2  ENCFF332APE.bam
# 3276                            1  ENCFF393BWX.bam
# 3277                            2  ENCFF479PPT.bam
# 3278                            1  ENCFF182PZY.bam
# 3279                            2  ENCFF594GKW.bam
#
#                                                expt_url  \
# 0     https://www.encodeproject.org/files/ENCFF019ZB...
# 1     https://www.encodeproject.org/files/ENCFF022QU...
# 2     https://www.encodeproject.org/files/ENCFF145TK...
# 3255  /long-RNA-seq/runs/hg19/ENCSR296ERI/rep2_1/ENC...
# 3256  /long-RNA-seq/runs/GRCh38/ENCSR511SYK/rep1_1/E...
# 3257  /long-RNA-seq/runs/GRCh38/ENCSR511SYK/rep2_1/E...
# 3258  /long-RNA-seq/runs/GRCh38/ENCSR511SYK/rep1_1/E...
# 3259  /long-RNA-seq/runs/GRCh38/ENCSR511SYK/rep2_1/E...
# 3260  /long-RNA-seq/runs/hg19/ENCSR511SYK/rep2_1/ENC...
# 3261  /long-RNA-seq/runs/hg19/ENCSR511SYK/rep1_1/ENC...
# 3262  /long-RNA-seq/runs/hg19/ENCSR511SYK/rep1_1/ENC...
# 3263  /long-RNA-seq/runs/hg19/ENCSR511SYK/rep2_1/ENC...
# 3264  /long-RNA-seq/runs/GRCh38/ENCSR530BOP/rep1_1/E...
# 3265  /long-RNA-seq/runs/GRCh38/ENCSR530BOP/rep2_1/E...
# 3266  /long-RNA-seq/runs/GRCh38/ENCSR530BOP/rep1_1/E...
# 3267  /long-RNA-seq/runs/GRCh38/ENCSR530BOP/rep2_1/E...
# 3268  /long-RNA-seq/runs/hg19/ENCSR530BOP/rep1_1/ENC...
# 3269  /long-RNA-seq/runs/hg19/ENCSR530BOP/rep2_1/ENC...
# 3270  /long-RNA-seq/runs/hg19/ENCSR530BOP/rep1_1/ENC...
# 3271  /long-RNA-seq/runs/hg19/ENCSR530BOP/rep2_1/ENC...
# 3272  /long-RNA-seq/runs/GRCh38/ENCSR355OQC/rep1_1/E...
# 3273  /long-RNA-seq/runs/GRCh38/ENCSR355OQC/rep2_1/E...
# 3274  /long-RNA-seq/runs/GRCh38/ENCSR355OQC/rep1_1/E...
# 3275  /long-RNA-seq/runs/GRCh38/ENCSR355OQC/rep2_1/E...
# 3276  /long-RNA-seq/runs/hg19/ENCSR355OQC/rep1_1/ENC...
# 3277  /long-RNA-seq/runs/hg19/ENCSR355OQC/rep2_1/ENC...
# 3278  /long-RNA-seq/runs/hg19/ENCSR355OQC/rep1_1/ENC...
# 3279  /long-RNA-seq/runs/hg19/ENCSR355OQC/rep2_1/ENC...
#
# [3280 rows x 8 columns]

# %%
samples = list()
error = list()
for h in controls:
    url = experiments+h+"/?format=json"
    response = urllib.urlopen(url)
    data = json.loads(response.read())
    if 'code' in data.keys():
        next
    else:
        for i in range(0,len(data['files'])):
            # for key, value in data['files'][i].iteritems():
            #     print(key)
            # print(data['files'][i].iteritems())
            # print( data['files'][i]['replicate']['biological_replicate_number'])
            if ((host+data['files'][i]['href']).endswith('bam') & 
            (data['files'][i]['output_type'] == u'alignments') &
            (data['files'][i]['lab'][u'name'] == 'encode-processing-pipeline')):
                """if(list(X[X['RNASEQ_ControlENC']==h]['RNASEQ_ENCODEAccID'])[0] != data['possible_controls'][0]['accession']):
                    error.append("WARNING: CTRL VS AFF CHANGED: {}:{}:{}".format(
                        h,
                        list(X[X['RNASEQ_ControlENC']==h]['RNASEQ_ENCODEAccID'])[0],
                        data['possible_controls'][0]['accession']))"""
                samples.append({'biological_replicate_number':data['files'][i]['replicate']['biological_replicate_number'],
                          'submitted_ctrl_file_name':data['files'][i]['submitted_file_name'],
                          'ctrl_file_name':os.path.basename(data['files'][i]['href']),
                          'assembly':data['files'][i]['assembly'],
                          'ctrl_url':host+data['files'][i]['href'],
                          'aligner': star_or_tophat(data['files'][i]['submitted_file_name']),
                          'RNASEQ_ControlENC':h})
                links.append(host+data['files'][i]['href'])
                # controls[data['accession']] = data['possible_controls'][0]['accession']
samples_df = pandas.DataFrame(samples)
samples_df.to_csv(control_manifest,
                  sep='\t',
                  index=None)
samples_df
# Out:
#      RNASEQ_ControlENC aligner assembly  biological_replicate_number  \
# 0          ENCSR603TCV  TOPHAT     hg19                            1
# 1          ENCSR603TCV  TOPHAT     hg19                            2
# 2          ENCSR603TCV    STAR     hg19                            1
# 3          ENCSR603TCV    STAR     hg19                            2
# 4          ENCSR603TCV  TOPHAT   GRCh38                            1
# 5          ENCSR603TCV  TOPHAT   GRCh38                            2
# 6          ENCSR603TCV    STAR   GRCh38                            1
# 7          ENCSR603TCV    STAR   GRCh38                            2
# 8          ENCSR305XWT    STAR     hg19                            1
# 9          ENCSR305XWT    STAR     hg19                            2
# 10         ENCSR305XWT  TOPHAT     hg19                            1
# 11         ENCSR305XWT  TOPHAT     hg19                            2
# 12         ENCSR305XWT  TOPHAT   GRCh38                            1
# 13         ENCSR305XWT  TOPHAT   GRCh38                            2
# 14         ENCSR305XWT    STAR   GRCh38                            1
# 15         ENCSR305XWT    STAR   GRCh38                            2
# 16         ENCSR104ABF  TOPHAT   GRCh38                            1
# 17         ENCSR104ABF  TOPHAT   GRCh38                            2
# 18         ENCSR104ABF    STAR   GRCh38                            1
# 19         ENCSR104ABF    STAR   GRCh38                            2
# 20         ENCSR104ABF  TOPHAT     hg19                            1
# 21         ENCSR104ABF  TOPHAT     hg19                            2
# 22         ENCSR104ABF    STAR     hg19                            1
# 23         ENCSR104ABF    STAR     hg19                            2
# 24         ENCSR491FOC  TOPHAT     hg19                            2
# 25         ENCSR491FOC    STAR     hg19                            1
# 26         ENCSR491FOC  TOPHAT     hg19                            1
# 27         ENCSR491FOC    STAR     hg19                            2
# 28         ENCSR491FOC  TOPHAT   GRCh38                            1
# 29         ENCSR491FOC    STAR   GRCh38                            1
# ...                ...     ...      ...                          ...
# 3250       ENCSR538QOG    STAR   GRCh38                            1
# 3251       ENCSR538QOG    STAR   GRCh38                            2
# 3252       ENCSR538QOG  TOPHAT     hg19                            1
# 3253       ENCSR538QOG  TOPHAT     hg19                            2
# 3254       ENCSR538QOG    STAR     hg19                            1
# 3255       ENCSR538QOG    STAR     hg19                            2
# 3256       ENCSR538QOG  TOPHAT   GRCh38                            1
# 3257       ENCSR538QOG  TOPHAT   GRCh38                            2
# 3258       ENCSR538QOG    STAR   GRCh38                            1
# 3259       ENCSR538QOG    STAR   GRCh38                            2
# 3260       ENCSR538QOG  TOPHAT     hg19                            1
# 3261       ENCSR538QOG  TOPHAT     hg19                            2
# 3262       ENCSR538QOG    STAR     hg19                            1
# 3263       ENCSR538QOG    STAR     hg19                            2
# 3264       ENCSR164MUK  TOPHAT   GRCh38                            2
# 3260  /long-RNA-seq/runs/hg19/ENCSR538QOG/rep1_1/ENC...
# 3261  /long-RNA-seq/runs/hg19/ENCSR538QOG/rep2_1/ENC...
# 3262  /long-RNA-seq/runs/hg19/ENCSR538QOG/rep1_1/ENC...
# 3263  /long-RNA-seq/runs/hg19/ENCSR538QOG/rep2_1/ENC...
# 3264  /long-RNA-seq/runs/GRCh38/ENCSR164MUK/rep2_1/E...
# 3265  /long-RNA-seq/runs/GRCh38/ENCSR164MUK/rep1_1/E...
# 3266  /long-RNA-seq/runs/GRCh38/ENCSR164MUK/rep1_1/E...
# 3267  /long-RNA-seq/runs/GRCh38/ENCSR164MUK/rep2_1/E...
# 3268  /long-RNA-seq/runs/hg19/ENCSR164MUK/rep1_1/ENC...
# 3269  /long-RNA-seq/runs/hg19/ENCSR164MUK/rep2_1/ENC...
# 3270  /long-RNA-seq/runs/hg19/ENCSR164MUK/rep1_1/ENC...
# 3271  /long-RNA-seq/runs/hg19/ENCSR164MUK/rep2_1/ENC...
# 3272  /long-RNA-seq/runs/GRCh38/ENCSR067GHD/rep1_1/E...
# 3273  /long-RNA-seq/runs/GRCh38/ENCSR067GHD/rep2_1/E...
# 3274  /long-RNA-seq/runs/GRCh38/ENCSR067GHD/rep1_1/E...
# 3275  /long-RNA-seq/runs/GRCh38/ENCSR067GHD/rep2_1/E...
# 3276  /long-RNA-seq/runs/hg19/ENCSR067GHD/rep1_1/ENC...
# 3277  /long-RNA-seq/runs/hg19/ENCSR067GHD/rep2_1/ENC...
# 3278  /long-RNA-seq/runs/hg19/ENCSR067GHD/rep1_1/ENC...
# 3279  /long-RNA-seq/runs/hg19/ENCSR067GHD/rep2_1/ENC...
#
# [3280 rows x 7 columns]

# %%
import pandas as pd # because i like using pd
import numpy as np

# %%
samples_df = pd.read_table(sample_manifest)
controls_df = pd.read_table(control_manifest)

# %%
samples_df[(samples_df['RNASEQ_ControlENC']=='ENCSR603TCV') & \
           (samples_df['aligner']=='TOPHAT') & \
           (samples_df['assembly']=='hg19') & \
          (samples_df['biological_replicate_number']==1)]
# Out:
#      RNASEQ_ControlENC RNASEQ_ENCODEAccID aligner assembly  \
# 0          ENCSR603TCV        ENCSR064DXG  TOPHAT     hg19
# 40         ENCSR603TCV        ENCSR017PRS  TOPHAT     hg19
# 72         ENCSR603TCV        ENCSR057GCF  TOPHAT     hg19
# 80         ENCSR603TCV        ENCSR597XHH  TOPHAT     hg19
# 160        ENCSR603TCV        ENCSR148MQK  TOPHAT     hg19
# 488        ENCSR603TCV        ENCSR094KBY  TOPHAT     hg19
# 816        ENCSR603TCV        ENCSR998RZI  TOPHAT     hg19
# 992        ENCSR603TCV        ENCSR330YOU  TOPHAT     hg19
# 1072       ENCSR603TCV        ENCSR939ZRA  TOPHAT     hg19
# 2240       ENCSR603TCV        ENCSR610AEI  TOPHAT     hg19
# 2536       ENCSR603TCV        ENCSR572AMC  TOPHAT     hg19
# 2696       ENCSR603TCV        ENCSR635FRH  TOPHAT     hg19
#
#       biological_replicate_number   expt_file_name  \
# 0                               1  ENCFF019ZBE.bam
# 40                              1  ENCFF926XIX.bam
# 72                              1  ENCFF433FVR.bam
# 80                              1  ENCFF665FGJ.bam
# 160                             1  ENCFF965CYH.bam
# 488                             1  ENCFF448HND.bam
# 816                             1  ENCFF813TQJ.bam
# 992                             1  ENCFF887BZL.bam
# 1072                            1  ENCFF685RQP.bam
# 2240                            1  ENCFF255BZJ.bam
# 2536                            1  ENCFF954YCL.bam
# 2696                            1  ENCFF179WXC.bam
#
#                                                expt_url  \
# 0     https://www.encodeproject.org/files/ENCFF019ZB...
# 40    https://www.encodeproject.org/files/ENCFF926XI...
# 72    https://www.encodeproject.org/files/ENCFF433FV...
# 80    https://www.encodeproject.org/files/ENCFF665FG...
# 160   https://www.encodeproject.org/files/ENCFF965CY...
# 488   https://www.encodeproject.org/files/ENCFF448HN...
# 816   https://www.encodeproject.org/files/ENCFF813TQ...
# 992   https://www.encodeproject.org/files/ENCFF887BZ...
# 1072  https://www.encodeproject.org/files/ENCFF685RQ...
# 2240  https://www.encodeproject.org/files/ENCFF255BZ...
# 2536  https://www.encodeproject.org/files/ENCFF954YC...
# 2696  https://www.encodeproject.org/files/ENCFF179WX...
#
#                                submitted_expt_file_name
# 0     /long-RNA-seq/runs/hg19/ENCSR064DXG/rep1_1/ENC...
# 40    /long-RNA-seq/runs/hg19/ENCSR017PRS/rep1_1/ENC...
# 72    /long-RNA-seq/runs/hg19/ENCSR057GCF/rep1_1/ENC...
# 80    /long-RNA-seq/runs/hg19/ENCSR597XHH/rep1_1/ENC...
# 160   /long-RNA-seq/runs/hg19/ENCSR148MQK/rep1_1/ENC...
# 488   /long-RNA-seq/runs/hg19/ENCSR094KBY/rep1_1/ENC...
# 816   /long-RNA-seq/runs/hg19/ENCSR998RZI/rep1_1/ENC...
# 992   /long-RNA-seq/runs/hg19/ENCSR330YOU/rep1_1/ENC...
# 1072  /long-RNA-seq/runs/hg19/ENCSR939ZRA/rep1_1/ENC...
# 2240  /long-RNA-seq/runs/hg19/ENCSR610AEI/rep1_1/ENC...
# 2536  /long-RNA-seq/runs/hg19/ENCSR572AMC/rep1_1/ENC...
# 2696  /long-RNA-seq/runs/hg19/ENCSR635FRH/rep1_1/ENC...

# %%
controls_df.drop_duplicates(inplace=True)
controls_df[(controls_df['RNASEQ_ControlENC']=='ENCSR603TCV') & \
           (controls_df['aligner']=='TOPHAT') & \
           (controls_df['assembly']=='hg19') & \
          (controls_df['biological_replicate_number']==1)]
# Out:
#   RNASEQ_ControlENC aligner assembly  biological_replicate_number  \
# 0       ENCSR603TCV  TOPHAT     hg19                            1
#
#     ctrl_file_name                                           ctrl_url  \
# 0  ENCFF674CZO.bam  https://www.encodeproject.org/files/ENCFF674CZ...
#
#                             submitted_ctrl_file_name
# 0  /long-RNA-seq/runs/hg19/ENCSR603TCV/rep1_1/ENC...

# %% [markdown]
# ### perform a pandas merge on the ControlENC, aligner, assembly, and biological replicate number

# %%
merged_df = pd.merge(samples_df,controls_df,how='inner',on=['RNASEQ_ControlENC','aligner','assembly','biological_replicate_number'])
merged_df.drop_duplicates(inplace=True)
merged_df
# Out:
#      RNASEQ_ControlENC RNASEQ_ENCODEAccID aligner assembly  \
# 0          ENCSR603TCV        ENCSR064DXG  TOPHAT     hg19
# 1          ENCSR603TCV        ENCSR017PRS  TOPHAT     hg19
# 2          ENCSR603TCV        ENCSR057GCF  TOPHAT     hg19
# 3          ENCSR603TCV        ENCSR597XHH  TOPHAT     hg19
# 4          ENCSR603TCV        ENCSR148MQK  TOPHAT     hg19
# 5          ENCSR603TCV        ENCSR094KBY  TOPHAT     hg19
# 6          ENCSR603TCV        ENCSR998RZI  TOPHAT     hg19
# 7          ENCSR603TCV        ENCSR330YOU  TOPHAT     hg19
# 8          ENCSR603TCV        ENCSR939ZRA  TOPHAT     hg19
# 9          ENCSR603TCV        ENCSR610AEI  TOPHAT     hg19
# 10         ENCSR603TCV        ENCSR572AMC  TOPHAT     hg19
# 11         ENCSR603TCV        ENCSR635FRH  TOPHAT     hg19
# 12         ENCSR603TCV        ENCSR064DXG  TOPHAT     hg19
# 13         ENCSR603TCV        ENCSR017PRS  TOPHAT     hg19
# 14         ENCSR603TCV        ENCSR057GCF  TOPHAT     hg19
# 15         ENCSR603TCV        ENCSR597XHH  TOPHAT     hg19
# 16         ENCSR603TCV        ENCSR148MQK  TOPHAT     hg19
# 17         ENCSR603TCV        ENCSR094KBY  TOPHAT     hg19
# 18         ENCSR603TCV        ENCSR998RZI  TOPHAT     hg19
# 19         ENCSR603TCV        ENCSR330YOU  TOPHAT     hg19
# 20         ENCSR603TCV        ENCSR939ZRA  TOPHAT     hg19
# 21         ENCSR603TCV        ENCSR610AEI  TOPHAT     hg19
# 22         ENCSR603TCV        ENCSR572AMC  TOPHAT     hg19
# 23         ENCSR603TCV        ENCSR635FRH  TOPHAT     hg19
# 24         ENCSR603TCV        ENCSR064DXG    STAR     hg19
# 25         ENCSR603TCV        ENCSR017PRS    STAR     hg19
# 26         ENCSR603TCV        ENCSR057GCF    STAR     hg19
# 27         ENCSR603TCV        ENCSR597XHH    STAR     hg19
# 28         ENCSR603TCV        ENCSR148MQK    STAR     hg19
# 29         ENCSR603TCV        ENCSR094KBY    STAR     hg19
# ...                ...                ...     ...      ...
# 3250       ENCSR771ZZL        ENCSR470PRV  TOPHAT   GRCh38
# 3251       ENCSR771ZZL        ENCSR481YXD  TOPHAT   GRCh38
# 3252       ENCSR771ZZL        ENCSR470PRV    STAR   GRCh38
# 3253       ENCSR771ZZL        ENCSR481YXD    STAR   GRCh38
# 3254       ENCSR771ZZL        ENCSR470PRV    STAR   GRCh38
# 3255       ENCSR771ZZL        ENCSR481YXD    STAR   GRCh38
# 3256       ENCSR376RJN        ENCSR755KOM    STAR     hg19
# 3257       ENCSR376RJN        ENCSR755KOM    STAR     hg19
# 3258       ENCSR376RJN        ENCSR755KOM  TOPHAT     hg19
# 3259       ENCSR376RJN        ENCSR755KOM  TOPHAT     hg19
# 3260       ENCSR376RJN        ENCSR755KOM  TOPHAT   GRCh38
# 3261       ENCSR376RJN        ENCSR755KOM  TOPHAT   GRCh38
# 3262       ENCSR376RJN        ENCSR755KOM    STAR   GRCh38
# 3263       ENCSR376RJN        ENCSR755KOM    STAR   GRCh38
# 3264       ENCSR364GRM        ENCSR040WAK  TOPHAT   GRCh38
# 3265       ENCSR364GRM        ENCSR040WAK  TOPHAT   GRCh38
# 3266       ENCSR364GRM        ENCSR040WAK    STAR   GRCh38
# 3267       ENCSR364GRM        ENCSR040WAK    STAR   GRCh38
# 3268       ENCSR364GRM        ENCSR040WAK  TOPHAT     hg19
# 3269       ENCSR364GRM        ENCSR040WAK  TOPHAT     hg19
# 3270       ENCSR364GRM        ENCSR040WAK    STAR     hg19
# 3271       ENCSR364GRM        ENCSR040WAK    STAR     hg19
# 3272       ENCSR936VPP        ENCSR675KPR  TOPHAT     hg19
# 3273       ENCSR936VPP        ENCSR675KPR  TOPHAT     hg19
# 3274       ENCSR936VPP        ENCSR675KPR    STAR     hg19
# 3275       ENCSR936VPP        ENCSR675KPR    STAR     hg19
# 3276       ENCSR936VPP        ENCSR675KPR  TOPHAT   GRCh38
# 3277       ENCSR936VPP        ENCSR675KPR  TOPHAT   GRCh38
# 3278       ENCSR936VPP        ENCSR675KPR    STAR   GRCh38
# 3279       ENCSR936VPP        ENCSR675KPR    STAR   GRCh38
#
#       biological_replicate_number   expt_file_name  \
# 0                               1  ENCFF019ZBE.bam
# 1                               1  ENCFF926XIX.bam
# 2                               1  ENCFF433FVR.bam
# 3                               1  ENCFF665FGJ.bam
# 4                               1  ENCFF965CYH.bam
# 5                               1  ENCFF448HND.bam
# 6                               1  ENCFF813TQJ.bam
# 7                               1  ENCFF887BZL.bam
# 8                               1  ENCFF685RQP.bam
# 9                               1  ENCFF255BZJ.bam
# 10                              1  ENCFF954YCL.bam
# 11                              1  ENCFF179WXC.bam
# 12                              2  ENCFF022QUQ.bam
# 13                              2  ENCFF030NQW.bam
# 14                              2  ENCFF252IHW.bam
# 15                              2  ENCFF921WIW.bam
# 16                              2  ENCFF718IHB.bam
# 17                              2  ENCFF535TDK.bam
# 18                              2  ENCFF161FLY.bam
# 19                              2  ENCFF297VZZ.bam
# 20                              2  ENCFF926KAY.bam
# 21                              2  ENCFF826ZVP.bam
# 22                              2  ENCFF472IOG.bam
# 23                              2  ENCFF321YGV.bam
# 24                              1  ENCFF145TKU.bam
# 25                              1  ENCFF642TXU.bam
# 26                              1  ENCFF298LYN.bam
# 27                              1  ENCFF754SUW.bam
# 28                              1  ENCFF301YOD.bam
# 29                              1  ENCFF856VSZ.bam
# ...                           ...              ...
# 3250                            2  ENCFF474VND.bam
# 3251                            2  ENCFF736RML.bam
# 3252                            1  ENCFF885OGZ.bam
# 3253                            1  ENCFF960BRU.bam
# 3254                            2  ENCFF859QBQ.bam
# 3255                            2  ENCFF749IYE.bam
# 3256                            1  ENCFF513ADH.bam
# 3257                            2  ENCFF880UOR.bam
# 3258                            1  ENCFF170HJE.bam
# 3259                            2  ENCFF162PSX.bam
# 3260                            1  ENCFF779RHX.bam
# 3261                            2  ENCFF106HNU.bam
# 3262                            1  ENCFF410LSF.bam
# 3263                            2  ENCFF722ZRT.bam
# 3264                            1  ENCFF967YIH.bam
# 15    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep2_1/ENC...
# 16    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep2_1/ENC...
# 17    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep2_1/ENC...
# 18    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep2_1/ENC...
# 19    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep2_1/ENC...
# 20    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep2_1/ENC...
# 21    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep2_1/ENC...
# 22    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep2_1/ENC...
# 23    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep2_1/ENC...
# 24    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep1_1/ENC...
# 25    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep1_1/ENC...
# 26    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep1_1/ENC...
# 27    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep1_1/ENC...
# 28    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep1_1/ENC...
# 29    /long-RNA-seq/runs/hg19/ENCSR603TCV/rep1_1/ENC...
# ...                                                 ...
# 3250  /long-RNA-seq/runs/GRCh38/ENCSR771ZZL/rep2_1/E...
# 3251  /long-RNA-seq/runs/GRCh38/ENCSR771ZZL/rep2_1/E...
# 3252  /long-RNA-seq/runs/GRCh38/ENCSR771ZZL/rep1_1/E...
# 3253  /long-RNA-seq/runs/GRCh38/ENCSR771ZZL/rep1_1/E...
# 3254  /long-RNA-seq/runs/GRCh38/ENCSR771ZZL/rep2_1/E...
# 3255  /long-RNA-seq/runs/GRCh38/ENCSR771ZZL/rep2_1/E...
# 3256  /long-RNA-seq/runs/hg19/ENCSR376RJN/rep1_1/ENC...
# 3257  /long-RNA-seq/runs/hg19/ENCSR376RJN/rep2_1/ENC...
# 3258  /long-RNA-seq/posted/hg19/2015-08-26/ENCSR376R...
# 3259  /long-RNA-seq/posted/hg19/2015-08-26/ENCSR376R...
# 3260  /long-RNA-seq/runs/GRCh38/ENCSR376RJN/rep1_1/E...
# 3261  /long-RNA-seq/runs/GRCh38/ENCSR376RJN/rep2_1/E...
# 3262  /long-RNA-seq/runs/GRCh38/ENCSR376RJN/rep1_1/E...
# 3263  /long-RNA-seq/runs/GRCh38/ENCSR376RJN/rep2_1/E...
# 3264  /long-RNA-seq/runs/GRCh38/ENCSR364GRM/rep1_1/E...
# 3265  /long-RNA-seq/runs/GRCh38/ENCSR364GRM/rep2_1/E...
# 3266  /long-RNA-seq/runs/GRCh38/ENCSR364GRM/rep1_1/E...
# 3267  /long-RNA-seq/runs/GRCh38/ENCSR364GRM/rep2_1/E...
# 3268  /long-RNA-seq/runs/hg19/ENCSR364GRM/rep1_1/ENC...
# 3269  /long-RNA-seq/runs/hg19/ENCSR364GRM/rep2_1/ENC...
# 3270  /long-RNA-seq/runs/hg19/ENCSR364GRM/rep1_1/ENC...
# 3271  /long-RNA-seq/runs/hg19/ENCSR364GRM/rep2_1/ENC...
# 3272  /long-RNA-seq/runs/hg19/ENCSR936VPP/rep1_1/ENC...
# 3273  /long-RNA-seq/runs/hg19/ENCSR936VPP/rep2_1/ENC...
# 3274  /long-RNA-seq/runs/hg19/ENCSR936VPP/rep1_1/ENC...
# 3275  /long-RNA-seq/runs/hg19/ENCSR936VPP/rep2_1/ENC...
# 3276  /long-RNA-seq/runs/GRCh38/ENCSR936VPP/rep1_1/E...
# 3277  /long-RNA-seq/runs/GRCh38/ENCSR936VPP/rep2_1/E...
# 3278  /long-RNA-seq/runs/GRCh38/ENCSR936VPP/rep1_1/E...
# 3279  /long-RNA-seq/runs/GRCh38/ENCSR936VPP/rep2_1/E...
#
# [3240 rows x 11 columns]

# %%
merged_df.to_csv(combined_sample_and_control_manifest,index=None,sep="\t")

# %%
to_download_file = open(to_download,'w')
to_download_file2 = open(to_download2,'w')
for link in list(set(links)):
    to_download_file.write("wget -O {}{} {};\n".format(out_dir, os.path.basename(link), link))
    to_download_file2.write("wget -O {}{} {};\n".format(out_dir2, os.path.basename(link), link))
to_download_file.close()
to_download_file2.close()

# %%
len(list(set(links)))
# Out:
# 3544

# %%
# ! sh /home/bay001/projects/encode/permanent_data/to_download.sh

# %%
len(links)
# Out:
# 6560

# %%
! tail /home/bay001/projects/encode/permanent_data/to_download.sh
# Out:
# wget -O /projects/ps-yeolab3/encode/rnaseq/differential_expression/ENCFF596UTY.bam https://www.encodeproject.org/files/ENCFF596UTY/@@download/ENCFF596UTY.bam;
# wget -O /projects/ps-yeolab3/encode/rnaseq/differential_expression/ENCFF178VLQ.bam https://www.encodeproject.org/files/ENCFF178VLQ/@@download/ENCFF178VLQ.bam;
# wget -O /projects/ps-yeolab3/encode/rnaseq/differential_expression/ENCFF912DCG.bam https://www.encodeproject.org/files/ENCFF912DCG/@@download/ENCFF912DCG.bam;
# wget -O /projects/ps-yeolab3/encode/rnaseq/differential_expression/ENCFF201XMY.bam https://www.encodeproject.org/files/ENCFF201XMY/@@download/ENCFF201XMY.bam;
# wget -O /projects/ps-yeolab3/encode/rnaseq/differential_expression/ENCFF744IPR.bam https://www.encodeproject.org/files/ENCFF744IPR/@@download/ENCFF744IPR.bam;
# wget -O /projects/ps-yeolab3/encode/rnaseq/differential_expression/ENCFF655HSR.bam https://www.encodeproject.org/files/ENCFF655HSR/@@download/ENCFF655HSR.bam;
# wget -O /projects/ps-yeolab3/encode/rnaseq/differential_expression/ENCFF349HFT.bam https://www.encodeproject.org/files/ENCFF349HFT/@@download/ENCFF349HFT.bam;
# wget -O /projects/ps-yeolab3/encode/rnaseq/differential_expression/ENCFF187ZFL.bam https://www.encodeproject.org/files/ENCFF187ZFL/@@download/ENCFF187ZFL.bam;
# wget -O /projects/ps-yeolab3/encode/rnaseq/differential_expression/ENCFF171VAE.bam https://www.encodeproject.org/files/ENCFF171VAE/@@download/ENCFF171VAE.bam;
# wget -O /projects/ps-yeolab3/encode/rnaseq/differential_expression/ENCFF067YHP.bam https://www.encodeproject.org/files/ENCFF067YHP/@@download/ENCFF067YHP.bam;

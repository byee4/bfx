# %%
import os
import glob

# %%
from_xintao = '/projects/ps-yeolab3/encode/rnaseq/differential_expression/HepG2_file_list.20170509.txt'
output_dir = '/projects/ps-yeolab3/encode/rnaseq/differential_expression/output_sig/'

# %%
with open(from_xintao, 'r') as f:
    for line in f:
        line = line.rstrip()
        target_name = os.path.join(output_dir, os.path.basename(line))
        if os.path.exists(target_name):
            print("{} exists".format(target_name))
        else:
            ! wget $line -O $target_name
# Out:
# /projects/ps-yeolab3/encode/rnaseq/differential_expression/output_sig/AARS_BGHLV17_DESeq_output_sig.txt exists
# /projects/ps-yeolab3/encode/rnaseq/differential_expression/output_sig/AATF_BGHLV14_DESeq_output_sig.txt exists
# /projects/ps-yeolab3/encode/rnaseq/differential_expression/output_sig/ABCF1_BGHLV30_DESeq_output_sig.txt exists
# /projects/ps-yeolab3/encode/rnaseq/differential_expression/output_sig/ACO1_BGHLV31_DESeq_output_sig.txt exists
# /projects/ps-yeolab3/encode/rnaseq/differential_expression/output_sig/ADAR_BGHLV20_DESeq_output_sig.txt exists
# /projects/ps-yeolab3/encode/rnaseq/differential_expression/output_sig/AKAP1_BGHLV12_DESeq_output_sig.txt exists
# /projects/ps-yeolab3/encode/rnaseq/differential_expression/output_sig/AKAP8_BGHLV27_DESeq_output_sig.txt exists
# /projects/ps-yeolab3/encode/rnaseq/differential_expression/output_sig/AKAP8L_BGHLV31_DESeq_output_sig.txt exists
# ...

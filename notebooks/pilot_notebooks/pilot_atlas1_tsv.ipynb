# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
csv = '/projects/ps-yeolab3/bootcamps/cmm262_2018/single_cell/raw_data/batch1_counts.csv'
df = pd.read_table(csv, sep=',', index_col=0)
df.head()
# Out:
#          B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal  B1_AAACCGTGCCAAGT_Tuft  \
# Mrpl15                                              2                       1
# Lypla1                                              2                       0
# Gm37988                                             0                       0
# Tcea1                                               0                       0
# Atp6v1h                                             0                       0
#
#          B1_AAACGCACAGCCTA_Goblet  B1_AAACGCACCAGATC_Endocrine  \
# Mrpl15                          2                            2
# Lypla1                          0                            1
# Gm37988                         0                            0
# Tcea1                           0                            0
# Atp6v1h                         0                            0
#
#          B1_AAACGCACCGCCTT_Stem  B1_AAACGCACCGTAGT_Stem  \
# Mrpl15                        0                       4
# ...

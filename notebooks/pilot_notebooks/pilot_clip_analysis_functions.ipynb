# %%
# %matplotlib inline
import pandas as pd
import parsers as p
import plotting_methods as pm

# %%
fn = '/projects/ps-yeolab3/bay001/tbos/input_norm/input_norm_latest/WTV5_02_01.basedon_WTV5_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated'

# %%
p.filter_input_norm_as_df(fn, 3, 3, ).to_csv('test.bed', sep='\t', header=False, index=False)

# %%
wd = '/projects/ps-yeolab3/bay001/tbos/input_norm/input_norm_latest/'
p.get_cumulative_sum_counts(wd, 3, 3)
# Out:
#                   A11_01_01.basedon_A11_01_01.peaks.l2inputnormnew.bed.compressed.bed.annotated  \
# 3utr                                                       0.389793
# 5utr                                                       0.428156
# 5utr_and_3utr                                              0.428327
# CDS                                                        0.917452
# intergenic                                                 0.917623
# intron                                                     0.969515
# noncoding_exon                                             0.987155
# noncoding_intron                                           1.000000
#
#                   A11_02_01.basedon_A11_02_01.peaks.l2inputnormnew.bed.compressed.bed.annotated  \
# 3utr                                                       0.377309
# 5utr                                                       0.451206
# 5utr_and_3utr                                              0.451206
# ...

# %%
pm.plot_region_distribution(wd, 'plot.png', 3, 3)
# Out:
# /home/bay001/anaconda2/envs/brian/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

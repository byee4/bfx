# %% [markdown]
# # Piloting out a script that takes:
# - YAML/JSON experiment metadata (captured from form)
# - idx file metadata (user upload)
# - images (user upload)
# - plate map (user upload)
#
# and creates an easy-to-read excel sheet for users to check (similar to GEO)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import glob
import os
import json
import xlsxwriter
import re
import javabridge
import bioformats
import xmljson
from xmljson import badgerfish as bf
from xml.etree.ElementTree import fromstring
from xml.etree import ElementTree as ETree
from json import dumps
# from lxml import etree

javabridge.start_vm(class_path=bioformats.JARS)

# %%
input_dir = '/projects/ps-yeolab4/NCRCRG/example_files/'
output_dir = '/projects/ps-yeolab4/NCRCRG/example_files/'

# %% [markdown]
# # Get Experiment-level metadata from the YAML/JSON form

# %%
expt_metadata_json = os.path.join(input_dir, 'imaging_metadata_v10.json')

# %%
def read_expt_metadata(fn):
    with open(fn) as f:
        f.readline()  # skips the /usr/bin/env line
        try:
            data = json.load(f)
            return data
        except Exception as e:
            print(e)
            return None
        
def generate_plate_map():
    pass

# %%
expt_dict = read_expt_metadata(expt_metadata_json)
print(expt_dict.keys())
# Out:
# [u'wells_per_plate', u'investigator', u'number_of_plates', u'image_capture_date', u'Channel_Type', u'microscope', u'experiment_type', u'contact_email', u'magnification_power', u'samples', u'treatment_protocol_description', u'imaging_and_segmentation_software', u'pi_name', u'experiment_nickname', u'organism', u'cell_growth_protocol', u'experiment_summary']

# %%
# let's parse the the top level metadata fields out first, leave samples for another day.
top_level_metadata_fields = [
    u'Channel_Type', 
    u'contact_email', 
    u'cell_growth_protocol',
    u'investigator',
    u'number_of_plates',
    u'image_capture_date',
    u'microscope',
    u'experiment_type',
    u'magnification_power',
    u'treatment_protocol_description',
    u'imaging_and_segmentation_software',
    u'pi_name',
    u'experiment_nickname',
    u'organism',
    u'cell_growth_protocol',
    u'experiment_summary',
]

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame(expt_dict).T
# Grab the toplevel metadata
top_level_metadata = df.loc[top_level_metadata_fields,]
sample_level_metadata = df.loc[u'samples']
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(
    os.path.join(output_dir, 'imaging_metadata_v10.xlsx'), 
    engine='xlsxwriter'
)
# Convert the dataframe to an XlsxWriter Excel object.
top_level_metadata.to_excel(writer, sheet_name='Sheet1')
# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# # Get Plate-level metadata from idx and platemap file

# %%
def read_platemap_from_excel(fn, sheet='Sheet1'):
    excel = pd.ExcelFile(fn, index_col=0)
    # Read in the sheet specified by param
    try:
        df = excel.parse(sheet)
    except Exception as e:
        print("{}. Parsing first sheet in file.".format(e))
        df = excel.parse(excel.sheet_names[0])
    
    # select only the "Plate Layout" columns, leaving everything else as comment.
    df = df[df['Plate Layout'] == 'Plate Layout']
    # use the plate row names as index, dropping the 'Plate Layout' column 
    df.set_index('Unnamed: 1', inplace=True)
    df.drop('Plate Layout', axis=1, inplace=True)
    return df

plate_map = read_platemap_from_excel(
    os.path.join(input_dir, 'from_anthony_vu', '181221_H9_G3BP1gfp_SGopt_TEMPLATED.xlsx')
)
plate_map
# Out:
#              1                 2                 3                 4  \
# Unnamed: 1
# A          NaN               NaN               NaN   min stressed: 0
# B          NaN  negative control  negative control  negative control
# C          NaN    stressed cells    stressed cells    stressed cells
# D          NaN    stressed cells    stressed cells    stressed cells
# E          NaN    stressed cells    stressed cells    stressed cells
# F          NaN    stressed cells    stressed cells    stressed cells
# G          NaN  negative control  negative control  negative control
# H          NaN    stressed cells    stressed cells    stressed cells
# I          NaN    stressed cells    stressed cells    stressed cells
# J          NaN    stressed cells    stressed cells    stressed cells
# K          NaN                 0                 0                 0
# L          NaN         no stress         no stress         no stress
# M          NaN               NaN               NaN               NaN
# N          NaN               NaN               NaN               NaN
# O          NaN               NaN               NaN               NaN
# P          NaN               NaN               NaN               NaN
#
#                                                   5  \
# Unnamed: 1
# A                                  min stressed: 15
# B                                  negative control
# C                                    stressed cells
# D                                    stressed cells
# E                                    stressed cells
# F                                    stressed cells
# G                                  negative control
# H                                    stressed cells
# I                                    stressed cells
# J                                    stressed cells
# K                                                 0
# L           1hr stress, followed by X hrs recovery:
# M                                               NaN
# N                                               NaN
# O                                               NaN
# P                                               NaN
#
#                                                   6  \
# Unnamed: 1
# A                                  min stressed: 15
# B                                  negative control
# C                                    stressed cells
# D                                    stressed cells
# E                                    stressed cells
# F                                    stressed cells
# G                                  negative control
# H                                    stressed cells
# I                                    stressed cells
# J                                    stressed cells
# K                                                 0
# L           1hr stress, followed by X hrs recovery:
# M                                               NaN
# N                                               NaN
# O                                               NaN
# P                                               NaN
#
#                                                   7  \
# Unnamed: 1
# A                                  min stressed: 15
# B                                  negative control
# C                                    stressed cells
# D                                    stressed cells
# E                                    stressed cells
# F                                    stressed cells
# G                                  negative control
# H                                    stressed cells
# I                                    stressed cells
# J                                    stressed cells
# K                                                 0
# L           1hr stress, followed by X hrs recovery:
# M                                               NaN
# N                                               NaN
# O                                               NaN
# P                                               NaN
#
#                                                   8  \
# Unnamed: 1
# A                                  min stressed: 30
# B                                  negative control
# C                                    stressed cells
# D                                    stressed cells
# E                                    stressed cells
# F                                    stressed cells
# G                                  negative control
# H                                    stressed cells
# I                                    stressed cells
# J                                    stressed cells
# K                                                 1
# L           1hr stress, followed by X hrs recovery:
# M                                               NaN
# N                                               NaN
# O                                               NaN
# P                                               NaN
#
#                                                   9  \
# Unnamed: 1
# A                                  min stressed: 30
# B                                  negative control
# C                                    stressed cells
# D                                    stressed cells
# E                                    stressed cells
# F                                    stressed cells
# G                                  negative control
# H                                    stressed cells
# I                                    stressed cells
# J                                    stressed cells
# K                                                 1
# L           1hr stress, followed by X hrs recovery:
# M                                               NaN
# N                                               NaN
# O                                               NaN
# P                                               NaN
#
#                                                  10           ...             \
# Unnamed: 1                                                    ...
# A                                  min stressed: 30           ...
# B                                  negative control           ...
# C                                    stressed cells           ...
# D                                    stressed cells           ...
# E                                    stressed cells           ...
# F                                    stressed cells           ...
# G                                  negative control           ...
# H                                    stressed cells           ...
# I                                    stressed cells           ...
# J                                    stressed cells           ...
# K                                                 1           ...
# L           1hr stress, followed by X hrs recovery:           ...
# M                                               NaN           ...
# N                                               NaN           ...
# O                                               NaN           ...
# P                                               NaN           ...
#
#                                                  17  \
# Unnamed: 1
# A                                  min stressed: 75
# B                                  negative control
# C                                    stressed cells
# D                                    stressed cells
# E                                    stressed cells
# F                                    stressed cells
# G                                  negative control
# H                                    stressed cells
# I                                    stressed cells
# J                                    stressed cells
# K                                                 4
# L           1hr stress, followed by X hrs recovery:
# M                                               NaN
# N                                               NaN
# O                                               NaN
# P                                               NaN
#
#                                                  18  \
# Unnamed: 1
# A                                  min stressed: 75
# B                                  negative control
# C                                    stressed cells
# D                                    stressed cells
# E                                    stressed cells
# F                                    stressed cells
# G                                  negative control
# H                                    stressed cells
# I                                    stressed cells
# J                                    stressed cells
# K                                                 4
# L           1hr stress, followed by X hrs recovery:
# M                                               NaN
# N                                               NaN
# O                                               NaN
# P                                               NaN
#
#                                                  19  \
# Unnamed: 1
# A                                  min stressed: 75
# B                                  negative control
# C                                    stressed cells
# D                                    stressed cells
# E                                    stressed cells
# F                                    stressed cells
# G                                  negative control
# H                                    stressed cells
# I                                    stressed cells
# J                                    stressed cells
# K                                                 4
# L           1hr stress, followed by X hrs recovery:
# M                                               NaN
# N                                               NaN
# O                                               NaN
# P                                               NaN
#
#                                                  20  \
# Unnamed: 1
# A                                  min stressed: 90
# B                                  negative control
# C                                    stressed cells
# D                                    stressed cells
# E                                    stressed cells
# F                                    stressed cells
# G                                  negative control
# H                                    stressed cells
# I                                    stressed cells
# J                                    stressed cells
# K                                                 5
# L           1hr stress, followed by X hrs recovery:
# M                                               NaN
# N                                               NaN
# O                                               NaN
# P                                               NaN
#
#                                                  21  \
# Unnamed: 1
# A                                  min stressed: 90
# B                                  negative control
# C                                    stressed cells
# D                                    stressed cells
# E                                    stressed cells
# F                                    stressed cells
# G                                  negative control
# H                                    stressed cells
# I                                    stressed cells
# J                                    stressed cells
# K                                                 5
# L           1hr stress, followed by X hrs recovery:
# M                                               NaN
# N                                               NaN
# O                                               NaN
# P                                               NaN
#
#                                                  22           23           24  \
# Unnamed: 1
# A                                  min stressed: 90  NaAsO2 (uM)  NaAsO2 (uM)
# B                                  negative control            0          NaN
# C                                    stressed cells          100          NaN
# D                                    stressed cells          250          NaN
# E                                    stressed cells          500          NaN
# F                                    stressed cells          750          NaN
# G                                  negative control            0          NaN
# H                                    stressed cells          100          NaN
# I                                    stressed cells          250          NaN
# J                                    stressed cells          500          NaN
# K                                                 5          NaN          NaN
# L           1hr stress, followed by X hrs recovery:          NaN          NaN
# M                                               NaN          NaN          NaN
# N                                               NaN          NaN          NaN
# O                                               NaN          NaN          NaN
# P                                               NaN          NaN          NaN
#
#            Unnamed: 26              Unnamed: 27
# Unnamed: 1
# A                  NaN                      NaN
# B                  NaN                      NaN
# C                  NaN                      NaN
# D                  NaN                      NaN
# E                  NaN  (orange) stressed cells
# F                  NaN   (red) negative control
# G                  NaN                      NaN
# H                  NaN                      NaN
# I                  NaN                      NaN
# J                  NaN                      NaN
# K                  NaN                      NaN
# L                  NaN                      NaN
# M                  NaN                      NaN
# N                  NaN                      NaN
# O                  NaN                      NaN
# P                  NaN                      NaN
#
# [16 rows x 26 columns]

# %%
def read_idx_csv(fn, software="Columbus"):
    """
    Reads in an idx file (for now just Columbus-formatted IDX files).
    Returns a pandas.DataFrame
    """
    if software == "Columbus":
        df = pd.read_table(fn, sep=',')
        df.columns = [c.lstrip(' ') for c in df.columns]
        df = df.apply(lambda x: x.str.lstrip(' ') if x.dtype == "object" else x)
        return df # .to_json()
    else:
        print("Unsupported software!")
        return None

fn = os.path.join(input_dir, 'from_anthony_vu', 'ImageIndex.ColumbusIDX.csv')
idx = read_idx_csv(fn)
idx.head()
# Out:
#    AbsoluteTime@s  Channel ChannelName  Column  Field  ImageResolutionX@um  \
# 0      1516331533        0        DAPI       2      1                 0.65
# 1      1516331541        0        DAPI       2      2                 0.65
# 2      1516331536        0        DAPI       2      3                 0.65
# 3      1516331539        0        DAPI       2      4                 0.65
# 4      1516331533        1         GFP       2      1                 0.65
#
#    ImageResolutionY@um           MeasurementDate  Plane             PlateName  \
# 0                 0.65  2018-01-19T03:12:13.000Z      0  AnthinyVu_plate1_20x
# 1                 0.65  2018-01-19T03:12:13.000Z      0  AnthinyVu_plate1_20x
# 2                 0.65  2018-01-19T03:12:13.000Z      0  AnthinyVu_plate1_20x
# 3                 0.65  2018-01-19T03:12:13.000Z      0  AnthinyVu_plate1_20x
# 4                 0.65  2018-01-19T03:12:13.000Z      0  AnthinyVu_plate1_20x
#
#    PositionX@um  PositionY@um  PositionZ@um  Row  TimeOffset@s  Timepoint  \
# 0        1404.0         832.0           0.0    2             0          0
# 1        2106.0         832.0           0.0    2             0          0
# 2        1404.0        1664.0           0.0    2             0          0
# 3        2106.0        1664.0           0.0    2             0          0
# 4        1404.0         832.0           0.0    2             0          0
#
#   WellName                                     sourcefilename
# 0       B2  DAPI__B_002_r_0001_c_0002_t_00000000_z_0000-00...
# 1       B2  DAPI__B_002_r_0001_c_0003_t_00000000_z_0000-00...
# 2       B2  DAPI__B_002_r_0002_c_0002_t_00000000_z_0000-00...
# 3       B2  DAPI__B_002_r_0002_c_0003_t_00000000_z_0000-00...
# 4       B2  GFP__B_002_r_0001_c_0002_t_00000000_z_0000-000...

# %%
def get_sample_id_from_plate_map(plate_map, row, col):
    return plate_map.loc[row, col]

def get_filled_well_positions_from_idx(idx, software="Columbus"):
    """ 
    Assuming we have an index file whose rows correspond to well images, return the positions 
    describing wells filled
    """
    if software == "Columbus":
        all_image_positions = list(set(idx['WellName']))
    else:
        all_image_positions = []
    return all_image_positions

def get_list_of_associated_files(idx, row, col, software="Columbus"):
    """ Given a row and a column and a template, return the list of files belonging to that template. """
    if software == "Columbus":
        return idx[idx['WellName'] == '{}{}'.format(row, col)]['sourcefilename'].values
    else:
        print("Unsupported software! Assumes no leading whitespace in well positions")
    
def get_template(well_format='standard96well'):
    """ Returns an empty well template. Supports only 96well for now, but will do for later """
    if well_format == 'standard96well':
        rows = [chr(l) for l in range(65, 65+8)]  # 'A' char is ascii 65
        cols = [c for c in range(1, 13)]
        return pd.DataFrame(index=rows, columns=cols)
    if well_format == 'standard384well':
        rows = [chr(l) for l in range(65, 65+16)]  # 'A' char is ascii 65
        cols = [c for c in range(1, 25)]
        return pd.DataFrame(index=rows, columns=cols)
    else:
        print("Unsupported well range!")
        return None
    
def split_letter_number(position):
    """
    Splits a position (ie. A3) into letter and number (ie. 'A', 3).
    Letters must come before numbers
    
    param position: string
    returns: letter, number
    """
    letter, number = re.findall('\d+|\D+', position)
    return letter, int(number)

def return_platemap_based_on_idx(idx, well_format='standard384well', software="Columbus"):
    """
    Returns a dataframe containing 
    df: pandas.DataFrame
        DataFrame of an index file
        @see: read_idx_csv()
    """
    filled_letters = []
    filled_numbers = []
    filled = []
    
    template = get_template(well_format=well_format)
    
    all_image_positions = get_filled_well_positions_from_idx(idx=idx, software=software)
        
    for position in all_image_positions:
        letter, number = split_letter_number(position)
        template.loc[letter, number] = 'x'
    return template

def label_from_plate_map(row, plate_map, software):
    """ 
    Given an IDX row containing a 'WellName' (maybe Columbus only?), 
    parse into row and column identifiers and 
    return the label on the plate_map.
    """
    if software == "Columbus":
        letter, number = split_letter_number(row['WellName'])
        return get_sample_id_from_plate_map(plate_map=plate_map, row=letter, col=number)
    else:
        return None
    
def label_idx_with_plate_map_identifiers(plate_map, idx, well_format='standard384well', software="Columbus"):
    """
    Uses the plate map identifiers in each well to label the index IDX file.
    """
    idx['label'] = idx.apply(label_from_plate_map, args=[plate_map, software], axis=1)
    return idx

# %%
label_idx_with_plate_map_identifiers(
    plate_map=plate_map, 
    idx=idx, 
    well_format='standard384well', 
    software="Columbus"
)
# Out:
#       AbsoluteTime@s  Channel ChannelName  Column  Field  ImageResolutionX@um  \
# 0         1516331533        0        DAPI       2      1                 0.65
# 1         1516331541        0        DAPI       2      2                 0.65
# 2         1516331536        0        DAPI       2      3                 0.65
# 3         1516331539        0        DAPI       2      4                 0.65
# 4         1516331533        1         GFP       2      1                 0.65
# 5         1516331541        1         GFP       2      2                 0.65
# 6         1516331536        1         GFP       2      3                 0.65
# 7         1516331538        1         GFP       2      4                 0.65
# 8         1516331544        0        DAPI       3      1                 0.65
# 9         1516331552        0        DAPI       3      2                 0.65
# 10        1516331547        0        DAPI       3      3                 0.65
# 11        1516331549        0        DAPI       3      4                 0.65
# 12        1516331543        1         GFP       3      1                 0.65
# 13        1516331551        1         GFP       3      2                 0.65
# 14        1516331546        1         GFP       3      3                 0.65
# 15        1516331549        1         GFP       3      4                 0.65
# 16        1516331554        0        DAPI       4      1                 0.65
# 17        1516331562        0        DAPI       4      2                 0.65
# 18        1516331557        0        DAPI       4      3                 0.65
# 19        1516331560        0        DAPI       4      4                 0.65
# 20        1516331554        1         GFP       4      1                 0.65
# 21        1516331562        1         GFP       4      2                 0.65
# 22        1516331557        1         GFP       4      3                 0.65
# 23        1516331559        1         GFP       4      4                 0.65
# 24        1516331565        0        DAPI       5      1                 0.65
# 1578  AnthinyVu_plate1_20x        1404.0        1664.0           0.0   10
# 1579  AnthinyVu_plate1_20x        2106.0        1664.0           0.0   10
# 1580  AnthinyVu_plate1_20x        1404.0         832.0           0.0   10
# 1581  AnthinyVu_plate1_20x        2106.0         832.0           0.0   10
# 1582  AnthinyVu_plate1_20x        1404.0        1664.0           0.0   10
# 1583  AnthinyVu_plate1_20x        2106.0        1664.0           0.0   10
#
#       TimeOffset@s  Timepoint WellName  \
# 0                0          0       B2
# 1                0          0       B2
# 2                0          0       B2
# 3                0          0       B2
# 4                0          0       B2
# 5                0          0       B2
# 6                0          0       B2
# 7                0          0       B2
# 8                0          0       B3
# 9                0          0       B3
# 10               0          0       B3
# 11               0          0       B3
# 12               0          0       B3
# 13               0          0       B3
# 14               0          0       B3
# 15               0          0       B3
# 16               0          0       B4
# 17               0          0       B4
# 18               0          0       B4
# 19               0          0       B4
# 20               0          0       B4
# 21               0          0       B4
# 22               0          0       B4
# 23               0          0       B4
# 24               0          0       B5
# 25               0          0       B5
# 26               0          0       B5
# 27               0          0       B5
# 28               0          0       B5
# 29               0          0       B5
# ...            ...        ...      ...
# 1554             0          0      J20
# 1555             0          0      J20
# 1556             0          0      J20
# 1557             0          0      J20
# 1558             0          0      J20
# 1559             0          0      J20
# 1560             0          0      J21
# 1561             0          0      J21
# 1562             0          0      J21
# 1563             0          0      J21
# 1564             0          0      J21
# 1565             0          0      J21
# 1566             0          0      J21
# 1567             0          0      J21
# 1568             0          0      J22
# 1569             0          0      J22
# 1570             0          0      J22
# 1571             0          0      J22
# 1572             0          0      J22
# 1573             0          0      J22
# 1574             0          0      J22
# 1575             0          0      J22
# 1576             0          0      J23
# 1577             0          0      J23
# 1578             0          0      J23
# 1579             0          0      J23
# 1580             0          0      J23
# 1581             0          0      J23
# 1582             0          0      J23
# 1583             0          0      J23
#
#                                          sourcefilename             label
# 0     DAPI__B_002_r_0001_c_0002_t_00000000_z_0000-00...  negative control
# 1     DAPI__B_002_r_0001_c_0003_t_00000000_z_0000-00...  negative control
# 2     DAPI__B_002_r_0002_c_0002_t_00000000_z_0000-00...  negative control
# 3     DAPI__B_002_r_0002_c_0003_t_00000000_z_0000-00...  negative control
# 4     GFP__B_002_r_0001_c_0002_t_00000000_z_0000-000...  negative control
# 5     GFP__B_002_r_0001_c_0003_t_00000000_z_0000-000...  negative control
# 6     GFP__B_002_r_0002_c_0002_t_00000000_z_0000-000...  negative control
# 7     GFP__B_002_r_0002_c_0003_t_00000000_z_0000-000...  negative control
# 8     DAPI__B_003_r_0001_c_0002_t_00000000_z_0000-00...  negative control
# 9     DAPI__B_003_r_0001_c_0003_t_00000000_z_0000-00...  negative control
# 10    DAPI__B_003_r_0002_c_0002_t_00000000_z_0000-00...  negative control
# 11    DAPI__B_003_r_0002_c_0003_t_00000000_z_0000-00...  negative control
# 12    GFP__B_003_r_0001_c_0002_t_00000000_z_0000-000...  negative control
# 13    GFP__B_003_r_0001_c_0003_t_00000000_z_0000-000...  negative control
# 1574  GFP__J_022_r_0002_c_0002_t_00000000_z_0000-000...    stressed cells
# 1575  GFP__J_022_r_0002_c_0003_t_00000000_z_0000-000...    stressed cells
# 1576  DAPI__J_023_r_0001_c_0002_t_00000000_z_0000-00...               500
# 1577  DAPI__J_023_r_0001_c_0003_t_00000000_z_0000-00...               500
# 1578  DAPI__J_023_r_0002_c_0002_t_00000000_z_0000-00...               500
# 1579  DAPI__J_023_r_0002_c_0003_t_00000000_z_0000-00...               500
# 1580  GFP__J_023_r_0001_c_0002_t_00000000_z_0000-000...               500
# 1581  GFP__J_023_r_0001_c_0003_t_00000000_z_0000-000...               500
# 1582  GFP__J_023_r_0002_c_0002_t_00000000_z_0000-000...               500
# 1583  GFP__J_023_r_0002_c_0003_t_00000000_z_0000-000...               500
#
# [1584 rows x 19 columns]

# %%
get_list_of_associated_files(idx=idx, row='B', col=7)
# Out:
# array(['DAPI__B_007_r_0001_c_0002_t_00000000_z_0000-00000040.tif',
#        'DAPI__B_007_r_0001_c_0003_t_00000000_z_0000-00000041.tif',
#        'DAPI__B_007_r_0002_c_0002_t_00000000_z_0000-00000042.tif',
#        'DAPI__B_007_r_0002_c_0003_t_00000000_z_0000-00000043.tif',
#        'GFP__B_007_r_0001_c_0002_t_00000000_z_0000-00000044.tif',
#        'GFP__B_007_r_0001_c_0003_t_00000000_z_0000-00000045.tif',
#        'GFP__B_007_r_0002_c_0002_t_00000000_z_0000-00000046.tif',
#        'GFP__B_007_r_0002_c_0003_t_00000000_z_0000-00000047.tif'], dtype=object)

# %% [markdown]
# # Getting Image-level metadata from each TIF file

# %%
def read_tif_metadata(fn):
    img = bioformats.load_image(path=fn)
    md = bioformats.get_omexml_metadata(path=fn)
    return bioformats.OMEXML(xml=md)

def read_tif(fn):
    img = bioformats.load_image(path=fn)
    return img

img = read_tif_metadata(
    '/projects/ps-yeolab4/SG_imaging_data/aqvu/rawdata/180123_AnthonyVu_plate1_20x-1516382552/GFP__J_021_r_0002_c_0003_t_00000000_z_0000-00001567.tif'
)
img = read_tif_metadata(
    '/projects/ps-yeolab3/ecwheele/images/cellraft_Air/20180416_100um_g3bp_staining_fullscan/B0D6R.tiff'
)

# %%
print(img.image().Name)
print(img.image().Pixels.ID)
print(img.image().Pixels.PhysicalSizeX)
print(img.image_count)
# Out:
# B0D6R.tiff
# Pixels:0
# None
# 1

# %%
with open('/oasis/tscc/scratch/bay001/example_xml.xml', 'w') as o:
    o.write(img.to_xml())

# %%
img = read_tif_metadata(
    '/projects/ps-yeolab4/NCRCRG/example_files/from_regina_powers/HCS_6.18.18_20x_W1NeunFR_W2NestinR_W3Tuj1G_W4DAPIB_E09_s1_w1.TIF'
)

# %%
print(img.image().Name)
print(img.image().Pixels.ID)
print(img.image().Pixels.PhysicalSizeX)
print(img.image_count)
# Out:
# HCS_6.18.18_20x_W1NeunFR_W2NestinR_W3Tuj1G_W4DAPIB_E09_s1_w1.TIF
# Pixels:0
# None
# 1

# %%
with open('/oasis/tscc/scratch/bay001/example_xml.xml', 'w') as o:
    o.write(img.to_xml())
